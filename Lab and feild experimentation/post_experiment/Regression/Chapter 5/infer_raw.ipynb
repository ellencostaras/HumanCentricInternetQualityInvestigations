# %%
install.packages("ggplot2")
install.packages("dplyr")
install.packages("glmnet")
# Out:
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//Rtmp2dawdP/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//Rtmp2dawdP/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//Rtmp2dawdP/downloaded_packages

# %%
library(dplyr)
library(glmnet)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: Matrix
#
# Loaded glmnet 4.1-8

# %% [markdown]
# # Import and format data

# %%
#read in the data
data <- read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression_2_(web_to_serviceable)/regression_tables/fieldwork_regression_table.csv")
data$scaled_score <- (data$score_min -1)/4
data$logistic_transformed_score <-  1 / (1 + exp(-data$scaled_score))
trim_data <- data %>% select(-identifier,-score_min, - scaled_score,  -serviceable_agg, -score_ellen, -score_aadya, -serviceable_ellen, -serviceable_aadya)

# %% [markdown]
# # Build a model

# %%
model <- lm(logistic_transformed_score ~ ., data = trim_data)
fit_aic <- step(model)
summary(fit_aic)
# Out:
# Start:  AIC=-564.46
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_frameHeight_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_ellen + IT01V_bytesReceived_in_bits_s_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitter_ellen + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=-564.46
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_frameHeight_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_ellen + IT01V_bytesReceived_in_bits_s_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitter_ellen + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=-564.46
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=-564.46
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq      RSS
# - IT01V_jitter_ellen                                  1 0.0000000 0.061162
# - OT01V_bytesSent_in_bits_s_aadya                     1 0.0000000 0.061162
# - RIV_fractionLost_aadya                              1 0.0000033 0.061165
# - AP_totalPlayoutDelay_aadya                          1 0.0000070 0.061169
# - OT01V_packetsSent_s_aadya                           1 0.0000075 0.061169
# - IT01V_jitter_aadya                                  1 0.0000102 0.061172
# - RIA_fractionLost_ellen                              1 0.0000143 0.061176
# - IT01V_packetsRecieved_ellen                         1 0.0000243 0.061186
# - IT01V_totalFreezesDuration_ellen                    1 0.0000373 0.061199
# - RIA_roundTripTime_ellen                             1 0.0000491 0.061211
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000626 0.061224
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000765 0.061238
# - ROA_roundTripTime_aadya                             1 0.0001182 0.061280
# - ROA_roundTripTime_ellen                             1 0.0001754 0.061337
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0002062 0.061368
# - RIV_roundTripTime_ellen                             1 0.0002369 0.061399
# - OT01V_frameWidth_aadya                              1 0.0003270 0.061489
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0003567 0.061519
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0003639 0.061526
# - OT01V_totalPacketSendDelay_aadya                    1 0.0003753 0.061537
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0004154 0.061577
# - IT01V_frameWidth_ellen                              1 0.0004717 0.061633
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0005576 0.061719
# - IT01V_packetsRecieved_aadya                         1 0.0006312 0.061793
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0006447 0.061807
# - IT01V_totalFreezesDuration_aadya                    1 0.0006582 0.061820
# - IT01V_packetsLost_ellen                             1 0.0008304 0.061992
# - OT01V_packetsSent_s_ellen                           1 0.0009659 0.062128
# - RIA_fractionLost_aadya                              1 0.0010922 0.062254
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0010924 0.062254
# - IT01V_frameWidth_aadya                              1 0.0012390 0.062401
# <none>                                                            0.061162
# - IT01V_totalProcessingDelay_ellen                    1 0.0014994 0.062661
# - IT01V_framesPerSecond_aadya                         1 0.0016003 0.062762
# - RIV_fractionLost_ellen                              1 0.0016321 0.062794
# - AP_totalPlayoutDelay_ellen                          1 0.0016876 0.062849
# - IT01V_packetsLost_aadya                             1 0.0021448 0.063307
# - RIA_roundTripTime_aadya                             1 0.0021887 0.063350
# - RIV_roundTripTime_aadya                             1 0.0021969 0.063359
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0024843 0.063646
# - IT01V_totalProcessingDelay_aadya                    1 0.0028364 0.063998
# - OT01V_totalPacketSendDelay_ellen                    1 0.0032602 0.064422
# - OT01V_framesPerSecond_aadya                         1 0.0034438 0.064606
# - IT01V_framesPerSecond_ellen                         1 0.0037800 0.064942
# - OT01V_framesPerSecond_ellen                         1 0.0048420 0.066004
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0081592 0.069321
#                                                          AIC
# - IT01V_jitter_ellen                                 -566.46
# - OT01V_bytesSent_in_bits_s_aadya                    -566.46
# - RIV_fractionLost_aadya                             -566.46
# - AP_totalPlayoutDelay_aadya                         -566.45
# - OT01V_packetsSent_s_aadya                          -566.45
# - IT01V_jitter_aadya                                 -566.45
# - RIA_fractionLost_ellen                             -566.44
# - IT01V_packetsRecieved_ellen                        -566.43
# - IT01V_totalFreezesDuration_ellen                   -566.41
# - RIA_roundTripTime_ellen                            -566.39
# - IT01V_bytesReceived_in_bits_s_ellen                -566.37
# - IT01V_jitterBufferDelay_emissions_aadya            -566.35
# - ROA_roundTripTime_aadya                            -566.29
# - ROA_roundTripTime_ellen                            -566.21
# - IT01A_bytesReceived_in_bits_s_aadya                -566.16
# - RIV_roundTripTime_ellen                            -566.12
# - OT01V_frameWidth_aadya                             -565.98
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -565.94
# - IT01V_bytesReceived_in_bits_s_aadya                -565.93
# - OT01V_totalPacketSendDelay_aadya                   -565.91
# - IT01A_bytesReceived_in_bits_s_ellen                -565.85
# - IT01V_frameWidth_ellen                             -565.77
# - OT01V_bytesSent_in_bits_s_ellen                    -565.65
# - IT01V_packetsRecieved_aadya                        -565.54
# - IT01A_jitterBufferDelay_emissions_aadya            -565.52
# - IT01V_totalFreezesDuration_aadya                   -565.50
# - IT01V_packetsLost_ellen                            -565.25
# - OT01V_packetsSent_s_ellen                          -565.05
# - RIA_fractionLost_aadya                             -564.87
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -564.87
# - IT01V_frameWidth_aadya                             -564.66
# <none>                                               -564.46
# - IT01V_totalProcessingDelay_ellen                   -564.28
# - IT01V_framesPerSecond_aadya                        -564.14
# - RIV_fractionLost_ellen                             -564.09
# - AP_totalPlayoutDelay_ellen                         -564.01
# - IT01V_packetsLost_aadya                            -563.36
# - RIA_roundTripTime_aadya                            -563.30
# - RIV_roundTripTime_aadya                            -563.29
# - IT01V_jitterBufferDelay_emissions_ellen            -562.88
# - IT01V_totalProcessingDelay_aadya                   -562.38
# - OT01V_totalPacketSendDelay_ellen                   -561.79
# - OT01V_framesPerSecond_aadya                        -561.53
# - IT01V_framesPerSecond_ellen                        -561.07
# - OT01V_framesPerSecond_ellen                        -559.61
# - IT01A_jitterBufferDelay_emissions_ellen            -555.19
#
# Step:  AIC=-566.46
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq      RSS
# - OT01V_bytesSent_in_bits_s_aadya                     1 0.0000000 0.061162
# - RIV_fractionLost_aadya                              1 0.0000045 0.061166
# - AP_totalPlayoutDelay_aadya                          1 0.0000071 0.061169
# - OT01V_packetsSent_s_aadya                           1 0.0000076 0.061169
# - IT01V_jitter_aadya                                  1 0.0000106 0.061172
# - RIA_fractionLost_ellen                              1 0.0000147 0.061177
# - IT01V_packetsRecieved_ellen                         1 0.0000245 0.061186
# - IT01V_totalFreezesDuration_ellen                    1 0.0000374 0.061199
# - RIA_roundTripTime_ellen                             1 0.0000501 0.061212
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000637 0.061226
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000782 0.061240
# - ROA_roundTripTime_aadya                             1 0.0001190 0.061281
# - ROA_roundTripTime_ellen                             1 0.0001803 0.061342
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0002097 0.061372
# - RIV_roundTripTime_ellen                             1 0.0002483 0.061410
# - OT01V_frameWidth_aadya                              1 0.0003285 0.061490
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0003567 0.061519
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0003813 0.061543
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0004211 0.061583
# - IT01V_frameWidth_ellen                              1 0.0004766 0.061638
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0005654 0.061727
# - IT01V_totalFreezesDuration_aadya                    1 0.0006607 0.061823
# - OT01V_totalPacketSendDelay_aadya                    1 0.0006697 0.061832
# - IT01V_packetsRecieved_aadya                         1 0.0006714 0.061833
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0007125 0.061874
# - IT01V_packetsLost_ellen                             1 0.0008329 0.061995
# - OT01V_packetsSent_s_ellen                           1 0.0009816 0.062143
# - RIA_fractionLost_aadya                              1 0.0011595 0.062321
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0011760 0.062338
# - IT01V_frameWidth_aadya                              1 0.0012390 0.062401
# <none>                                                            0.061162
# - IT01V_totalProcessingDelay_ellen                    1 0.0016224 0.062784
# - RIV_fractionLost_ellen                              1 0.0016767 0.062839
# - AP_totalPlayoutDelay_ellen                          1 0.0017805 0.062942
# - IT01V_framesPerSecond_aadya                         1 0.0020695 0.063231
# - IT01V_packetsLost_aadya                             1 0.0021792 0.063341
# - RIA_roundTripTime_aadya                             1 0.0022512 0.063413
# - RIV_roundTripTime_aadya                             1 0.0022609 0.063423
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0029085 0.064070
# - IT01V_totalProcessingDelay_aadya                    1 0.0030997 0.064262
# - OT01V_totalPacketSendDelay_ellen                    1 0.0032627 0.064425
# - OT01V_framesPerSecond_aadya                         1 0.0035973 0.064759
# - IT01V_framesPerSecond_ellen                         1 0.0044055 0.065567
# - OT01V_framesPerSecond_ellen                         1 0.0055457 0.066708
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0084477 0.069610
#                                                          AIC
# - OT01V_bytesSent_in_bits_s_aadya                    -568.46
# - RIV_fractionLost_aadya                             -568.46
# - AP_totalPlayoutDelay_aadya                         -568.45
# - OT01V_packetsSent_s_aadya                          -568.45
# - IT01V_jitter_aadya                                 -568.45
# - RIA_fractionLost_ellen                             -568.44
# - IT01V_packetsRecieved_ellen                        -568.43
# - IT01V_totalFreezesDuration_ellen                   -568.41
# - RIA_roundTripTime_ellen                            -568.39
# - IT01V_bytesReceived_in_bits_s_ellen                -568.37
# - IT01V_jitterBufferDelay_emissions_aadya            -568.35
# - ROA_roundTripTime_aadya                            -568.29
# - ROA_roundTripTime_ellen                            -568.20
# - IT01A_bytesReceived_in_bits_s_aadya                -568.16
# - RIV_roundTripTime_ellen                            -568.10
# - OT01V_frameWidth_aadya                             -567.98
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -567.94
# - IT01V_bytesReceived_in_bits_s_aadya                -567.90
# - IT01A_bytesReceived_in_bits_s_ellen                -567.85
# - IT01V_frameWidth_ellen                             -567.77
# - OT01V_bytesSent_in_bits_s_ellen                    -567.64
# - IT01V_totalFreezesDuration_aadya                   -567.50
# - OT01V_totalPacketSendDelay_aadya                   -567.48
# - IT01V_packetsRecieved_aadya                        -567.48
# - IT01A_jitterBufferDelay_emissions_aadya            -567.42
# - IT01V_packetsLost_ellen                            -567.25
# - OT01V_packetsSent_s_ellen                          -567.03
# - RIA_fractionLost_aadya                             -566.77
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -566.75
# - IT01V_frameWidth_aadya                             -566.66
# <none>                                               -566.46
# - IT01V_totalProcessingDelay_ellen                   -566.11
# - RIV_fractionLost_ellen                             -566.03
# - AP_totalPlayoutDelay_ellen                         -565.88
# - IT01V_framesPerSecond_aadya                        -565.47
# - IT01V_packetsLost_aadya                            -565.31
# - RIA_roundTripTime_aadya                            -565.21
# - RIV_roundTripTime_aadya                            -565.20
# - IT01V_jitterBufferDelay_emissions_ellen            -564.28
# - IT01V_totalProcessingDelay_aadya                   -564.01
# - OT01V_totalPacketSendDelay_ellen                   -563.79
# - OT01V_framesPerSecond_aadya                        -563.32
# - IT01V_framesPerSecond_ellen                        -562.20
# - OT01V_framesPerSecond_ellen                        -560.65
# - IT01A_jitterBufferDelay_emissions_ellen            -556.82
#
# Step:  AIC=-568.46
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq      RSS
# - RIV_fractionLost_aadya                              1 0.0000046 0.061166
# - AP_totalPlayoutDelay_aadya                          1 0.0000075 0.061169
# - IT01V_jitter_aadya                                  1 0.0000112 0.061173
# - RIA_fractionLost_ellen                              1 0.0000147 0.061177
# - IT01V_packetsRecieved_ellen                         1 0.0000249 0.061187
# - IT01V_totalFreezesDuration_ellen                    1 0.0000379 0.061200
# - RIA_roundTripTime_ellen                             1 0.0000501 0.061212
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000658 0.061228
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000783 0.061240
# - ROA_roundTripTime_aadya                             1 0.0001503 0.061312
# - OT01V_packetsSent_s_aadya                           1 0.0001755 0.061337
# - ROA_roundTripTime_ellen                             1 0.0001815 0.061343
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0002165 0.061378
# - RIV_roundTripTime_ellen                             1 0.0002602 0.061422
# - OT01V_frameWidth_aadya                              1 0.0003520 0.061514
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0003572 0.061519
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0003824 0.061544
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0004214 0.061583
# - IT01V_frameWidth_ellen                              1 0.0004977 0.061660
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0005911 0.061753
# - IT01V_totalFreezesDuration_aadya                    1 0.0006610 0.061823
# - IT01V_packetsRecieved_aadya                         1 0.0006721 0.061834
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0007125 0.061874
# - OT01V_totalPacketSendDelay_aadya                    1 0.0007524 0.061914
# - IT01V_packetsLost_ellen                             1 0.0008495 0.062011
# - OT01V_packetsSent_s_ellen                           1 0.0010467 0.062209
# - RIA_fractionLost_aadya                              1 0.0011642 0.062326
# <none>                                                            0.061162
# - IT01V_frameWidth_aadya                              1 0.0014136 0.062576
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0015706 0.062732
# - IT01V_totalProcessingDelay_ellen                    1 0.0016669 0.062829
# - RIV_fractionLost_ellen                              1 0.0017047 0.062867
# - AP_totalPlayoutDelay_ellen                          1 0.0019660 0.063128
# - IT01V_framesPerSecond_aadya                         1 0.0021660 0.063328
# - IT01V_packetsLost_aadya                             1 0.0021793 0.063341
# - RIA_roundTripTime_aadya                             1 0.0028009 0.063963
# - RIV_roundTripTime_aadya                             1 0.0028163 0.063978
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0030010 0.064163
# - IT01V_totalProcessingDelay_aadya                    1 0.0032361 0.064398
# - OT01V_totalPacketSendDelay_ellen                    1 0.0032649 0.064427
# - OT01V_framesPerSecond_aadya                         1 0.0036025 0.064764
# - IT01V_framesPerSecond_ellen                         1 0.0046438 0.065806
# - OT01V_framesPerSecond_ellen                         1 0.0055683 0.066730
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0087484 0.069910
#                                                          AIC
# - RIV_fractionLost_aadya                             -570.46
# - AP_totalPlayoutDelay_aadya                         -570.45
# - IT01V_jitter_aadya                                 -570.45
# - RIA_fractionLost_ellen                             -570.44
# - IT01V_packetsRecieved_ellen                        -570.43
# - IT01V_totalFreezesDuration_ellen                   -570.41
# - RIA_roundTripTime_ellen                            -570.39
# - IT01V_bytesReceived_in_bits_s_ellen                -570.37
# - IT01V_jitterBufferDelay_emissions_aadya            -570.35
# - ROA_roundTripTime_aadya                            -570.24
# - OT01V_packetsSent_s_aadya                          -570.21
# - ROA_roundTripTime_ellen                            -570.20
# - IT01A_bytesReceived_in_bits_s_aadya                -570.15
# - RIV_roundTripTime_ellen                            -570.08
# - OT01V_frameWidth_aadya                             -569.95
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -569.94
# - IT01V_bytesReceived_in_bits_s_aadya                -569.90
# - IT01A_bytesReceived_in_bits_s_ellen                -569.85
# - IT01V_frameWidth_ellen                             -569.73
# - OT01V_bytesSent_in_bits_s_ellen                    -569.60
# - IT01V_totalFreezesDuration_aadya                   -569.50
# - IT01V_packetsRecieved_aadya                        -569.48
# - IT01A_jitterBufferDelay_emissions_aadya            -569.42
# - OT01V_totalPacketSendDelay_aadya                   -569.36
# - IT01V_packetsLost_ellen                            -569.22
# - OT01V_packetsSent_s_ellen                          -568.94
# - RIA_fractionLost_aadya                             -568.77
# <none>                                               -568.46
# - IT01V_frameWidth_aadya                             -568.41
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -568.18
# - IT01V_totalProcessingDelay_ellen                   -568.04
# - RIV_fractionLost_ellen                             -567.99
# - AP_totalPlayoutDelay_ellen                         -567.62
# - IT01V_framesPerSecond_aadya                        -567.33
# - IT01V_packetsLost_aadya                            -567.31
# - RIA_roundTripTime_aadya                            -566.43
# - RIV_roundTripTime_aadya                            -566.41
# - IT01V_jitterBufferDelay_emissions_ellen            -566.15
# - IT01V_totalProcessingDelay_aadya                   -565.82
# - OT01V_totalPacketSendDelay_ellen                   -565.78
# - OT01V_framesPerSecond_aadya                        -565.31
# - IT01V_framesPerSecond_ellen                        -563.88
# - OT01V_framesPerSecond_ellen                        -562.62
# - IT01A_jitterBufferDelay_emissions_ellen            -558.43
#
# Step:  AIC=-570.46
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_ellen +
#     RIA_roundTripTime_aadya + ROA_roundTripTime_ellen + ROA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq      RSS
# - AP_totalPlayoutDelay_aadya                          1 0.0000092 0.061176
# - RIA_fractionLost_ellen                              1 0.0000146 0.061181
# - IT01V_jitter_aadya                                  1 0.0000168 0.061183
# - IT01V_packetsRecieved_ellen                         1 0.0000278 0.061194
# - IT01V_totalFreezesDuration_ellen                    1 0.0000358 0.061202
# - RIA_roundTripTime_ellen                             1 0.0000485 0.061215
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000738 0.061240
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000740 0.061240
# - ROA_roundTripTime_aadya                             1 0.0001492 0.061316
# - ROA_roundTripTime_ellen                             1 0.0001790 0.061345
# - OT01V_packetsSent_s_aadya                           1 0.0001930 0.061359
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0002417 0.061408
# - RIV_roundTripTime_ellen                             1 0.0002579 0.061424
# - OT01V_frameWidth_aadya                              1 0.0003526 0.061519
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0003690 0.061535
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0003934 0.061560
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0004558 0.061622
# - IT01V_frameWidth_ellen                              1 0.0005009 0.061667
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0006008 0.061767
# - IT01V_packetsRecieved_aadya                         1 0.0006926 0.061859
# - IT01V_totalFreezesDuration_aadya                    1 0.0007133 0.061880
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0007325 0.061899
# - OT01V_totalPacketSendDelay_aadya                    1 0.0007516 0.061918
# - IT01V_packetsLost_ellen                             1 0.0008697 0.062036
# - OT01V_packetsSent_s_ellen                           1 0.0010667 0.062233
# - RIA_fractionLost_aadya                              1 0.0012054 0.062372
# <none>                                                            0.061166
# - IT01V_frameWidth_aadya                              1 0.0015376 0.062704
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0016971 0.062864
# - RIV_fractionLost_ellen                              1 0.0017065 0.062873
# - IT01V_totalProcessingDelay_ellen                    1 0.0017528 0.062919
# - AP_totalPlayoutDelay_ellen                          1 0.0019692 0.063136
# - IT01V_packetsLost_aadya                             1 0.0021814 0.063348
# - IT01V_framesPerSecond_aadya                         1 0.0022112 0.063378
# - RIA_roundTripTime_aadya                             1 0.0028008 0.063967
# - RIV_roundTripTime_aadya                             1 0.0028163 0.063983
# - IT01V_totalProcessingDelay_aadya                    1 0.0032328 0.064399
# - OT01V_totalPacketSendDelay_ellen                    1 0.0032676 0.064434
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0034119 0.064578
# - OT01V_framesPerSecond_aadya                         1 0.0038956 0.065062
# - IT01V_framesPerSecond_ellen                         1 0.0050177 0.066184
# - OT01V_framesPerSecond_ellen                         1 0.0056190 0.066785
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0088504 0.070017
#                                                          AIC
# - AP_totalPlayoutDelay_aadya                         -572.44
# - RIA_fractionLost_ellen                             -572.44
# - IT01V_jitter_aadya                                 -572.43
# - IT01V_packetsRecieved_ellen                        -572.42
# - IT01V_totalFreezesDuration_ellen                   -572.40
# - RIA_roundTripTime_ellen                            -572.39
# - IT01V_jitterBufferDelay_emissions_aadya            -572.35
# - IT01V_bytesReceived_in_bits_s_ellen                -572.35
# - ROA_roundTripTime_aadya                            -572.24
# - ROA_roundTripTime_ellen                            -572.19
# - OT01V_packetsSent_s_aadya                          -572.17
# - IT01A_bytesReceived_in_bits_s_aadya                -572.10
# - RIV_roundTripTime_ellen                            -572.08
# - OT01V_frameWidth_aadya                             -571.94
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -571.92
# - IT01V_bytesReceived_in_bits_s_aadya                -571.88
# - IT01A_bytesReceived_in_bits_s_ellen                -571.79
# - IT01V_frameWidth_ellen                             -571.72
# - OT01V_bytesSent_in_bits_s_ellen                    -571.58
# - IT01V_packetsRecieved_aadya                        -571.44
# - IT01V_totalFreezesDuration_aadya                   -571.41
# - IT01A_jitterBufferDelay_emissions_aadya            -571.39
# - OT01V_totalPacketSendDelay_aadya                   -571.36
# - IT01V_packetsLost_ellen                            -571.19
# - OT01V_packetsSent_s_ellen                          -570.90
# - RIA_fractionLost_aadya                             -570.70
# <none>                                               -570.46
# - IT01V_frameWidth_aadya                             -570.22
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -569.99
# - RIV_fractionLost_ellen                             -569.98
# - IT01V_totalProcessingDelay_ellen                   -569.91
# - AP_totalPlayoutDelay_ellen                         -569.61
# - IT01V_packetsLost_aadya                            -569.30
# - IT01V_framesPerSecond_aadya                        -569.26
# - RIA_roundTripTime_aadya                            -568.43
# - RIV_roundTripTime_aadya                            -568.41
# - IT01V_totalProcessingDelay_aadya                   -567.82
# - OT01V_totalPacketSendDelay_ellen                   -567.77
# - IT01V_jitterBufferDelay_emissions_ellen            -567.57
# - OT01V_framesPerSecond_aadya                        -566.90
# - IT01V_framesPerSecond_ellen                        -565.36
# - OT01V_framesPerSecond_ellen                        -564.55
# - IT01A_jitterBufferDelay_emissions_ellen            -560.29
#
# Step:  AIC=-572.44
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_ellen +
#     RIA_roundTripTime_aadya + ROA_roundTripTime_ellen + ROA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq      RSS
# - RIA_fractionLost_ellen                              1 0.0000120 0.061188
# - IT01V_jitter_aadya                                  1 0.0000178 0.061194
# - IT01V_packetsRecieved_ellen                         1 0.0000300 0.061206
# - IT01V_totalFreezesDuration_ellen                    1 0.0000404 0.061216
# - RIA_roundTripTime_ellen                             1 0.0000592 0.061235
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000740 0.061250
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000748 0.061250
# - ROA_roundTripTime_aadya                             1 0.0001426 0.061318
# - OT01V_packetsSent_s_aadya                           1 0.0001838 0.061359
# - ROA_roundTripTime_ellen                             1 0.0001908 0.061366
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0002349 0.061411
# - RIV_roundTripTime_ellen                             1 0.0003132 0.061489
# - OT01V_frameWidth_aadya                              1 0.0003540 0.061530
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0003599 0.061536
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0004428 0.061618
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0004466 0.061622
# - IT01V_frameWidth_ellen                              1 0.0005029 0.061679
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0007045 0.061880
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0007403 0.061916
# - IT01V_totalFreezesDuration_aadya                    1 0.0007416 0.061917
# - OT01V_totalPacketSendDelay_aadya                    1 0.0007688 0.061944
# - IT01V_packetsRecieved_aadya                         1 0.0007708 0.061947
# - IT01V_packetsLost_ellen                             1 0.0008673 0.062043
# - RIA_fractionLost_aadya                              1 0.0012177 0.062393
# - OT01V_packetsSent_s_ellen                           1 0.0012396 0.062415
# <none>                                                            0.061176
# - IT01V_frameWidth_aadya                              1 0.0015350 0.062711
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0017117 0.062887
# - IT01V_totalProcessingDelay_ellen                    1 0.0017449 0.062921
# - RIV_fractionLost_ellen                              1 0.0019117 0.063087
# - IT01V_packetsLost_aadya                             1 0.0021730 0.063349
# - IT01V_framesPerSecond_aadya                         1 0.0022583 0.063434
# - RIA_roundTripTime_aadya                             1 0.0028468 0.064022
# - RIV_roundTripTime_aadya                             1 0.0028615 0.064037
# - IT01V_totalProcessingDelay_aadya                    1 0.0032236 0.064399
# - OT01V_totalPacketSendDelay_ellen                    1 0.0032697 0.064445
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0034029 0.064579
# - AP_totalPlayoutDelay_ellen                          1 0.0040321 0.065208
# - OT01V_framesPerSecond_aadya                         1 0.0040335 0.065209
# - IT01V_framesPerSecond_ellen                         1 0.0050840 0.066260
# - OT01V_framesPerSecond_ellen                         1 0.0062230 0.067399
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0090486 0.070224
#                                                          AIC
# - RIA_fractionLost_ellen                             -574.43
# - IT01V_jitter_aadya                                 -574.42
# - IT01V_packetsRecieved_ellen                        -574.40
# - IT01V_totalFreezesDuration_ellen                   -574.38
# - RIA_roundTripTime_ellen                            -574.36
# - IT01V_jitterBufferDelay_emissions_aadya            -574.33
# - IT01V_bytesReceived_in_bits_s_ellen                -574.33
# - ROA_roundTripTime_aadya                            -574.23
# - OT01V_packetsSent_s_aadya                          -574.17
# - ROA_roundTripTime_ellen                            -574.16
# - IT01A_bytesReceived_in_bits_s_aadya                -574.10
# - RIV_roundTripTime_ellen                            -573.98
# - OT01V_frameWidth_aadya                             -573.92
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -573.92
# - IT01V_bytesReceived_in_bits_s_aadya                -573.79
# - IT01A_bytesReceived_in_bits_s_ellen                -573.79
# - IT01V_frameWidth_ellen                             -573.71
# - OT01V_bytesSent_in_bits_s_ellen                    -573.41
# - IT01A_jitterBufferDelay_emissions_aadya            -573.36
# - IT01V_totalFreezesDuration_aadya                   -573.36
# - OT01V_totalPacketSendDelay_aadya                   -573.32
# - IT01V_packetsRecieved_aadya                        -573.32
# - IT01V_packetsLost_ellen                            -573.18
# - RIA_fractionLost_aadya                             -572.67
# - OT01V_packetsSent_s_ellen                          -572.64
# <none>                                               -572.44
# - IT01V_frameWidth_aadya                             -572.21
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -571.96
# - IT01V_totalProcessingDelay_ellen                   -571.91
# - RIV_fractionLost_ellen                             -571.67
# - IT01V_packetsLost_aadya                            -571.30
# - IT01V_framesPerSecond_aadya                        -571.18
# - RIA_roundTripTime_aadya                            -570.35
# - RIV_roundTripTime_aadya                            -570.33
# - IT01V_totalProcessingDelay_aadya                   -569.82
# - OT01V_totalPacketSendDelay_ellen                   -569.76
# - IT01V_jitterBufferDelay_emissions_ellen            -569.57
# - AP_totalPlayoutDelay_ellen                         -568.70
# - OT01V_framesPerSecond_aadya                        -568.70
# - IT01V_framesPerSecond_ellen                        -567.26
# - OT01V_framesPerSecond_ellen                        -565.72
# - IT01A_jitterBufferDelay_emissions_ellen            -562.03
#
# Step:  AIC=-574.43
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIA_fractionLost_aadya + RIA_roundTripTime_ellen + RIA_roundTripTime_aadya +
#     ROA_roundTripTime_ellen + ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq      RSS
# - IT01V_jitter_aadya                                  1 0.0000208 0.061208
# - IT01V_packetsRecieved_ellen                         1 0.0000276 0.061215
# - IT01V_totalFreezesDuration_ellen                    1 0.0000428 0.061230
# - RIA_roundTripTime_ellen                             1 0.0000590 0.061247
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000697 0.061257
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000705 0.061258
# - ROA_roundTripTime_aadya                             1 0.0001513 0.061339
# - OT01V_packetsSent_s_aadya                           1 0.0001769 0.061365
# - ROA_roundTripTime_ellen                             1 0.0001994 0.061387
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0002281 0.061416
# - RIV_roundTripTime_ellen                             1 0.0003328 0.061521
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0003507 0.061538
# - OT01V_frameWidth_aadya                              1 0.0003523 0.061540
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0004384 0.061626
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0004471 0.061635
# - IT01V_frameWidth_ellen                              1 0.0004995 0.061687
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0007398 0.061927
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0007563 0.061944
# - OT01V_totalPacketSendDelay_aadya                    1 0.0007573 0.061945
# - IT01V_packetsRecieved_aadya                         1 0.0007688 0.061957
# - IT01V_totalFreezesDuration_aadya                    1 0.0007746 0.061962
# - IT01V_packetsLost_ellen                             1 0.0008707 0.062058
# - RIA_fractionLost_aadya                              1 0.0012284 0.062416
# - OT01V_packetsSent_s_ellen                           1 0.0013032 0.062491
# <none>                                                            0.061188
# - IT01V_frameWidth_aadya                              1 0.0016109 0.062799
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0017044 0.062892
# - IT01V_totalProcessingDelay_ellen                    1 0.0017753 0.062963
# - RIV_fractionLost_ellen                              1 0.0019384 0.063126
# - IT01V_packetsLost_aadya                             1 0.0021670 0.063355
# - IT01V_framesPerSecond_aadya                         1 0.0023048 0.063492
# - RIA_roundTripTime_aadya                             1 0.0028822 0.064070
# - RIV_roundTripTime_aadya                             1 0.0028964 0.064084
# - IT01V_totalProcessingDelay_aadya                    1 0.0032172 0.064405
# - OT01V_totalPacketSendDelay_ellen                    1 0.0032667 0.064454
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0034276 0.064615
# - OT01V_framesPerSecond_aadya                         1 0.0040274 0.065215
# - AP_totalPlayoutDelay_ellen                          1 0.0041266 0.065314
# - IT01V_framesPerSecond_ellen                         1 0.0050852 0.066273
# - OT01V_framesPerSecond_ellen                         1 0.0063133 0.067501
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0090510 0.070239
#                                                          AIC
# - IT01V_jitter_aadya                                 -576.40
# - IT01V_packetsRecieved_ellen                        -576.39
# - IT01V_totalFreezesDuration_ellen                   -576.36
# - RIA_roundTripTime_ellen                            -576.34
# - IT01V_jitterBufferDelay_emissions_aadya            -576.32
# - IT01V_bytesReceived_in_bits_s_ellen                -576.32
# ...
# - OT01V_totalPacketSendDelay_ellen                   -595.29
# - RIV_fractionLost_ellen                             -594.95
# - RIA_fractionLost_aadya                             -593.50
# - IT01V_framesPerSecond_ellen                        -592.86
# - OT01V_framesPerSecond_aadya                        -590.77
# - OT01V_framesPerSecond_ellen                        -588.08
# - RIV_roundTripTime_aadya                            -586.66
# - RIA_roundTripTime_aadya                            -586.56
# - IT01A_jitterBufferDelay_emissions_ellen            -575.97
#
# Step:  AIC=-602.26
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_frameWidth_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_bytesSent_in_bits_s_ellen + OT01V_framesPerSecond_ellen +
#     OT01V_framesPerSecond_aadya + OT01V_totalPacketSendDelay_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq      RSS
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0008278 0.069331
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0010770 0.069580
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0012897 0.069793
# <none>                                                            0.068503
# - OT01V_packetsSent_s_ellen                           1 0.0015969 0.070100
# - IT01V_frameWidth_aadya                              1 0.0018140 0.070317
# - IT01V_packetsLost_aadya                             1 0.0021424 0.070645
# - IT01V_totalProcessingDelay_ellen                    1 0.0024198 0.070923
# - IT01V_framesPerSecond_aadya                         1 0.0028479 0.071351
# - IT01V_totalProcessingDelay_aadya                    1 0.0040417 0.072545
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0051035 0.073606
# - AP_totalPlayoutDelay_ellen                          1 0.0055579 0.074061
# - OT01V_totalPacketSendDelay_ellen                    1 0.0059772 0.074480
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0064756 0.074979
# - RIV_fractionLost_ellen                              1 0.0072129 0.075716
# - IT01V_framesPerSecond_ellen                         1 0.0077759 0.076279
# - OT01V_framesPerSecond_aadya                         1 0.0094236 0.077927
# - RIA_fractionLost_aadya                              1 0.0100995 0.078602
# - OT01V_framesPerSecond_ellen                         1 0.0122965 0.080799
# - RIV_roundTripTime_aadya                             1 0.0133169 0.081820
# - RIA_roundTripTime_aadya                             1 0.0134061 0.081909
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0232475 0.091750
#                                                          AIC
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -603.18
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -602.86
# - OT01V_bytesSent_in_bits_s_ellen                    -602.58
# <none>                                               -602.26
# - OT01V_packetsSent_s_ellen                          -602.19
# - IT01V_frameWidth_aadya                             -601.91
# - IT01V_packetsLost_aadya                            -601.49
# - IT01V_totalProcessingDelay_ellen                   -601.14
# - IT01V_framesPerSecond_aadya                        -600.60
# - IT01V_totalProcessingDelay_aadya                   -599.10
# - IT01A_jitterBufferDelay_emissions_aadya            -597.79
# - AP_totalPlayoutDelay_ellen                         -597.24
# - OT01V_totalPacketSendDelay_ellen                   -596.73
# - IT01V_jitterBufferDelay_emissions_ellen            -596.13
# - RIV_fractionLost_ellen                             -595.25
# - IT01V_framesPerSecond_ellen                        -594.59
# - OT01V_framesPerSecond_aadya                        -592.66
# - RIA_fractionLost_aadya                             -591.88
# - OT01V_framesPerSecond_ellen                        -589.40
# - RIV_roundTripTime_aadya                            -588.27
# - RIA_roundTripTime_aadya                            -588.18
# - IT01A_jitterBufferDelay_emissions_ellen            -577.96
#
# Step:  AIC=-603.18
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_frameWidth_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_bytesSent_in_bits_s_ellen + OT01V_framesPerSecond_ellen +
#     OT01V_framesPerSecond_aadya + OT01V_totalPacketSendDelay_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + RIV_roundTripTime_aadya +
#     RIV_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq      RSS
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0011347 0.070465
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0013154 0.070646
# <none>                                                            0.069331
# - OT01V_packetsSent_s_ellen                           1 0.0016593 0.070990
# - IT01V_packetsLost_aadya                             1 0.0019781 0.071309
# - IT01V_frameWidth_aadya                              1 0.0021847 0.071515
# - IT01V_framesPerSecond_aadya                         1 0.0033101 0.072641
# - IT01V_totalProcessingDelay_aadya                    1 0.0033445 0.072675
# - IT01V_totalProcessingDelay_ellen                    1 0.0043918 0.073723
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0048364 0.074167
# - OT01V_totalPacketSendDelay_ellen                    1 0.0061625 0.075493
# - IT01V_framesPerSecond_ellen                         1 0.0069554 0.076286
# - RIV_fractionLost_ellen                              1 0.0075730 0.076904
# - AP_totalPlayoutDelay_ellen                          1 0.0080068 0.077338
# - OT01V_framesPerSecond_aadya                         1 0.0086187 0.077949
# - RIA_fractionLost_aadya                              1 0.0110002 0.080331
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0121676 0.081498
# - OT01V_framesPerSecond_ellen                         1 0.0124886 0.081819
# - RIV_roundTripTime_aadya                             1 0.0130642 0.082395
# - RIA_roundTripTime_aadya                             1 0.0131406 0.082471
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0225520 0.091883
#                                                          AIC
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -603.72
# - OT01V_bytesSent_in_bits_s_ellen                    -603.49
# <none>                                               -603.18
# - OT01V_packetsSent_s_ellen                          -603.05
# - IT01V_packetsLost_aadya                            -602.65
# - IT01V_frameWidth_aadya                             -602.39
# - IT01V_framesPerSecond_aadya                        -600.98
# - IT01V_totalProcessingDelay_aadya                   -600.94
# - IT01V_totalProcessingDelay_ellen                   -599.65
# - IT01A_jitterBufferDelay_emissions_aadya            -599.11
# - OT01V_totalPacketSendDelay_ellen                   -597.52
# - IT01V_framesPerSecond_ellen                        -596.58
# - RIV_fractionLost_ellen                             -595.85
# - AP_totalPlayoutDelay_ellen                         -595.34
# - OT01V_framesPerSecond_aadya                        -594.64
# - RIA_fractionLost_aadya                             -591.93
# - IT01V_jitterBufferDelay_emissions_ellen            -590.63
# - OT01V_framesPerSecond_ellen                        -590.27
# - RIV_roundTripTime_aadya                            -589.64
# - RIA_roundTripTime_aadya                            -589.56
# - IT01A_jitterBufferDelay_emissions_ellen            -579.83
#
# Step:  AIC=-603.72
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_frameWidth_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_bytesSent_in_bits_s_ellen + OT01V_framesPerSecond_ellen +
#     OT01V_framesPerSecond_aadya + OT01V_totalPacketSendDelay_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen
#
#                                           Df Sum of Sq      RSS     AIC
# - IT01V_frameWidth_aadya                   1 0.0011693 0.071635 -604.24
# - IT01V_packetsLost_aadya                  1 0.0013516 0.071817 -604.01
# <none>                                                 0.070465 -603.72
# - OT01V_bytesSent_in_bits_s_ellen          1 0.0016666 0.072132 -603.62
# - OT01V_packetsSent_s_ellen                1 0.0018609 0.072326 -603.37
# - IT01V_totalProcessingDelay_aadya         1 0.0023192 0.072785 -602.81
# - IT01V_framesPerSecond_aadya              1 0.0030354 0.073501 -601.92
# - IT01V_totalProcessingDelay_ellen         1 0.0037527 0.074218 -601.05
# - IT01A_jitterBufferDelay_emissions_aadya  1 0.0042367 0.074702 -600.47
# - OT01V_totalPacketSendDelay_ellen         1 0.0063848 0.076850 -597.91
# - RIV_fractionLost_ellen                   1 0.0067165 0.077182 -597.53
# - AP_totalPlayoutDelay_ellen               1 0.0069373 0.077403 -597.27
# - IT01V_framesPerSecond_ellen              1 0.0072291 0.077695 -596.93
# - OT01V_framesPerSecond_aadya              1 0.0093120 0.079777 -594.55
# - RIA_fractionLost_aadya                   1 0.0104545 0.080920 -593.27
# - IT01V_jitterBufferDelay_emissions_ellen  1 0.0112667 0.081732 -592.37
# - OT01V_framesPerSecond_ellen              1 0.0125055 0.082971 -591.02
# - RIV_roundTripTime_aadya                  1 0.0144193 0.084885 -588.96
# - RIA_roundTripTime_aadya                  1 0.0145164 0.084982 -588.86
# - IT01A_jitterBufferDelay_emissions_ellen  1 0.0217366 0.092202 -581.52
#
# Step:  AIC=-604.24
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + RIV_roundTripTime_aadya +
#     RIV_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                           Df Sum of Sq      RSS     AIC
# <none>                                                 0.071635 -604.24
# - IT01V_totalProcessingDelay_aadya         1 0.0016246 0.073259 -604.22
# - IT01V_framesPerSecond_aadya              1 0.0023582 0.073993 -603.32
# - IT01V_totalProcessingDelay_ellen         1 0.0027292 0.074364 -602.87
# - OT01V_packetsSent_s_ellen                1 0.0029584 0.074593 -602.60
# - OT01V_bytesSent_in_bits_s_ellen          1 0.0031627 0.074797 -602.35
# - IT01A_jitterBufferDelay_emissions_aadya  1 0.0035718 0.075207 -601.86
# - IT01V_packetsLost_aadya                  1 0.0037695 0.075404 -601.62
# - AP_totalPlayoutDelay_ellen               1 0.0059690 0.077604 -599.04
# - RIV_fractionLost_ellen                   1 0.0061061 0.077741 -598.88
# - IT01V_framesPerSecond_ellen              1 0.0069858 0.078620 -597.86
# - OT01V_framesPerSecond_aadya              1 0.0095017 0.081136 -595.03
# - RIA_fractionLost_aadya                   1 0.0097353 0.081370 -594.77
# - IT01V_jitterBufferDelay_emissions_ellen  1 0.0102530 0.081888 -594.20
# - OT01V_totalPacketSendDelay_ellen         1 0.0115237 0.083158 -592.81
# - OT01V_framesPerSecond_ellen              1 0.0120871 0.083722 -592.21
# - RIV_roundTripTime_aadya                  1 0.0132632 0.084898 -590.95
# - RIA_roundTripTime_aadya                  1 0.0133594 0.084994 -590.85
# - IT01A_jitterBufferDelay_emissions_ellen  1 0.0221242 0.093759 -582.02
# Call:
# lm(formula = logistic_transformed_score ~ IT01V_packetsLost_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_bytesSent_in_bits_s_ellen + OT01V_framesPerSecond_ellen +
#     OT01V_framesPerSecond_aadya + OT01V_totalPacketSendDelay_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen, data = trim_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.07130 -0.01663  0.00031  0.01897  0.07109
#
# Coefficients:
#                                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)                              7.432e-01  6.972e-02  10.660  < 2e-16
# IT01V_packetsLost_aadya                  1.838e-03  9.509e-04   1.933 0.057239
# IT01V_framesPerSecond_ellen             -7.122e-03  2.707e-03  -2.631 0.010425
# IT01V_framesPerSecond_aadya             -2.112e-03  1.382e-03  -1.529 0.130753
# IT01V_totalProcessingDelay_ellen         4.195e-04  2.551e-04   1.645 0.104457
# IT01V_totalProcessingDelay_aadya        -2.026e-04  1.596e-04  -1.269 0.208612
# IT01V_jitterBufferDelay_emissions_ellen -2.845e-04  8.924e-05  -3.188 0.002133
# IT01A_jitterBufferDelay_emissions_ellen -9.414e-05  2.010e-05  -4.683 1.32e-05
# IT01A_jitterBufferDelay_emissions_aadya  4.321e-05  2.296e-05   1.882 0.063998
# OT01V_packetsSent_s_ellen               -3.383e-03  1.976e-03  -1.712 0.091197
# OT01V_bytesSent_in_bits_s_ellen          3.807e-07  2.150e-07   1.771 0.080935
# OT01V_framesPerSecond_ellen              4.940e-03  1.427e-03   3.461 0.000914
# OT01V_framesPerSecond_aadya              7.836e-03  2.554e-03   3.069 0.003043
# OT01V_totalPacketSendDelay_ellen         1.579e-04  4.671e-05   3.380 0.001182
# RIV_roundTripTime_aadya                  3.314e-01  9.139e-02   3.626 0.000539
# RIV_fractionLost_ellen                  -2.828e+00  1.150e+00  -2.460 0.016327
# RIA_fractionLost_aadya                   2.940e-01  9.466e-02   3.106 0.002723
# RIA_roundTripTime_aadya                 -4.261e-01  1.171e-01  -3.639 0.000516
# AP_totalPlayoutDelay_ellen              -3.025e-06  1.244e-06  -2.432 0.017526
#
# (Intercept)                             ***
# IT01V_packetsLost_aadya                 .
# IT01V_framesPerSecond_ellen             *
# IT01V_framesPerSecond_aadya
# IT01V_totalProcessingDelay_ellen
# IT01V_totalProcessingDelay_aadya
# IT01V_jitterBufferDelay_emissions_ellen **
# IT01A_jitterBufferDelay_emissions_ellen ***
# IT01A_jitterBufferDelay_emissions_aadya .
# OT01V_packetsSent_s_ellen               .
# OT01V_bytesSent_in_bits_s_ellen         .
# OT01V_framesPerSecond_ellen             ***
# OT01V_framesPerSecond_aadya             **
# OT01V_totalPacketSendDelay_ellen        **
# RIV_roundTripTime_aadya                 ***
# RIV_fractionLost_ellen                  *
# RIA_fractionLost_aadya                  **
# RIA_roundTripTime_aadya                 ***
# AP_totalPlayoutDelay_ellen              *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.03176 on 71 degrees of freedom
# Multiple R-squared:  0.6458,	Adjusted R-squared:  0.556
# F-statistic:  7.19 on 18 and 71 DF,  p-value: 5.5e-10

# %% [markdown]
# # import data

# %%
stage_1 <- read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression_2_(web_to_serviceable)/regression_tables/stage_1_regression_table.csv")
stage_2 <- read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression_2_(web_to_serviceable)/regression_tables/stage_2_regression_table.csv")
stage_3 <- read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression_2_(web_to_serviceable)/regression_tables/stage_3_regression_table.csv")

# %% [markdown]
# # infer values

# %%
predicted_scores_1 <- predict(fit_aic, newdata = stage_1)
stage_1$score <- predicted_scores_1
predicted_scores_2 <- predict(fit_aic, newdata = stage_2)
stage_2$score <- predicted_scores_2
predicted_scores_3 <- predict(fit_aic, newdata = stage_3)
stage_3$score <- predicted_scores_3

# %% [markdown]
# # scatter plots of score

# %%
options(repr.plot.width = 10, repr.plot.height = 6)
ggplot(stage_2, aes(x = log(Upload), y = score)) +
  geom_point(shape = 1, color = 'blue', size = 2) +  # shape = 1 for empty circles
  labs(title = "Scatter Plot of Upload vs. Score", 
       x = "Upload", 
       y = "Score") +
  theme_minimal()
  ggplot(stage_2, aes(x = Latency, y = score)) +
  geom_point(shape = 1, color = 'blue', size = 2) +  # shape = 1 for empty circles
  labs(title = "Scatter Plot of rtt vs. Score", 
       x = "Latency", 
       y = "Score") +
  theme_minimal()
# Out:
# plot without title
# plot without title

# %% [markdown]
# # density plots of score

# %%
# Assuming stage_1$score is populated with predictions
stage_1$score <- predict(fit_aic, newdata = stage_1)

# Create a density plot
ggplot(stage_1, aes(x = score)) +
  geom_density(fill = "blue", alpha = 0.7) +
  labs(title = "Density Plot of Predicted Scores", x = "Predicted Score", y = "Density") +
  theme_minimal()

ggplot(stage_2, aes(x = score)) +
  geom_density(fill = "blue", alpha = 0.7) +
  labs(title = "Density Plot of Predicted Scores", x = "Predicted Score", y = "Density") +
  theme_minimal()
# Out:
# plot without title
# plot without title

# %% [markdown]
# # model of inferred score to up/down/rtt

# %%
new_model1 <- lm(score ~ log(Upload) + log(Download) + Latency, data = stage_1)
new_model2 <- lm(score ~ log(Upload) + log(Download) + Latency, data = stage_2)
new_model3 <- lm(score ~ log(Upload_x) + log(Download_x) + Latency_x + log(Upload_y) + log(Download_y) + Latency_y, data = stage_3)

# %%
summary(new_model1)
summary(new_model2)
summary(new_model3)

par(bg = "white")  # set background color to white
options(repr.plot.width = 10, repr.plot.height = 6)
plot(stage_2$score, predict(new_model2, stage_2), xlim = c(0,1), ylim = c(0,1))

calculate_mse <- function(stage, model) {
    predictions <- predict(model, stage)
    mse <- mean((stage$score - predictions)^2)
    stage_name <- deparse(substitute(stage))
    return(paste(stage_name, mse, sep= " "))
}
calculate_mse(stage_1, new_model1)
calculate_mse(stage_2, new_model2)
calculate_mse(stage_3, new_model3)
# Out:
# Call:
# lm(formula = score ~ log(Upload) + log(Download) + Latency, data = stage_1)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.162349 -0.010435  0.001847  0.014808  0.112753
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)    5.045e-01  1.688e-02  29.886   <2e-16 ***
# log(Upload)    1.426e-02  1.171e-03  12.179   <2e-16 ***
# log(Download) -1.482e-03  1.471e-03  -1.007    0.315
# Latency       -1.020e-04  7.384e-06 -13.811   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.02897 on 295 degrees of freedom
# Multiple R-squared:  0.5349,	Adjusted R-squared:  0.5301
# F-statistic: 113.1 on 3 and 295 DF,  p-value: < 2.2e-16
# Call:
# lm(formula = score ~ log(Upload) + log(Download) + Latency, data = stage_2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.83122 -0.01985  0.01663  0.04326  0.19035
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)    3.948e-01  5.773e-02   6.838  4.8e-11 ***
# log(Upload)    3.804e-02  4.010e-03   9.485  < 2e-16 ***
# log(Download) -1.297e-02  5.019e-03  -2.584  0.01027 *
# Latency       -7.303e-05  2.512e-05  -2.907  0.00394 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.09777 on 288 degrees of freedom
# Multiple R-squared:  0.2672,	Adjusted R-squared:  0.2596
# F-statistic:    35 on 3 and 288 DF,  p-value: < 2.2e-16
# Call:
# lm(formula = score ~ log(Upload_x) + log(Download_x) + Latency_x +
#     log(Upload_y) + log(Download_y) + Latency_y, data = stage_3)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.307916 -0.015784  0.007391  0.024607  0.112650
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)      5.867e-01  3.531e-02  16.614  < 2e-16 ***
# log(Upload_x)    1.695e-03  1.801e-03   0.941    0.348
# log(Download_x) -2.551e-03  2.252e-03  -1.133    0.258
# Latency_x       -6.072e-05  1.156e-05  -5.251 2.96e-07 ***
# log(Upload_y)    9.237e-03  1.814e-03   5.092 6.42e-07 ***
# log(Download_y) -3.107e-03  2.263e-03  -1.373    0.171
# Latency_y       -5.983e-05  1.156e-05  -5.175 4.31e-07 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.04396 on 286 degrees of freedom
# Multiple R-squared:  0.2024,	Adjusted R-squared:  0.1857
# F-statistic:  12.1 on 6 and 286 DF,  p-value: 4.066e-12
# [1] "stage_1 0.000828049102429206"
# [1] "stage_2 0.00942725608596439"
# [1] "stage_3 0.00188638002554757"
# plot without title

# %% [markdown]
# # undo the logistic transform

# %%
transform_scores <- function(stage_data) {
  #ensure strictly between 0 and 1 to avoid undefined
  stage_data$score <- pmax(pmin(stage_data$score, 0.999), 0.001) 
  #apply logit transform to put back into normalised score form
  stage_data$real_score <-log(stage_data$score / (1 - stage_data$score))
  #then scale back up to 1-5
  stage_data$real_score_multiplied <- ((stage_data$real_score * 4) + 1)
  return(stage_data)
}
stage_1 <- transform_scores(stage_1)
stage_2 <- transform_scores(stage_2)
stage_3 <- transform_scores(stage_3)

# %% [markdown]
# # add a binary column that defines serviceability

# %%
create_binary_grouping <- function(stage_data) {
  stage_data$binary_col <- ifelse(stage_data$real_score_multiplied < 3, 0, 1)
  
  unserv_0 <- subset(stage_data, binary_col == 0)
  serv_1 <- subset(stage_data, binary_col == 1)
  
  unserv_0$group <- paste("UNSERV")
  serv_1$group <- paste("SERV")
  
  combined_data <- rbind(unserv_0, serv_1)
  return(combined_data)
}
#execute for each stage
combined_data1 <- create_binary_grouping(stage_1)
combined_data2 <- create_binary_grouping(stage_2)
combined_data3 <- create_binary_grouping(stage_3)

# %%
#show distribution of 0s and 1s
table(combined_data1$binary_col)
table(combined_data2$binary_col)
table(combined_data3$binary_col)
# Out:
#   0   1
# 295   4
#   0   1
# 263  29
#   0   1
# 270  23

# %%
install.packages("plotly")
install.packages("dplyr")
# Out:
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpaLzMFo/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpaLzMFo/downloaded_packages

# %% [markdown]
# # create factors for up and latency

# %%
create_factors <- function(data) {
    upload_levels <- c(500, 1000, 5000, 20000)
    latency_levels <-  c(100, 250, 400, 550, 750)
    download_levels <- c(2000, 5000, 12000, 25000, 50000)
    data$Upload_Factor <- factor(data$Upload, levels = upload_levels)
    data$Download_Factor <- factor(data$Download, levels = download_levels)
    data$Latency_Factor <- factor(data$Latency, levels = latency_levels)
  return(data)
}
combined_data1 <- create_factors(combined_data1)
combined_data2 <- create_factors(combined_data2)

create_factors3 <- function(data) {
    upload_levels <- c(500, 1000, 5000, 20000)
    latency_levels <-  c(100, 250, 400, 550, 750)
    download_levels <- c(2000, 5000, 12000, 25000, 50000)
    data$Upload_Factor_x <- factor(data$Upload_x, levels = upload_levels)
    data$Upload_Factor_y <- factor(data$Upload_y, levels = upload_levels)
    data$Latency_Factor_x <- factor(data$Latency_x, levels = latency_levels)
    data$Latency_Factor_y <- factor(data$Latency_y, levels = latency_levels)
    data$Download_Factor_x <- factor(data$Download_x, levels = download_levels)
    data$Download_Factor_y <- factor(data$Download_y, levels = download_levels)
  return(data)
}
combined_data3 <- create_factors3(combined_data3)

# %% [markdown]
# # Heat map

# %%
serv2 <-subset(combined_data2,binary_col == 1)
serv3 <- subset(combined_data3,binary_col == 1)
#serv2_wi <- subset(serv2, Latency ==750)
library(ggplot2)
total_points <- nrow(serv2)

# Create a heat map with proportions
ggplot(data = serv2, aes(x = Latency_Factor, y = Upload_Factor)) +
    stat_bin2d(bins = 30, aes(fill = ..count../total_points)) +  # Calculate proportion
    scale_fill_viridis_c(option = "plasma", labels = scales::percent) +  # Display as percentages
    labs(title = "Heat Map of Latency vs Upload Factor",
         x = "Latency (ms)",                       
         y = "Upload Factor (units)",              
         fill = "Proportion of Serviceable calls") +                    # Legend title showing proportion
    theme_minimal() +
    theme(panel.grid.major = element_blank(),
          panel.grid.minor = element_blank())
# Out:
# plot without title

# %% [markdown]
# # visualise Stages 1 and 2

# %%
library(ggplot2)

plot_grouped_stacked_bars <- function(data, stage_name) {
  custom_colors <- c("UNSERV" = "pink", "SERV" = "#61e861")
  options(repr.plot.width = 10, repr.plot.height = 6)

  # Plot for Latency Factor
  p1 <- ggplot(data, aes(x = Latency_Factor, fill = group)) +
    geom_bar(position = "fill") +  # Stacked bar with proportions
    labs(title = paste("Serviciability Distribution Amongst Latency Tiers", stage_name),
         x = "Latency [ms]",
         y = "Proportion of calls") +
    scale_y_continuous(labels = scales::percent) +  # Format y-axis as percentage
    scale_fill_manual(values = custom_colors) + 
    theme_minimal() +
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) 

  # Plot for Upload Factor
  p2 <- ggplot(data, aes(x = Upload_Factor, fill = group)) +
    geom_bar(position = "fill") +  # Stacked bar with proportions
    labs(title = paste("Serviciability Distribution Amongst Upload Speed Tiers", stage_name),
         x = "Upload Speed [bits/s]",
         y = "Proportion") +
    scale_y_continuous(labels = scales::percent) +
    scale_fill_manual(values = custom_colors) + 
    theme_minimal() +
    theme(axis.text.x = element_text(angle = 45, hjust = 1))

  #download
  p3 <- ggplot(data, aes(x = Download_Factor, fill = group)) +
    geom_bar(position = "fill") +  # Stacked bar with proportions
    labs(title = paste("Group disitrbution amongst Download", stage_name),
         x = "Download speed",
         y = "Proportion of calls") +
    scale_y_continuous(labels = scales::percent) +  # Format y-axis as percentage
    scale_fill_manual(values = custom_colors) + 
    theme_minimal() +
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) 

  return(list(latency_plot = p1, upload_plot = p2, download_plot =p3))
}

#make plots
plots_stage_1 <- plot_grouped_stacked_bars(combined_data1, "Stage 1")
plots_stage_2 <- plot_grouped_stacked_bars(combined_data2, "Stage 2")

#print plots
# print(plots_stage_1$latency_plot)
# print(plots_stage_1$upload_plot)

print(plots_stage_2$latency_plot)
print(plots_stage_2$upload_plot)
print(plots_stage_2$download_plot)
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# # Visualise Stage 3

# %%
library(ggplot2)

plot_stage_3 <- function(data, stage_name) {
  custom_colors <- c("UNSERV" = "pink", "SERV" = "#61e861")
  options(repr.plot.width = 10, repr.plot.height = 6)

  # Plot for Latency Factor
  p1 <- ggplot(data, aes(x = Latency_Factor_x, fill = group)) +
    geom_bar(position = "fill") +  # Stacked bar with proportions
    labs(title = paste("Serviceability against User 1's Latency", stage_name),
         x = "Latency user 1",
         y = "Proportion") +
    scale_y_continuous(labels = scales::percent) +  # Format y-axis as percentage
    scale_fill_manual(values = custom_colors) + 
    theme_minimal() +
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) 

p2 <- ggplot(data, aes(x = Latency_Factor_y, fill = group)) +
    geom_bar(position = "fill") +  # Stacked bar with proportions
    labs(title = paste("Serviceability against User 2's Latency", stage_name),
         x = "Latency user 2",
         y = "Proportion") +
    scale_y_continuous(labels = scales::percent) +  # Format y-axis as percentage
    scale_fill_manual(values = custom_colors) + 
    theme_minimal() +
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) 


  # Plot for Upload Factor
  p3 <- ggplot(data, aes(x = Upload_Factor_x, fill = group)) +
    geom_bar(position = "fill") +  # Stacked bar with proportions
    labs(title = paste("Serviceability against User 1 Upload", stage_name),
         x = "Upload user 1",
         y = "Proportion") +
    scale_y_continuous(labels = scales::percent) +
    scale_fill_manual(values = custom_colors) + 
    theme_minimal() +
    theme(axis.text.x = element_text(angle = 45, hjust = 1))

  p4 <- ggplot(data, aes(x = Upload_Factor_y, fill = group)) +
    geom_bar(position = "fill") +  # Stacked bar with proportions
    labs(title = paste("Serviceability against User 2 Upload", stage_name),
         x = "Upload user 2",
         y = "Proportion") +
    scale_y_continuous(labels = scales::percent) +
    scale_fill_manual(values = custom_colors) + 
    theme_minimal() +
    theme(axis.text.x = element_text(angle = 45, hjust = 1))

  return(list(latency_plot_x = p1,latency_plot_y = p2, upload_plot_x = p3, upload_plot_y = p4))
}

#make plots
plots_stage_3 <- plot_stage_3(combined_data3, "Stage 3")
print(plots_stage_3$latency_plot_x)
#print(plots_stage_3$latency_plot_y)
print(plots_stage_3$upload_plot_x)
#print(plots_stage_3$upload_plot_y)
# Out:
# plot without title
# plot without title
