# %%
install.packages("ggplot2")
install.packages("dplyr")
install.packages("caret")
install.packages("glmnet")
# Out:
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpsQrJEh/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpsQrJEh/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpsQrJEh/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpsQrJEh/downloaded_packages

# %%
library(dplyr)
library(glmnet)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: Matrix
#
# Loaded glmnet 4.1-8

# %% [markdown]
# # Import and format data

# %%
#read in the data
data <- read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression_2_(web_to_serviceable)/regression_tables/fieldwork_regression_table.csv")
data$scaled_score <- data$score_min/5
data$scaled_score <- pmax(pmin(data$scaled_score, 0.9999), 0.0001)
data$logistic_transformed_score <- log(data$scaled_score / (1 - data$scaled_score))
trim_data <- data %>% select(-identifier,-score_min, - scaled_score,  -serviceable_agg, -score_ellen, -score_aadya, -serviceable_ellen, -serviceable_aadya)

# %% [markdown]
# # Build a model

# %%
model <- lm(logistic_transformed_score ~ ., data = trim_data)
summary(model)
# Out:
# Call:
# lm(formula = logistic_transformed_score ~ ., data = trim_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.95765 -0.29883 -0.00502  0.22484  1.42456
#
# Coefficients: (3 not defined because of singularities)
#                                                      Estimate Std. Error
# (Intercept)                                         2.345e+00  2.592e+00
# IT01V_packetsRecieved_ellen                        -1.626e-03  6.398e-02
# IT01V_packetsRecieved_aadya                         7.237e-02  6.080e-02
# IT01V_packetsLost_ellen                            -1.201e-02  5.790e-02
# IT01V_packetsLost_aadya                             2.545e-03  2.947e-02
# IT01V_frameWidth_ellen                              1.712e-03  5.649e-03
# IT01V_frameWidth_aadya                             -2.546e-04  1.163e-03
# IT01V_frameHeight_ellen                                    NA         NA
# IT01V_frameHeight_aadya                                    NA         NA
# IT01V_totalFreezesDuration_ellen                    2.534e-01  2.793e-01
# IT01V_totalFreezesDuration_aadya                    2.272e-01  2.073e-01
# IT01V_framesPerSecond_ellen                        -6.502e-02  8.253e-02
# IT01V_framesPerSecond_aadya                        -6.704e-02  4.722e-02
# IT01V_bytesReceived_in_bits_s_ellen                 1.411e-07  7.338e-06
# IT01V_bytesReceived_in_bits_s_aadya                -7.126e-06  7.225e-06
# IT01V_totalProcessingDelay_ellen                    3.244e-02  9.418e-03
# IT01V_totalProcessingDelay_aadya                   -4.010e-03  5.560e-03
# IT01V_jitter_ellen                                  3.174e+00  2.563e+01
# IT01V_jitter_aadya                                 -1.912e+00  1.073e+01
# IT01V_jitterBufferDelay_emissions_ellen            -1.431e-02  4.316e-03
# IT01V_jitterBufferDelay_emissions_aadya             1.345e-03  2.107e-03
# IT01A_bytesReceived_in_bits_s_ellen                 9.072e-06  1.386e-05
# IT01A_bytesReceived_in_bits_s_aadya                 8.354e-06  1.521e-05
# IT01A_jitterBufferDelay_emissions_ellen            -4.009e-03  6.918e-04
# IT01A_jitterBufferDelay_emissions_aadya             1.770e-04  1.148e-03
# OT01V_packetsSent_s_ellen                          -3.801e-03  6.482e-02
# OT01V_packetsSent_s_aadya                           1.073e-01  7.683e-02
# OT01V_bytesSent_in_bits_s_ellen                     6.405e-08  7.376e-06
# OT01V_bytesSent_in_bits_s_aadya                    -1.072e-05  8.661e-06
# OT01V_frameWidth_ellen                                     NA         NA
# OT01V_frameWidth_aadya                             -1.485e-03  5.725e-03
# OT01V_framesPerSecond_ellen                         6.346e-02  4.610e-02
# OT01V_framesPerSecond_aadya                         2.375e-02  7.978e-02
# OT01V_totalPacketSendDelay_ellen                    2.589e-05  2.223e-03
# OT01V_totalPacketSendDelay_aadya                    5.220e-03  3.699e-03
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1.418e-03  1.530e-03
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  8.570e-04  1.426e-03
# RIV_roundTripTime_ellen                             7.058e+00  5.395e+00
# RIV_roundTripTime_aadya                             3.284e+00  3.674e+00
# RIV_fractionLost_ellen                              7.109e+00  3.941e+01
# RIV_fractionLost_aadya                              1.216e-01  3.024e+00
# RIA_fractionLost_ellen                             -3.945e-01  1.480e+00
# RIA_fractionLost_aadya                              1.639e+00  3.708e+00
# RIA_roundTripTime_ellen                             1.180e-03  3.867e-02
# RIA_roundTripTime_aadya                            -4.156e+00  4.717e+00
# ROA_roundTripTime_ellen                            -2.266e+00  5.113e+00
# ROA_roundTripTime_aadya                            -7.680e-01  1.630e+00
# AP_totalPlayoutDelay_ellen                         -5.970e-05  5.641e-05
# AP_totalPlayoutDelay_aadya                         -1.292e-05  2.842e-05
#                                                    t value Pr(>|t|)
# (Intercept)                                          0.905  0.37051
# IT01V_packetsRecieved_ellen                         -0.025  0.97984
# IT01V_packetsRecieved_aadya                          1.190  0.24034
# IT01V_packetsLost_ellen                             -0.207  0.83668
# IT01V_packetsLost_aadya                              0.086  0.93156
# IT01V_frameWidth_ellen                               0.303  0.76330
# IT01V_frameWidth_aadya                              -0.219  0.82775
# IT01V_frameHeight_ellen                                 NA       NA
# IT01V_frameHeight_aadya                                 NA       NA
# IT01V_totalFreezesDuration_ellen                     0.907  0.36915
# IT01V_totalFreezesDuration_aadya                     1.096  0.27909
# IT01V_framesPerSecond_ellen                         -0.788  0.43504
# IT01V_framesPerSecond_aadya                         -1.420  0.16274
# IT01V_bytesReceived_in_bits_s_ellen                  0.019  0.98474
# IT01V_bytesReceived_in_bits_s_aadya                 -0.986  0.32938
# IT01V_totalProcessingDelay_ellen                     3.445  0.00127 **
# IT01V_totalProcessingDelay_aadya                    -0.721  0.47461
# IT01V_jitter_ellen                                   0.124  0.90202
# IT01V_jitter_aadya                                  -0.178  0.85939
# IT01V_jitterBufferDelay_emissions_ellen             -3.315  0.00184 **
# IT01V_jitterBufferDelay_emissions_aadya              0.638  0.52650
# IT01A_bytesReceived_in_bits_s_ellen                  0.655  0.51616
# IT01A_bytesReceived_in_bits_s_aadya                  0.549  0.58572
# IT01A_jitterBufferDelay_emissions_ellen             -5.794 6.77e-07 ***
# IT01A_jitterBufferDelay_emissions_aadya              0.154  0.87822
# OT01V_packetsSent_s_ellen                           -0.059  0.95351
# OT01V_packetsSent_s_aadya                            1.397  0.16946
# OT01V_bytesSent_in_bits_s_ellen                      0.009  0.99311
# OT01V_bytesSent_in_bits_s_aadya                     -1.238  0.22221
# OT01V_frameWidth_ellen                                  NA       NA
# OT01V_frameWidth_aadya                              -0.259  0.79657
# OT01V_framesPerSecond_ellen                          1.377  0.17563
# OT01V_framesPerSecond_aadya                          0.298  0.76728
# OT01V_totalPacketSendDelay_ellen                     0.012  0.99076
# OT01V_totalPacketSendDelay_aadya                     1.411  0.16515
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen   0.927  0.35918
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya   0.601  0.55101
# RIV_roundTripTime_ellen                              1.308  0.19757
# RIV_roundTripTime_aadya                              0.894  0.37627
# RIV_fractionLost_ellen                               0.180  0.85767
# RIV_fractionLost_aadya                               0.040  0.96812
# RIA_fractionLost_ellen                              -0.267  0.79108
# RIA_fractionLost_aadya                               0.442  0.66062
# RIA_roundTripTime_ellen                              0.031  0.97580
# RIA_roundTripTime_aadya                             -0.881  0.38313
# ROA_roundTripTime_ellen                             -0.443  0.65987
# ROA_roundTripTime_aadya                             -0.471  0.63978
# AP_totalPlayoutDelay_ellen                          -1.058  0.29563
# AP_totalPlayoutDelay_aadya                          -0.455  0.65169
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.6622 on 44 degrees of freedom
# Multiple R-squared:  0.8455,	Adjusted R-squared:  0.6875
# F-statistic: 5.352 on 45 and 44 DF,  p-value: 6.953e-08

# %% [markdown]
# # Penalised regression

# %% [markdown]
# ## Lasso/ Ridge

# %%
X <- model.matrix(logistic_transformed_score ~ ., data = trim_data)[,-1]
y <- trim_data$logistic_transformed_score

# Fit the lasso model (alpha = 1 for Lasso)
lasso_model <- glmnet(X, y, alpha = 1)

# Predict on training data
lasso_predictions <- predict(lasso_model, X)

# Calculate MSE for lasso model
mse_lasso <- mean((y - lasso_predictions)^2)

# %%
# Fit the ridge model (alpha = 0)
ridge_model <- glmnet(X, y, alpha = 0)

# Predict on training data
ridge_predictions <- predict(ridge_model, X)

# Calculate MSE for lasso model
mse_ridge <- mean((y - ridge_predictions)^2)

# %% [markdown]
# ## AIC

# %%
fit_aic <- step(model)
summary(fit_aic)

aic_predictions <- predict(fit_aic, trim_data)
# par(bg = "white")
# options(repr.plot.width = 10, repr.plot.height = 6)
# plot(predictions, trim_data$logistic_transformed_score, 
#      main = "Prediction performance of AIC stepfit model", 
#      xlab = "Predicted values", ylab = "Recorded values")

# Calculate Mean Squared Error (MSE)
mse_aic <- mean((trim_data$logistic_transformed_score - aic_predictions)^2)
# Out:
# Start:  AIC=-46.6
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_frameHeight_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_ellen + IT01V_bytesReceived_in_bits_s_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitter_ellen + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=-46.6
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_frameHeight_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_ellen + IT01V_bytesReceived_in_bits_s_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitter_ellen + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=-46.6
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=-46.6
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq    RSS
# - OT01V_bytesSent_in_bits_s_ellen                     1    0.0000 19.295
# - OT01V_totalPacketSendDelay_ellen                    1    0.0001 19.295
# - IT01V_bytesReceived_in_bits_s_ellen                 1    0.0002 19.295
# - IT01V_packetsRecieved_ellen                         1    0.0003 19.295
# - RIA_roundTripTime_ellen                             1    0.0004 19.295
# - RIV_fractionLost_aadya                              1    0.0007 19.295
# - OT01V_packetsSent_s_ellen                           1    0.0015 19.296
# - IT01V_packetsLost_aadya                             1    0.0033 19.298
# - IT01V_jitter_ellen                                  1    0.0067 19.302
# - IT01A_jitterBufferDelay_emissions_aadya             1    0.0104 19.305
# - IT01V_jitter_aadya                                  1    0.0139 19.309
# - RIV_fractionLost_ellen                              1    0.0143 19.309
# - IT01V_packetsLost_ellen                             1    0.0189 19.314
# - IT01V_frameWidth_aadya                              1    0.0210 19.316
# - OT01V_frameWidth_aadya                              1    0.0295 19.324
# - RIA_fractionLost_ellen                              1    0.0312 19.326
# - OT01V_framesPerSecond_aadya                         1    0.0389 19.334
# - IT01V_frameWidth_ellen                              1    0.0403 19.335
# - RIA_fractionLost_aadya                              1    0.0857 19.380
# - ROA_roundTripTime_ellen                             1    0.0861 19.381
# - AP_totalPlayoutDelay_aadya                          1    0.0906 19.385
# - ROA_roundTripTime_aadya                             1    0.0974 19.392
# - IT01A_bytesReceived_in_bits_s_aadya                 1    0.1322 19.427
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    0.1583 19.453
# - IT01V_jitterBufferDelay_emissions_aadya             1    0.1787 19.474
# - IT01A_bytesReceived_in_bits_s_ellen                 1    0.1879 19.483
# - IT01V_totalProcessingDelay_aadya                    1    0.2281 19.523
# - IT01V_framesPerSecond_ellen                         1    0.2721 19.567
# - RIA_roundTripTime_aadya                             1    0.3403 19.635
# - RIV_roundTripTime_aadya                             1    0.3504 19.645
# - IT01V_totalFreezesDuration_ellen                    1    0.3610 19.656
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    0.3765 19.671
# - IT01V_bytesReceived_in_bits_s_aadya                 1    0.4266 19.721
# <none>                                                            19.295
# - AP_totalPlayoutDelay_ellen                          1    0.4913 19.786
# - IT01V_totalFreezesDuration_aadya                    1    0.5267 19.821
# - IT01V_packetsRecieved_aadya                         1    0.6212 19.916
# - OT01V_bytesSent_in_bits_s_aadya                     1    0.6723 19.967
# - RIV_roundTripTime_ellen                             1    0.7506 20.045
# - OT01V_framesPerSecond_ellen                         1    0.8309 20.126
# - OT01V_packetsSent_s_aadya                           1    0.8557 20.150
# - OT01V_totalPacketSendDelay_aadya                    1    0.8736 20.168
# - IT01V_framesPerSecond_aadya                         1    0.8838 20.179
# - IT01V_jitterBufferDelay_emissions_ellen             1    4.8200 24.115
# - IT01V_totalProcessingDelay_ellen                    1    5.2029 24.498
# - IT01A_jitterBufferDelay_emissions_ellen             1   14.7222 34.017
#                                                          AIC
# - OT01V_bytesSent_in_bits_s_ellen                    -48.598
# - OT01V_totalPacketSendDelay_ellen                   -48.597
# - IT01V_bytesReceived_in_bits_s_ellen                -48.597
# - IT01V_packetsRecieved_ellen                        -48.596
# - RIA_roundTripTime_ellen                            -48.596
# - RIV_fractionLost_aadya                             -48.594
# - OT01V_packetsSent_s_ellen                          -48.591
# - IT01V_packetsLost_aadya                            -48.583
# - IT01V_jitter_ellen                                 -48.566
# - IT01A_jitterBufferDelay_emissions_aadya            -48.549
# - IT01V_jitter_aadya                                 -48.533
# - RIV_fractionLost_ellen                             -48.531
# - IT01V_packetsLost_ellen                            -48.510
# - IT01V_frameWidth_aadya                             -48.500
# - OT01V_frameWidth_aadya                             -48.460
# - RIA_fractionLost_ellen                             -48.453
# - OT01V_framesPerSecond_aadya                        -48.417
# - IT01V_frameWidth_ellen                             -48.410
# - RIA_fractionLost_aadya                             -48.199
# - ROA_roundTripTime_ellen                            -48.197
# - AP_totalPlayoutDelay_aadya                         -48.176
# - ROA_roundTripTime_aadya                            -48.145
# - IT01A_bytesReceived_in_bits_s_aadya                -47.983
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -47.862
# - IT01V_jitterBufferDelay_emissions_aadya            -47.768
# - IT01A_bytesReceived_in_bits_s_ellen                -47.726
# - IT01V_totalProcessingDelay_aadya                   -47.540
# - IT01V_framesPerSecond_ellen                        -47.337
# - RIA_roundTripTime_aadya                            -47.024
# - RIV_roundTripTime_aadya                            -46.978
# - IT01V_totalFreezesDuration_ellen                   -46.929
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -46.858
# - IT01V_bytesReceived_in_bits_s_aadya                -46.630
# <none>                                               -46.598
# - AP_totalPlayoutDelay_ellen                         -46.335
# - IT01V_totalFreezesDuration_aadya                   -46.174
# - IT01V_packetsRecieved_aadya                        -45.746
# - OT01V_bytesSent_in_bits_s_aadya                    -45.515
# - RIV_roundTripTime_ellen                            -45.163
# - OT01V_framesPerSecond_ellen                        -44.803
# - OT01V_packetsSent_s_aadya                          -44.692
# - OT01V_totalPacketSendDelay_aadya                   -44.612
# - IT01V_framesPerSecond_aadya                        -44.567
# - IT01V_jitterBufferDelay_emissions_ellen            -28.529
# - IT01V_totalProcessingDelay_ellen                   -27.111
# - IT01A_jitterBufferDelay_emissions_ellen              2.435
#
# Step:  AIC=-48.6
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_aadya +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq    RSS
# - OT01V_totalPacketSendDelay_ellen                    1    0.0001 19.295
# - IT01V_bytesReceived_in_bits_s_ellen                 1    0.0001 19.295
# - IT01V_packetsRecieved_ellen                         1    0.0003 19.295
# - RIA_roundTripTime_ellen                             1    0.0005 19.295
# - RIV_fractionLost_aadya                              1    0.0008 19.296
# - IT01V_packetsLost_aadya                             1    0.0033 19.298
# - IT01V_jitter_ellen                                  1    0.0069 19.302
# - IT01A_jitterBufferDelay_emissions_aadya             1    0.0107 19.306
# - OT01V_packetsSent_s_ellen                           1    0.0129 19.308
# - IT01V_jitter_aadya                                  1    0.0142 19.309
# - RIV_fractionLost_ellen                              1    0.0160 19.311
# - IT01V_packetsLost_ellen                             1    0.0197 19.315
# - IT01V_frameWidth_aadya                              1    0.0222 19.317
# - OT01V_frameWidth_aadya                              1    0.0312 19.326
# - RIA_fractionLost_ellen                              1    0.0317 19.327
# - OT01V_framesPerSecond_aadya                         1    0.0429 19.338
# - IT01V_frameWidth_ellen                              1    0.0429 19.338
# - ROA_roundTripTime_ellen                             1    0.0861 19.381
# - RIA_fractionLost_aadya                              1    0.0898 19.385
# - ROA_roundTripTime_aadya                             1    0.0974 19.392
# - AP_totalPlayoutDelay_aadya                          1    0.0989 19.394
# - IT01A_bytesReceived_in_bits_s_aadya                 1    0.1361 19.431
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    0.1608 19.456
# - IT01V_jitterBufferDelay_emissions_aadya             1    0.1839 19.479
# - IT01A_bytesReceived_in_bits_s_ellen                 1    0.1918 19.487
# - IT01V_totalProcessingDelay_aadya                    1    0.2339 19.529
# - IT01V_framesPerSecond_ellen                         1    0.2894 19.584
# - RIA_roundTripTime_aadya                             1    0.3405 19.635
# - RIV_roundTripTime_aadya                             1    0.3505 19.645
# - IT01V_totalFreezesDuration_ellen                    1    0.3673 19.662
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    0.4259 19.721
# <none>                                                            19.295
# - IT01V_bytesReceived_in_bits_s_aadya                 1    0.4841 19.779
# - AP_totalPlayoutDelay_ellen                          1    0.4950 19.790
# - IT01V_totalFreezesDuration_aadya                    1    0.5272 19.822
# - IT01V_packetsRecieved_aadya                         1    0.6832 19.978
# - OT01V_bytesSent_in_bits_s_aadya                     1    0.6981 19.993
# - RIV_roundTripTime_ellen                             1    0.7527 20.048
# - OT01V_packetsSent_s_aadya                           1    0.8730 20.168
# - OT01V_totalPacketSendDelay_aadya                    1    0.8818 20.177
# - IT01V_framesPerSecond_aadya                         1    0.9190 20.214
# - OT01V_framesPerSecond_ellen                         1    1.0986 20.393
# - IT01V_jitterBufferDelay_emissions_ellen             1    4.8216 24.116
# - IT01V_totalProcessingDelay_ellen                    1    5.4882 24.783
# - IT01A_jitterBufferDelay_emissions_ellen             1   14.7233 34.018
#                                                          AIC
# - OT01V_totalPacketSendDelay_ellen                   -50.597
# - IT01V_bytesReceived_in_bits_s_ellen                -50.597
# - IT01V_packetsRecieved_ellen                        -50.596
# - RIA_roundTripTime_ellen                            -50.595
# - RIV_fractionLost_aadya                             -50.594
# - IT01V_packetsLost_aadya                            -50.582
# - IT01V_jitter_ellen                                 -50.565
# - IT01A_jitterBufferDelay_emissions_aadya            -50.548
# - OT01V_packetsSent_s_ellen                          -50.538
# - IT01V_jitter_aadya                                 -50.531
# - RIV_fractionLost_ellen                             -50.523
# - IT01V_packetsLost_ellen                            -50.506
# - IT01V_frameWidth_aadya                             -50.494
# - OT01V_frameWidth_aadya                             -50.452
# - RIA_fractionLost_ellen                             -50.450
# - OT01V_framesPerSecond_aadya                        -50.398
# - IT01V_frameWidth_ellen                             -50.398
# - ROA_roundTripTime_ellen                            -50.197
# - RIA_fractionLost_aadya                             -50.180
# - ROA_roundTripTime_aadya                            -50.144
# - AP_totalPlayoutDelay_aadya                         -50.137
# - IT01A_bytesReceived_in_bits_s_aadya                -49.965
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -49.851
# - IT01V_jitterBufferDelay_emissions_aadya            -49.744
# - IT01A_bytesReceived_in_bits_s_ellen                -49.707
# - IT01V_totalProcessingDelay_aadya                   -49.513
# - IT01V_framesPerSecond_ellen                        -49.258
# - RIA_roundTripTime_aadya                            -49.023
# - RIV_roundTripTime_aadya                            -48.977
# - IT01V_totalFreezesDuration_ellen                   -48.901
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -48.633
# <none>                                               -48.598
# - IT01V_bytesReceived_in_bits_s_aadya                -48.367
# - AP_totalPlayoutDelay_ellen                         -48.318
# - IT01V_totalFreezesDuration_aadya                   -48.172
# - IT01V_packetsRecieved_aadya                        -47.466
# - OT01V_bytesSent_in_bits_s_aadya                    -47.399
# - RIV_roundTripTime_ellen                            -47.153
# - OT01V_packetsSent_s_aadya                          -46.615
# - OT01V_totalPacketSendDelay_aadya                   -46.576
# - IT01V_framesPerSecond_aadya                        -46.410
# - OT01V_framesPerSecond_ellen                        -45.614
# - IT01V_jitterBufferDelay_emissions_ellen            -30.522
# - IT01V_totalProcessingDelay_ellen                   -28.069
# - IT01A_jitterBufferDelay_emissions_ellen              0.438
#
# Step:  AIC=-50.6
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_aadya +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya + RIV_roundTripTime_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIV_fractionLost_aadya +
#     RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_ellen +
#     RIA_roundTripTime_aadya + ROA_roundTripTime_ellen + ROA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq    RSS
# - IT01V_bytesReceived_in_bits_s_ellen                 1    0.0001 19.295
# - IT01V_packetsRecieved_ellen                         1    0.0003 19.295
# - RIA_roundTripTime_ellen                             1    0.0006 19.295
# - RIV_fractionLost_aadya                              1    0.0008 19.296
# - IT01V_packetsLost_aadya                             1    0.0037 19.299
# - IT01V_jitter_ellen                                  1    0.0070 19.302
# - IT01A_jitterBufferDelay_emissions_aadya             1    0.0108 19.306
# - OT01V_packetsSent_s_ellen                           1    0.0138 19.309
# - IT01V_jitter_aadya                                  1    0.0143 19.309
# - RIV_fractionLost_ellen                              1    0.0162 19.311
# - IT01V_packetsLost_ellen                             1    0.0199 19.315
# - IT01V_frameWidth_aadya                              1    0.0226 19.317
# - OT01V_frameWidth_aadya                              1    0.0315 19.326
# - RIA_fractionLost_ellen                              1    0.0328 19.328
# - OT01V_framesPerSecond_aadya                         1    0.0430 19.338
# - IT01V_frameWidth_ellen                              1    0.0433 19.338
# - ROA_roundTripTime_ellen                             1    0.0869 19.382
# - RIA_fractionLost_aadya                              1    0.0897 19.385
# - ROA_roundTripTime_aadya                             1    0.1003 19.395
# - AP_totalPlayoutDelay_aadya                          1    0.1005 19.395
# - IT01A_bytesReceived_in_bits_s_aadya                 1    0.1361 19.431
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    0.1627 19.458
# - IT01A_bytesReceived_in_bits_s_ellen                 1    0.1988 19.494
# - IT01V_jitterBufferDelay_emissions_aadya             1    0.2078 19.503
# - IT01V_totalProcessingDelay_aadya                    1    0.2367 19.532
# - IT01V_framesPerSecond_ellen                         1    0.2895 19.584
# - RIA_roundTripTime_aadya                             1    0.3406 19.635
# - RIV_roundTripTime_aadya                             1    0.3506 19.645
# - IT01V_totalFreezesDuration_ellen                    1    0.3675 19.662
# <none>                                                            19.295
# - AP_totalPlayoutDelay_ellen                          1    0.4982 19.793
# - IT01V_bytesReceived_in_bits_s_aadya                 1    0.5396 19.834
# - IT01V_totalFreezesDuration_aadya                    1    0.5490 19.844
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    0.6642 19.959
# - OT01V_bytesSent_in_bits_s_aadya                     1    0.6981 19.993
# - IT01V_packetsRecieved_aadya                         1    0.7296 20.024
# - RIV_roundTripTime_ellen                             1    0.7562 20.051
# - OT01V_packetsSent_s_aadya                           1    0.8730 20.168
# - OT01V_totalPacketSendDelay_aadya                    1    0.8844 20.179
# - IT01V_framesPerSecond_aadya                         1    0.9195 20.214
# - OT01V_framesPerSecond_ellen                         1    1.1011 20.396
# - IT01V_jitterBufferDelay_emissions_ellen             1    4.8450 24.140
# - IT01V_totalProcessingDelay_ellen                    1    5.5206 24.815
# - IT01A_jitterBufferDelay_emissions_ellen             1   15.3417 34.637
#                                                          AIC
# - IT01V_bytesReceived_in_bits_s_ellen                -52.597
# - IT01V_packetsRecieved_ellen                        -52.596
# - RIA_roundTripTime_ellen                            -52.595
# - RIV_fractionLost_aadya                             -52.594
# - IT01V_packetsLost_aadya                            -52.580
# - IT01V_jitter_ellen                                 -52.565
# - IT01A_jitterBufferDelay_emissions_aadya            -52.547
# - OT01V_packetsSent_s_ellen                          -52.533
# - IT01V_jitter_aadya                                 -52.531
# - RIV_fractionLost_ellen                             -52.522
# - IT01V_packetsLost_ellen                            -52.504
# - IT01V_frameWidth_aadya                             -52.492
# - OT01V_frameWidth_aadya                             -52.451
# - RIA_fractionLost_ellen                             -52.444
# - OT01V_framesPerSecond_aadya                        -52.397
# - IT01V_frameWidth_ellen                             -52.396
# - ROA_roundTripTime_ellen                            -52.193
# - RIA_fractionLost_aadya                             -52.180
# - ROA_roundTripTime_aadya                            -52.131
# - AP_totalPlayoutDelay_aadya                         -52.130
# - IT01A_bytesReceived_in_bits_s_aadya                -51.965
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -51.842
# - IT01A_bytesReceived_in_bits_s_ellen                -51.675
# - IT01V_jitterBufferDelay_emissions_aadya            -51.633
# - IT01V_totalProcessingDelay_aadya                   -51.500
# - IT01V_framesPerSecond_ellen                        -51.257
# - RIA_roundTripTime_aadya                            -51.022
# - RIV_roundTripTime_aadya                            -50.977
# - IT01V_totalFreezesDuration_ellen                   -50.899
# <none>                                               -50.597
# - AP_totalPlayoutDelay_ellen                         -50.303
# - IT01V_bytesReceived_in_bits_s_aadya                -50.115
# - IT01V_totalFreezesDuration_aadya                   -50.073
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -49.551
# - OT01V_bytesSent_in_bits_s_aadya                    -49.399
# - IT01V_packetsRecieved_aadya                        -49.257
# - RIV_roundTripTime_ellen                            -49.137
# - OT01V_packetsSent_s_aadya                          -48.615
# - OT01V_totalPacketSendDelay_aadya                   -48.564
# - IT01V_framesPerSecond_aadya                        -48.408
# - OT01V_framesPerSecond_ellen                        -47.603
# - IT01V_jitterBufferDelay_emissions_ellen            -32.435
# - IT01V_totalProcessingDelay_ellen                   -29.951
# - IT01A_jitterBufferDelay_emissions_ellen              0.059
#
# Step:  AIC=-52.6
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitter_ellen + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_aadya +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya + RIV_roundTripTime_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIV_fractionLost_aadya +
#     RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_ellen +
#     RIA_roundTripTime_aadya + ROA_roundTripTime_ellen + ROA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq    RSS
# - IT01V_packetsRecieved_ellen                         1    0.0004 19.295
# - RIA_roundTripTime_ellen                             1    0.0005 19.296
# - RIV_fractionLost_aadya                              1    0.0008 19.296
# - IT01V_packetsLost_aadya                             1    0.0036 19.299
# - IT01V_jitter_ellen                                  1    0.0072 19.302
# - IT01A_jitterBufferDelay_emissions_aadya             1    0.0113 19.306
# - OT01V_packetsSent_s_ellen                           1    0.0137 19.309
# - IT01V_jitter_aadya                                  1    0.0142 19.309
# - RIV_fractionLost_ellen                              1    0.0164 19.311
# - IT01V_packetsLost_ellen                             1    0.0198 19.315
# - IT01V_frameWidth_aadya                              1    0.0226 19.318
# - RIA_fractionLost_ellen                              1    0.0327 19.328
# - OT01V_frameWidth_aadya                              1    0.0359 19.331
# - OT01V_framesPerSecond_aadya                         1    0.0467 19.342
# - IT01V_frameWidth_ellen                              1    0.0520 19.347
# - RIA_fractionLost_aadya                              1    0.0900 19.385
# - ROA_roundTripTime_ellen                             1    0.0901 19.385
# - AP_totalPlayoutDelay_aadya                          1    0.1003 19.395
# - ROA_roundTripTime_aadya                             1    0.1004 19.395
# - IT01A_bytesReceived_in_bits_s_aadya                 1    0.1364 19.431
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    0.1858 19.481
# - IT01A_bytesReceived_in_bits_s_ellen                 1    0.2030 19.498
# - IT01V_jitterBufferDelay_emissions_aadya             1    0.2077 19.503
# - IT01V_totalProcessingDelay_aadya                    1    0.2367 19.532
# - IT01V_framesPerSecond_ellen                         1    0.2982 19.593
# - RIA_roundTripTime_aadya                             1    0.3408 19.636
# - RIV_roundTripTime_aadya                             1    0.3508 19.646
# - IT01V_totalFreezesDuration_ellen                    1    0.3738 19.669
# <none>                                                            19.295
# - AP_totalPlayoutDelay_ellen                          1    0.5098 19.805
# - IT01V_totalFreezesDuration_aadya                    1    0.5491 19.844
# - IT01V_bytesReceived_in_bits_s_aadya                 1    0.5494 19.844
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    0.6662 19.961
# - OT01V_bytesSent_in_bits_s_aadya                     1    0.7168 20.012
# - IT01V_packetsRecieved_aadya                         1    0.7353 20.030
# - RIV_roundTripTime_ellen                             1    0.7624 20.057
# - OT01V_packetsSent_s_aadya                           1    0.8865 20.182
# - OT01V_totalPacketSendDelay_aadya                    1    0.8930 20.188
# - IT01V_framesPerSecond_aadya                         1    0.9239 20.219
# - OT01V_framesPerSecond_ellen                         1    1.1089 20.404
# - IT01V_jitterBufferDelay_emissions_ellen             1    4.8899 24.185
# - IT01V_totalProcessingDelay_ellen                    1    5.5494 24.844
# - IT01A_jitterBufferDelay_emissions_ellen             1   15.4053 34.700
#                                                          AIC
# - IT01V_packetsRecieved_ellen                        -54.595
# - RIA_roundTripTime_ellen                            -54.594
# - RIV_fractionLost_aadya                             -54.593
# - IT01V_packetsLost_aadya                            -54.580
# - IT01V_jitter_ellen                                 -54.563
# - IT01A_jitterBufferDelay_emissions_aadya            -54.544
# - OT01V_packetsSent_s_ellen                          -54.533
# - IT01V_jitter_aadya                                 -54.531
# - RIV_fractionLost_ellen                             -54.520
# - IT01V_packetsLost_ellen                            -54.504
# - IT01V_frameWidth_aadya                             -54.492
# - RIA_fractionLost_ellen                             -54.444
# - OT01V_frameWidth_aadya                             -54.429
# - OT01V_framesPerSecond_aadya                        -54.379
# - IT01V_frameWidth_ellen                             -54.354
# - RIA_fractionLost_aadya                             -54.178
# - ROA_roundTripTime_ellen                            -54.178
# - AP_totalPlayoutDelay_aadya                         -54.130
# - ROA_roundTripTime_aadya                            -54.130
# - IT01A_bytesReceived_in_bits_s_aadya                -53.963
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -53.734
# - IT01A_bytesReceived_in_bits_s_ellen                -53.655
# - IT01V_jitterBufferDelay_emissions_aadya            -53.633
# - IT01V_totalProcessingDelay_aadya                   -53.499
# - IT01V_framesPerSecond_ellen                        -53.216
# - RIA_roundTripTime_aadya                            -53.021
# - RIV_roundTripTime_aadya                            -52.975
# - IT01V_totalFreezesDuration_ellen                   -52.870
# <none>                                               -52.597
# - AP_totalPlayoutDelay_ellen                         -52.250
# - IT01V_totalFreezesDuration_aadya                   -52.071
# - IT01V_bytesReceived_in_bits_s_aadya                -52.070
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -51.542
# - OT01V_bytesSent_in_bits_s_aadya                    -51.314
# - IT01V_packetsRecieved_aadya                        -51.231
# - RIV_roundTripTime_ellen                            -51.109
# - OT01V_packetsSent_s_aadya                          -50.554
# - OT01V_totalPacketSendDelay_aadya                   -50.525
# - IT01V_framesPerSecond_aadya                        -50.387
# - OT01V_framesPerSecond_ellen                        -49.568
# - IT01V_jitterBufferDelay_emissions_ellen            -34.267
# - IT01V_totalProcessingDelay_ellen                   -31.846
# - IT01A_jitterBufferDelay_emissions_ellen             -1.775
#
# Step:  AIC=-54.6
# logistic_transformed_score ~ IT01V_packetsRecieved_aadya + IT01V_packetsLost_ellen +
#     IT01V_packetsLost_aadya + IT01V_frameWidth_ellen + IT01V_frameWidth_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_aadya +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya + RIV_roundTripTime_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIV_fractionLost_aadya +
#     RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_ellen +
#     RIA_roundTripTime_aadya + ROA_roundTripTime_ellen + ROA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq    RSS
# - RIA_roundTripTime_ellen                             1    0.0006 19.296
# - RIV_fractionLost_aadya                              1    0.0008 19.296
# - IT01V_packetsLost_aadya                             1    0.0035 19.299
# - IT01V_jitter_ellen                                  1    0.0070 19.302
# - IT01A_jitterBufferDelay_emissions_aadya             1    0.0131 19.308
# - IT01V_jitter_aadya                                  1    0.0138 19.309
# - OT01V_packetsSent_s_ellen                           1    0.0156 19.311
# - RIV_fractionLost_ellen                              1    0.0161 19.311
# - IT01V_packetsLost_ellen                             1    0.0208 19.316
# - IT01V_frameWidth_aadya                              1    0.0247 19.320
# - RIA_fractionLost_ellen                              1    0.0327 19.328
# - OT01V_frameWidth_aadya                              1    0.0369 19.332
# - OT01V_framesPerSecond_aadya                         1    0.0520 19.347
# - IT01V_frameWidth_ellen                              1    0.0545 19.350
# - RIA_fractionLost_aadya                              1    0.0906 19.386
# - ROA_roundTripTime_ellen                             1    0.0913 19.387
# - AP_totalPlayoutDelay_aadya                          1    0.1006 19.396
# - ROA_roundTripTime_aadya                             1    0.1074 19.403
# - IT01A_bytesReceived_in_bits_s_aadya                 1    0.1381 19.433
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    0.1870 19.482
# - IT01A_bytesReceived_in_bits_s_ellen                 1    0.2041 19.499
# - IT01V_jitterBufferDelay_emissions_aadya             1    0.2081 19.504
# - IT01V_totalProcessingDelay_aadya                    1    0.2408 19.536
# - IT01V_framesPerSecond_ellen                         1    0.3300 19.625
# - RIA_roundTripTime_aadya                             1    0.3426 19.638
# - RIV_roundTripTime_aadya                             1    0.3527 19.648
# - IT01V_totalFreezesDuration_ellen                    1    0.4177 19.713
# <none>                                                            19.295
# - AP_totalPlayoutDelay_ellen                          1    0.5109 19.806
# - IT01V_bytesReceived_in_bits_s_aadya                 1    0.5518 19.847
# - IT01V_totalFreezesDuration_aadya                    1    0.5537 19.849
# - OT01V_bytesSent_in_bits_s_aadya                     1    0.7317 20.027
# - IT01V_packetsRecieved_aadya                         1    0.7354 20.031
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    0.7491 20.044
# - RIV_roundTripTime_ellen                             1    0.7954 20.091
# - OT01V_packetsSent_s_aadya                           1    0.8888 20.184
# - OT01V_totalPacketSendDelay_aadya                    1    0.9088 20.204
# - IT01V_framesPerSecond_aadya                         1    0.9687 20.264
# - OT01V_framesPerSecond_ellen                         1    1.1625 20.458
# - IT01V_jitterBufferDelay_emissions_ellen             1    5.0880 24.383
# - IT01V_totalProcessingDelay_ellen                    1    5.7109 25.006
# - IT01A_jitterBufferDelay_emissions_ellen             1   15.6827 34.978
#                                                          AIC
# - RIA_roundTripTime_ellen                            -56.592
# - RIV_fractionLost_aadya                             -56.591
# - IT01V_packetsLost_aadya                            -56.579
# - IT01V_jitter_ellen                                 -56.563
# - IT01A_jitterBufferDelay_emissions_aadya            -56.534
# - IT01V_jitter_aadya                                 -56.531
# - OT01V_packetsSent_s_ellen                          -56.522
# - RIV_fractionLost_ellen                             -56.520
# - IT01V_packetsLost_ellen                            -56.498
# - IT01V_frameWidth_aadya                             -56.480
# - RIA_fractionLost_ellen                             -56.443
# - OT01V_frameWidth_aadya                             -56.423
# - OT01V_framesPerSecond_aadya                        -56.353
# - IT01V_frameWidth_ellen                             -56.341
# - RIA_fractionLost_aadya                             -56.174
# - ROA_roundTripTime_ellen                            -56.170
# - AP_totalPlayoutDelay_aadya                         -56.127
# - ROA_roundTripTime_aadya                            -56.095
# - IT01A_bytesReceived_in_bits_s_aadya                -55.953
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -55.727
# - IT01A_bytesReceived_in_bits_s_ellen                -55.648
# - IT01V_jitterBufferDelay_emissions_aadya            -55.629
# - IT01V_totalProcessingDelay_aadya                   -55.479
# - IT01V_framesPerSecond_ellen                        -55.069
# - RIA_roundTripTime_aadya                            -55.011
# - RIV_roundTripTime_aadya                            -54.965
# - IT01V_totalFreezesDuration_ellen                   -54.667
# <none>                                               -54.595
# - AP_totalPlayoutDelay_ellen                         -54.243
# - IT01V_bytesReceived_in_bits_s_aadya                -54.057
# - IT01V_totalFreezesDuration_aadya                   -54.049
# - OT01V_bytesSent_in_bits_s_aadya                    -53.245
# - IT01V_packetsRecieved_aadya                        -53.229
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -53.167
# - RIV_roundTripTime_ellen                            -52.960
# - OT01V_packetsSent_s_aadya                          -52.542
# - OT01V_totalPacketSendDelay_aadya                   -52.453
# - IT01V_framesPerSecond_aadya                        -52.186
# - OT01V_framesPerSecond_ellen                        -51.330
# - IT01V_jitterBufferDelay_emissions_ellen            -35.532
# - IT01V_totalProcessingDelay_ellen                   -33.261
# - IT01A_jitterBufferDelay_emissions_ellen             -3.058
#
# Step:  AIC=-56.59
# logistic_transformed_score ~ IT01V_packetsRecieved_aadya + IT01V_packetsLost_ellen +
#     IT01V_packetsLost_aadya + IT01V_frameWidth_ellen + IT01V_frameWidth_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_aadya +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya + RIV_roundTripTime_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIV_fractionLost_aadya +
#     RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_aadya +
#     ROA_roundTripTime_ellen + ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen +
#     AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq    RSS
# - RIV_fractionLost_aadya                              1    0.0009 19.297
# - IT01V_packetsLost_aadya                             1    0.0035 19.300
# - IT01V_jitter_ellen                                  1    0.0065 19.303
# - IT01A_jitterBufferDelay_emissions_aadya             1    0.0131 19.309
# - IT01V_jitter_aadya                                  1    0.0141 19.310
# - OT01V_packetsSent_s_ellen                           1    0.0156 19.312
# - RIV_fractionLost_ellen                              1    0.0157 19.312
# - IT01V_packetsLost_ellen                             1    0.0206 19.317
# - IT01V_frameWidth_aadya                              1    0.0246 19.321
# - RIA_fractionLost_ellen                              1    0.0323 19.328
# - OT01V_frameWidth_aadya                              1    0.0370 19.333
# - IT01V_frameWidth_ellen                              1    0.0546 19.351
# - OT01V_framesPerSecond_aadya                         1    0.0566 19.353
# - RIA_fractionLost_aadya                              1    0.0921 19.388
# - ROA_roundTripTime_ellen                             1    0.0935 19.389
# - AP_totalPlayoutDelay_aadya                          1    0.1004 19.396
# - ROA_roundTripTime_aadya                             1    0.1069 19.403
# - IT01A_bytesReceived_in_bits_s_aadya                 1    0.1374 19.433
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    0.1871 19.483
# - IT01V_jitterBufferDelay_emissions_aadya             1    0.2088 19.505
# - IT01A_bytesReceived_in_bits_s_ellen                 1    0.2142 19.510
# - IT01V_totalProcessingDelay_aadya                    1    0.2421 19.538
# - RIA_roundTripTime_aadya                             1    0.3447 19.641
# - RIV_roundTripTime_aadya                             1    0.3549 19.651
# - IT01V_framesPerSecond_ellen                         1    0.3569 19.653
# - IT01V_totalFreezesDuration_ellen                    1    0.4171 19.713
# <none>                                                            19.296
# - AP_totalPlayoutDelay_ellen                          1    0.5205 19.816
# - IT01V_bytesReceived_in_bits_s_aadya                 1    0.5512 19.847
# - IT01V_totalFreezesDuration_aadya                    1    0.5536 19.850
# - OT01V_bytesSent_in_bits_s_aadya                     1    0.7312 20.027
# - IT01V_packetsRecieved_aadya                         1    0.7353 20.031
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    0.7493 20.045
# - RIV_roundTripTime_ellen                             1    0.7953 20.091
# - OT01V_packetsSent_s_aadya                           1    0.8886 20.185
# - OT01V_totalPacketSendDelay_aadya                    1    0.9097 20.206
# - IT01V_framesPerSecond_aadya                         1    0.9704 20.266
# - OT01V_framesPerSecond_ellen                         1    1.2496 20.546
# - IT01V_jitterBufferDelay_emissions_ellen             1    5.0900 24.386
# - IT01V_totalProcessingDelay_ellen                    1    5.7259 25.022
# - IT01A_jitterBufferDelay_emissions_ellen             1   15.6834 34.979
#                                                          AIC
# - RIV_fractionLost_aadya                             -58.588
# - IT01V_packetsLost_aadya                            -58.576
# - IT01V_jitter_ellen                                 -58.562
# - IT01A_jitterBufferDelay_emissions_aadya            -58.531
# - IT01V_jitter_aadya                                 -58.526
# - OT01V_packetsSent_s_ellen                          -58.519
# - RIV_fractionLost_ellen                             -58.519
# - IT01V_packetsLost_ellen                            -58.496
# - IT01V_frameWidth_aadya                             -58.477
# - RIA_fractionLost_ellen                             -58.442
# - OT01V_frameWidth_aadya                             -58.420
# - IT01V_frameWidth_ellen                             -58.338
# - OT01V_framesPerSecond_aadya                        -58.329
# - RIA_fractionLost_aadya                             -58.163
# - ROA_roundTripTime_ellen                            -58.157
# - AP_totalPlayoutDelay_aadya                         -58.125
# - ROA_roundTripTime_aadya                            -58.095
# ...
#
# Step:  AIC=-87.07
# logistic_transformed_score ~ IT01V_packetsRecieved_aadya + IT01V_frameWidth_ellen +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_aadya +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIA_fractionLost_aadya +
#     RIA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq    RSS
# - IT01V_frameWidth_ellen                              1    0.2051 20.723
# - OT01V_frameWidth_aadya                              1    0.2131 20.731
# <none>                                                            20.518
# - RIA_fractionLost_aadya                              1    0.5466 21.064
# - IT01V_framesPerSecond_ellen                         1    0.6589 21.177
# - IT01V_totalFreezesDuration_ellen                    1    1.0025 21.520
# - OT01V_bytesSent_in_bits_s_aadya                     1    1.1431 21.661
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    1.3108 21.829
# - OT01V_packetsSent_s_aadya                           1    1.3795 21.897
# - RIV_roundTripTime_ellen                             1    1.3861 21.904
# - IT01V_framesPerSecond_aadya                         1    1.4231 21.941
# - IT01V_bytesReceived_in_bits_s_aadya                 1    1.5487 22.066
# - IT01V_packetsRecieved_aadya                         1    1.5731 22.091
# - IT01V_totalFreezesDuration_aadya                    1    1.7238 22.241
# - OT01V_totalPacketSendDelay_aadya                    1    1.7521 22.270
# - OT01V_framesPerSecond_ellen                         1    2.1470 22.665
# - RIA_roundTripTime_aadya                             1    2.1689 22.687
# - RIV_roundTripTime_aadya                             1    2.2033 22.721
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    2.8286 23.346
# - AP_totalPlayoutDelay_ellen                          1    3.7525 24.270
# - IT01V_totalProcessingDelay_ellen                    1   10.2853 30.803
# - IT01V_jitterBufferDelay_emissions_ellen             1   12.9858 33.503
# - IT01A_jitterBufferDelay_emissions_ellen             1   28.7370 49.255
#                                                          AIC
# - IT01V_frameWidth_ellen                             -88.172
# - OT01V_frameWidth_aadya                             -88.137
# <none>                                               -87.067
# - RIA_fractionLost_aadya                             -86.701
# - IT01V_framesPerSecond_ellen                        -86.222
# - IT01V_totalFreezesDuration_ellen                   -84.774
# - OT01V_bytesSent_in_bits_s_aadya                    -84.187
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -83.493
# - OT01V_packetsSent_s_aadya                          -83.211
# - RIV_roundTripTime_ellen                            -83.184
# - IT01V_framesPerSecond_aadya                        -83.032
# - IT01V_bytesReceived_in_bits_s_aadya                -82.518
# - IT01V_packetsRecieved_aadya                        -82.418
# - IT01V_totalFreezesDuration_aadya                   -81.807
# - OT01V_totalPacketSendDelay_aadya                   -81.692
# - OT01V_framesPerSecond_ellen                        -80.110
# - RIA_roundTripTime_aadya                            -80.023
# - RIV_roundTripTime_aadya                            -79.887
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -77.443
# - AP_totalPlayoutDelay_ellen                         -73.951
# - IT01V_totalProcessingDelay_ellen                   -52.498
# - IT01V_jitterBufferDelay_emissions_ellen            -44.934
# - IT01A_jitterBufferDelay_emissions_ellen            -10.252
#
# Step:  AIC=-88.17
# logistic_transformed_score ~ IT01V_packetsRecieved_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_ellen + OT01V_packetsSent_s_aadya +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIA_fractionLost_aadya +
#     RIA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq    RSS
# - OT01V_frameWidth_aadya                              1    0.0082 20.731
# <none>                                                            20.723
# - RIA_fractionLost_aadya                              1    0.5704 21.293
# - IT01V_framesPerSecond_ellen                         1    0.7558 21.479
# - IT01V_totalFreezesDuration_ellen                    1    0.9657 21.688
# - OT01V_bytesSent_in_bits_s_aadya                     1    1.1694 21.892
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    1.2023 21.925
# - IT01V_bytesReceived_in_bits_s_aadya                 1    1.3834 22.106
# - IT01V_framesPerSecond_aadya                         1    1.3905 22.113
# - IT01V_packetsRecieved_aadya                         1    1.4013 22.124
# - OT01V_packetsSent_s_aadya                           1    1.4291 22.152
# - IT01V_totalFreezesDuration_aadya                    1    1.5754 22.298
# - RIV_roundTripTime_ellen                             1    1.5867 22.310
# - OT01V_totalPacketSendDelay_aadya                    1    1.9302 22.653
# - OT01V_framesPerSecond_ellen                         1    2.1986 22.921
# - RIA_roundTripTime_aadya                             1    2.4246 23.147
# - RIV_roundTripTime_aadya                             1    2.4643 23.187
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    2.8154 23.538
# - AP_totalPlayoutDelay_ellen                          1    3.7410 24.464
# - IT01V_totalProcessingDelay_ellen                    1   10.6264 31.349
# - IT01V_jitterBufferDelay_emissions_ellen             1   13.3719 34.095
# - IT01A_jitterBufferDelay_emissions_ellen             1   28.5606 49.283
#                                                          AIC
# - OT01V_frameWidth_aadya                             -90.136
# <none>                                               -88.172
# - RIA_fractionLost_aadya                             -87.728
# - IT01V_framesPerSecond_ellen                        -86.948
# - IT01V_totalFreezesDuration_ellen                   -86.073
# - OT01V_bytesSent_in_bits_s_aadya                    -85.231
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -85.096
# - IT01V_bytesReceived_in_bits_s_aadya                -84.356
# - IT01V_framesPerSecond_aadya                        -84.327
# - IT01V_packetsRecieved_aadya                        -84.283
# - OT01V_packetsSent_s_aadya                          -84.170
# - IT01V_totalFreezesDuration_aadya                   -83.578
# - RIV_roundTripTime_ellen                            -83.532
# - OT01V_totalPacketSendDelay_aadya                   -82.157
# - OT01V_framesPerSecond_ellen                        -81.096
# - RIA_roundTripTime_aadya                            -80.213
# - RIV_roundTripTime_aadya                            -80.059
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -78.707
# - AP_totalPlayoutDelay_ellen                         -75.235
# - IT01V_totalProcessingDelay_ellen                   -52.916
# - IT01V_jitterBufferDelay_emissions_ellen            -45.360
# - IT01A_jitterBufferDelay_emissions_ellen            -12.200
#
# Step:  AIC=-90.14
# logistic_transformed_score ~ IT01V_packetsRecieved_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_ellen + OT01V_packetsSent_s_aadya +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_framesPerSecond_ellen +
#     OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya + RIV_roundTripTime_ellen +
#     RIV_roundTripTime_aadya + RIA_fractionLost_aadya + RIA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq    RSS
# <none>                                                            20.731
# - RIA_fractionLost_aadya                              1    0.5742 21.305
# - IT01V_framesPerSecond_ellen                         1    0.7906 21.522
# - IT01V_totalFreezesDuration_ellen                    1    1.0353 21.766
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    1.1942 21.925
# - OT01V_bytesSent_in_bits_s_aadya                     1    1.2496 21.981
# - IT01V_bytesReceived_in_bits_s_aadya                 1    1.3753 22.106
# - IT01V_packetsRecieved_aadya                         1    1.3933 22.124
# - IT01V_framesPerSecond_aadya                         1    1.3976 22.129
# - OT01V_packetsSent_s_aadya                           1    1.4621 22.193
# - IT01V_totalFreezesDuration_aadya                    1    1.5692 22.300
# - RIV_roundTripTime_ellen                             1    1.5965 22.327
# - OT01V_totalPacketSendDelay_aadya                    1    1.9308 22.662
# - OT01V_framesPerSecond_ellen                         1    2.2121 22.943
# - RIA_roundTripTime_aadya                             1    2.4394 23.170
# - RIV_roundTripTime_aadya                             1    2.4793 23.210
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    2.8142 23.545
# - AP_totalPlayoutDelay_ellen                          1    4.0646 24.796
# - IT01V_totalProcessingDelay_ellen                    1   12.7506 33.482
# - IT01V_jitterBufferDelay_emissions_ellen             1   14.0131 34.744
# - IT01A_jitterBufferDelay_emissions_ellen             1   28.8558 49.587
#                                                          AIC
# <none>                                               -90.136
# - RIA_fractionLost_aadya                             -89.678
# - IT01V_framesPerSecond_ellen                        -88.768
# - IT01V_totalFreezesDuration_ellen                   -87.750
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -87.096
# - OT01V_bytesSent_in_bits_s_aadya                    -86.869
# - IT01V_bytesReceived_in_bits_s_aadya                -86.356
# - IT01V_packetsRecieved_aadya                        -86.282
# - IT01V_framesPerSecond_aadya                        -86.265
# - OT01V_packetsSent_s_aadya                          -86.002
# - IT01V_totalFreezesDuration_aadya                   -85.569
# - RIV_roundTripTime_ellen                            -85.459
# - OT01V_totalPacketSendDelay_aadya                   -84.122
# - OT01V_framesPerSecond_ellen                        -83.011
# - RIA_roundTripTime_aadya                            -82.124
# - RIV_roundTripTime_aadya                            -81.969
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -80.680
# - AP_totalPlayoutDelay_ellen                         -76.023
# - IT01V_totalProcessingDelay_ellen                   -48.993
# - IT01V_jitterBufferDelay_emissions_ellen            -45.662
# - IT01A_jitterBufferDelay_emissions_ellen            -13.648
# Call:
# lm(formula = logistic_transformed_score ~ IT01V_packetsRecieved_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIA_fractionLost_aadya +
#     RIA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen, data = trim_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.93527 -0.32707 -0.01506  0.31279  1.56469
#
# Coefficients:
#                                                      Estimate Std. Error
# (Intercept)                                         2.752e+00  1.510e+00
# IT01V_packetsRecieved_aadya                         7.421e-02  3.446e-02
# IT01V_totalFreezesDuration_ellen                    2.497e-01  1.345e-01
# IT01V_totalFreezesDuration_aadya                    2.332e-01  1.021e-01
# IT01V_framesPerSecond_ellen                        -3.146e-02  1.939e-02
# IT01V_framesPerSecond_aadya                        -5.686e-02  2.636e-02
# IT01V_bytesReceived_in_bits_s_aadya                -8.014e-06  3.746e-06
# IT01V_totalProcessingDelay_ellen                    3.173e-02  4.871e-03
# IT01V_jitterBufferDelay_emissions_ellen            -1.361e-02  1.992e-03
# IT01A_jitterBufferDelay_emissions_ellen            -4.053e-03  4.136e-04
# OT01V_packetsSent_s_aadya                           9.438e-02  4.278e-02
# OT01V_bytesSent_in_bits_s_aadya                    -9.325e-06  4.573e-06
# OT01V_framesPerSecond_ellen                         6.387e-02  2.354e-02
# OT01V_totalPacketSendDelay_aadya                    4.584e-03  1.808e-03
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1.441e-03  4.710e-04
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1.206e-03  6.047e-04
# RIV_roundTripTime_ellen                             4.878e+00  2.116e+00
# RIV_roundTripTime_aadya                             4.696e+00  1.635e+00
# RIA_fractionLost_aadya                              2.887e+00  2.089e+00
# RIA_roundTripTime_aadya                            -5.973e+00  2.096e+00
# AP_totalPlayoutDelay_ellen                         -9.009e-05  2.449e-05
#                                                    t value Pr(>|t|)
# (Intercept)                                          1.823 0.072597 .
# IT01V_packetsRecieved_aadya                          2.153 0.034777 *
# IT01V_totalFreezesDuration_ellen                     1.856 0.067685 .
# IT01V_totalFreezesDuration_aadya                     2.285 0.025370 *
# IT01V_framesPerSecond_ellen                         -1.622 0.109328
# IT01V_framesPerSecond_aadya                         -2.157 0.034508 *
# IT01V_bytesReceived_in_bits_s_aadya                 -2.139 0.035937 *
# IT01V_totalProcessingDelay_ellen                     6.514 9.97e-09 ***
# IT01V_jitterBufferDelay_emissions_ellen             -6.829 2.71e-09 ***
# IT01A_jitterBufferDelay_emissions_ellen             -9.800 1.07e-14 ***
# OT01V_packetsSent_s_aadya                            2.206 0.030715 *
# OT01V_bytesSent_in_bits_s_aadya                     -2.039 0.045245 *
# OT01V_framesPerSecond_ellen                          2.713 0.008403 **
# OT01V_totalPacketSendDelay_aadya                     2.535 0.013514 *
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen   3.060 0.003147 **
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya   1.994 0.050144 .
# RIV_roundTripTime_ellen                              2.305 0.024172 *
# RIV_roundTripTime_aadya                              2.873 0.005404 **
# RIA_fractionLost_aadya                               1.382 0.171312
# RIA_roundTripTime_aadya                             -2.849 0.005769 **
# AP_totalPlayoutDelay_ellen                          -3.678 0.000461 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.5481 on 69 degrees of freedom
# Multiple R-squared:  0.834,	Adjusted R-squared:  0.7859
# F-statistic: 17.34 on 20 and 69 DF,  p-value: < 2.2e-16

# %% [markdown]
# ## BIC

# %%
fit_bic<- step(model, k = log(length(trim_data$logistic_transformed_score)))
#summary(fit_aic)

bic_predictions <- predict(fit_bic, trim_data)
# par(bg = "white")
# options(repr.plot.width = 10, repr.plot.height = 6)
# plot(predictions, trim_data$logistic_transformed_score, 
#      main = "Prediction performance of AIC stepfit model", 
#      xlab = "Predicted values", ylab = "Recorded values")

# Calculate Mean Squared Error (MSE)
mse_bic <- mean((trim_data$logistic_transformed_score - bic_predictions)^2)
# Out:
# Start:  AIC=68.39
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_frameHeight_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_ellen + IT01V_bytesReceived_in_bits_s_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitter_ellen + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=68.39
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_frameHeight_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_ellen + IT01V_bytesReceived_in_bits_s_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitter_ellen + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=68.39
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=68.39
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq    RSS
# - OT01V_bytesSent_in_bits_s_ellen                     1    0.0000 19.295
# - OT01V_totalPacketSendDelay_ellen                    1    0.0001 19.295
# - IT01V_bytesReceived_in_bits_s_ellen                 1    0.0002 19.295
# - IT01V_packetsRecieved_ellen                         1    0.0003 19.295
# - RIA_roundTripTime_ellen                             1    0.0004 19.295
# - RIV_fractionLost_aadya                              1    0.0007 19.295
# - OT01V_packetsSent_s_ellen                           1    0.0015 19.296
# - IT01V_packetsLost_aadya                             1    0.0033 19.298
# - IT01V_jitter_ellen                                  1    0.0067 19.302
# - IT01A_jitterBufferDelay_emissions_aadya             1    0.0104 19.305
# - IT01V_jitter_aadya                                  1    0.0139 19.309
# - RIV_fractionLost_ellen                              1    0.0143 19.309
# - IT01V_packetsLost_ellen                             1    0.0189 19.314
# - IT01V_frameWidth_aadya                              1    0.0210 19.316
# - OT01V_frameWidth_aadya                              1    0.0295 19.324
# - RIA_fractionLost_ellen                              1    0.0312 19.326
# - OT01V_framesPerSecond_aadya                         1    0.0389 19.334
# - IT01V_frameWidth_ellen                              1    0.0403 19.335
# - RIA_fractionLost_aadya                              1    0.0857 19.380
# - ROA_roundTripTime_ellen                             1    0.0861 19.381
# - AP_totalPlayoutDelay_aadya                          1    0.0906 19.385
# - ROA_roundTripTime_aadya                             1    0.0974 19.392
# - IT01A_bytesReceived_in_bits_s_aadya                 1    0.1322 19.427
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    0.1583 19.453
# - IT01V_jitterBufferDelay_emissions_aadya             1    0.1787 19.474
# - IT01A_bytesReceived_in_bits_s_ellen                 1    0.1879 19.483
# - IT01V_totalProcessingDelay_aadya                    1    0.2281 19.523
# - IT01V_framesPerSecond_ellen                         1    0.2721 19.567
# - RIA_roundTripTime_aadya                             1    0.3403 19.635
# - RIV_roundTripTime_aadya                             1    0.3504 19.645
# - IT01V_totalFreezesDuration_ellen                    1    0.3610 19.656
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    0.3765 19.671
# - IT01V_bytesReceived_in_bits_s_aadya                 1    0.4266 19.721
# - AP_totalPlayoutDelay_ellen                          1    0.4913 19.786
# - IT01V_totalFreezesDuration_aadya                    1    0.5267 19.821
# - IT01V_packetsRecieved_aadya                         1    0.6212 19.916
# - OT01V_bytesSent_in_bits_s_aadya                     1    0.6723 19.967
# - RIV_roundTripTime_ellen                             1    0.7506 20.045
# - OT01V_framesPerSecond_ellen                         1    0.8309 20.126
# - OT01V_packetsSent_s_aadya                           1    0.8557 20.150
# - OT01V_totalPacketSendDelay_aadya                    1    0.8736 20.168
# - IT01V_framesPerSecond_aadya                         1    0.8838 20.179
# <none>                                                            19.295
# - IT01V_jitterBufferDelay_emissions_ellen             1    4.8200 24.115
# - IT01V_totalProcessingDelay_ellen                    1    5.2029 24.498
# - IT01A_jitterBufferDelay_emissions_ellen             1   14.7222 34.017
#                                                          AIC
# - OT01V_bytesSent_in_bits_s_ellen                     63.894
# - OT01V_totalPacketSendDelay_ellen                    63.894
# - IT01V_bytesReceived_in_bits_s_ellen                 63.894
# - IT01V_packetsRecieved_ellen                         63.895
# - RIA_roundTripTime_ellen                             63.896
# - RIV_fractionLost_aadya                              63.897
# - OT01V_packetsSent_s_ellen                           63.901
# - IT01V_packetsLost_aadya                             63.909
# - IT01V_jitter_ellen                                  63.925
# - IT01A_jitterBufferDelay_emissions_aadya             63.942
# - IT01V_jitter_aadya                                  63.959
# - RIV_fractionLost_ellen                              63.960
# - IT01V_packetsLost_ellen                             63.982
# - IT01V_frameWidth_aadya                              63.992
# - OT01V_frameWidth_aadya                              64.031
# - RIA_fractionLost_ellen                              64.039
# - OT01V_framesPerSecond_aadya                         64.075
# - IT01V_frameWidth_ellen                              64.081
# - RIA_fractionLost_aadya                              64.292
# - ROA_roundTripTime_ellen                             64.294
# - AP_totalPlayoutDelay_aadya                          64.315
# - ROA_roundTripTime_aadya                             64.347
# - IT01A_bytesReceived_in_bits_s_aadya                 64.508
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  64.629
# - IT01V_jitterBufferDelay_emissions_aadya             64.724
# - IT01A_bytesReceived_in_bits_s_ellen                 64.766
# - IT01V_totalProcessingDelay_aadya                    64.951
# - IT01V_framesPerSecond_ellen                         65.154
# - RIA_roundTripTime_aadya                             65.467
# - RIV_roundTripTime_aadya                             65.513
# - IT01V_totalFreezesDuration_ellen                    65.562
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  65.633
# - IT01V_bytesReceived_in_bits_s_aadya                 65.862
# - AP_totalPlayoutDelay_ellen                          66.157
# - IT01V_totalFreezesDuration_aadya                    66.317
# - IT01V_packetsRecieved_aadya                         66.746
# - OT01V_bytesSent_in_bits_s_aadya                     66.976
# - RIV_roundTripTime_ellen                             67.328
# - OT01V_framesPerSecond_ellen                         67.688
# - OT01V_packetsSent_s_aadya                           67.799
# - OT01V_totalPacketSendDelay_aadya                    67.879
# - IT01V_framesPerSecond_aadya                         67.925
# <none>                                                68.393
# - IT01V_jitterBufferDelay_emissions_ellen             83.963
# - IT01V_totalProcessingDelay_ellen                    85.381
# - IT01A_jitterBufferDelay_emissions_ellen            114.926
#
# Step:  AIC=63.89
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_aadya +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq    RSS
# - OT01V_totalPacketSendDelay_ellen                    1    0.0001 19.295
# - IT01V_bytesReceived_in_bits_s_ellen                 1    0.0001 19.295
# - IT01V_packetsRecieved_ellen                         1    0.0003 19.295
# - RIA_roundTripTime_ellen                             1    0.0005 19.295
# - RIV_fractionLost_aadya                              1    0.0008 19.296
# - IT01V_packetsLost_aadya                             1    0.0033 19.298
# - IT01V_jitter_ellen                                  1    0.0069 19.302
# - IT01A_jitterBufferDelay_emissions_aadya             1    0.0107 19.306
# - OT01V_packetsSent_s_ellen                           1    0.0129 19.308
# - IT01V_jitter_aadya                                  1    0.0142 19.309
# - RIV_fractionLost_ellen                              1    0.0160 19.311
# - IT01V_packetsLost_ellen                             1    0.0197 19.315
# - IT01V_frameWidth_aadya                              1    0.0222 19.317
# - OT01V_frameWidth_aadya                              1    0.0312 19.326
# - RIA_fractionLost_ellen                              1    0.0317 19.327
# - OT01V_framesPerSecond_aadya                         1    0.0429 19.338
# - IT01V_frameWidth_ellen                              1    0.0429 19.338
# - ROA_roundTripTime_ellen                             1    0.0861 19.381
# - RIA_fractionLost_aadya                              1    0.0898 19.385
# - ROA_roundTripTime_aadya                             1    0.0974 19.392
# - AP_totalPlayoutDelay_aadya                          1    0.0989 19.394
# - IT01A_bytesReceived_in_bits_s_aadya                 1    0.1361 19.431
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    0.1608 19.456
# - IT01V_jitterBufferDelay_emissions_aadya             1    0.1839 19.479
# - IT01A_bytesReceived_in_bits_s_ellen                 1    0.1918 19.487
# - IT01V_totalProcessingDelay_aadya                    1    0.2339 19.529
# - IT01V_framesPerSecond_ellen                         1    0.2894 19.584
# - RIA_roundTripTime_aadya                             1    0.3405 19.635
# - RIV_roundTripTime_aadya                             1    0.3505 19.645
# - IT01V_totalFreezesDuration_ellen                    1    0.3673 19.662
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    0.4259 19.721
# - IT01V_bytesReceived_in_bits_s_aadya                 1    0.4841 19.779
# - AP_totalPlayoutDelay_ellen                          1    0.4950 19.790
# - IT01V_totalFreezesDuration_aadya                    1    0.5272 19.822
# - IT01V_packetsRecieved_aadya                         1    0.6832 19.978
# - OT01V_bytesSent_in_bits_s_aadya                     1    0.6981 19.993
# - RIV_roundTripTime_ellen                             1    0.7527 20.048
# - OT01V_packetsSent_s_aadya                           1    0.8730 20.168
# - OT01V_totalPacketSendDelay_aadya                    1    0.8818 20.177
# - IT01V_framesPerSecond_aadya                         1    0.9190 20.214
# <none>                                                            19.295
# - OT01V_framesPerSecond_ellen                         1    1.0986 20.393
# - IT01V_jitterBufferDelay_emissions_ellen             1    4.8216 24.116
# - IT01V_totalProcessingDelay_ellen                    1    5.4882 24.783
# - IT01A_jitterBufferDelay_emissions_ellen             1   14.7233 34.018
#                                                          AIC
# - OT01V_totalPacketSendDelay_ellen                    59.394
# - IT01V_bytesReceived_in_bits_s_ellen                 59.395
# - IT01V_packetsRecieved_ellen                         59.395
# - RIA_roundTripTime_ellen                             59.397
# - RIV_fractionLost_aadya                              59.398
# - IT01V_packetsLost_aadya                             59.409
# - IT01V_jitter_ellen                                  59.426
# - IT01A_jitterBufferDelay_emissions_aadya             59.444
# - OT01V_packetsSent_s_ellen                           59.454
# - IT01V_jitter_aadya                                  59.460
# - RIV_fractionLost_ellen                              59.469
# - IT01V_packetsLost_ellen                             59.486
# - IT01V_frameWidth_aadya                              59.497
# - OT01V_frameWidth_aadya                              59.539
# - RIA_fractionLost_ellen                              59.542
# - OT01V_framesPerSecond_aadya                         59.594
# - IT01V_frameWidth_ellen                              59.594
# - ROA_roundTripTime_ellen                             59.795
# - RIA_fractionLost_aadya                              59.812
# - ROA_roundTripTime_aadya                             59.847
# - AP_totalPlayoutDelay_aadya                          59.854
# - IT01A_bytesReceived_in_bits_s_aadya                 60.027
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  60.141
# - IT01V_jitterBufferDelay_emissions_aadya             60.248
# - IT01A_bytesReceived_in_bits_s_ellen                 60.284
# - IT01V_totalProcessingDelay_aadya                    60.478
# - IT01V_framesPerSecond_ellen                         60.734
# - RIA_roundTripTime_aadya                             60.968
# - RIV_roundTripTime_aadya                             61.014
# - IT01V_totalFreezesDuration_ellen                    61.091
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  61.359
# - IT01V_bytesReceived_in_bits_s_aadya                 61.624
# - AP_totalPlayoutDelay_ellen                          61.674
# - IT01V_totalFreezesDuration_aadya                    61.820
# - IT01V_packetsRecieved_aadya                         62.526
# - OT01V_bytesSent_in_bits_s_aadya                     62.593
# - RIV_roundTripTime_ellen                             62.838
# - OT01V_packetsSent_s_aadya                           63.377
# - OT01V_totalPacketSendDelay_aadya                    63.416
# - IT01V_framesPerSecond_aadya                         63.582
# <none>                                                63.894
# - OT01V_framesPerSecond_ellen                         64.378
# - IT01V_jitterBufferDelay_emissions_ellen             79.469
# - IT01V_totalProcessingDelay_ellen                    81.923
# - IT01A_jitterBufferDelay_emissions_ellen            110.429
#
# Step:  AIC=59.39
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_aadya +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya + RIV_roundTripTime_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIV_fractionLost_aadya +
#     RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_ellen +
#     RIA_roundTripTime_aadya + ROA_roundTripTime_ellen + ROA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq    RSS
# - IT01V_bytesReceived_in_bits_s_ellen                 1    0.0001 19.295
# - IT01V_packetsRecieved_ellen                         1    0.0003 19.295
# - RIA_roundTripTime_ellen                             1    0.0006 19.295
# - RIV_fractionLost_aadya                              1    0.0008 19.296
# - IT01V_packetsLost_aadya                             1    0.0037 19.299
# - IT01V_jitter_ellen                                  1    0.0070 19.302
# - IT01A_jitterBufferDelay_emissions_aadya             1    0.0108 19.306
# - OT01V_packetsSent_s_ellen                           1    0.0138 19.309
# - IT01V_jitter_aadya                                  1    0.0143 19.309
# - RIV_fractionLost_ellen                              1    0.0162 19.311
# - IT01V_packetsLost_ellen                             1    0.0199 19.315
# - IT01V_frameWidth_aadya                              1    0.0226 19.317
# - OT01V_frameWidth_aadya                              1    0.0315 19.326
# - RIA_fractionLost_ellen                              1    0.0328 19.328
# - OT01V_framesPerSecond_aadya                         1    0.0430 19.338
# - IT01V_frameWidth_ellen                              1    0.0433 19.338
# - ROA_roundTripTime_ellen                             1    0.0869 19.382
# - RIA_fractionLost_aadya                              1    0.0897 19.385
# - ROA_roundTripTime_aadya                             1    0.1003 19.395
# - AP_totalPlayoutDelay_aadya                          1    0.1005 19.395
# - IT01A_bytesReceived_in_bits_s_aadya                 1    0.1361 19.431
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    0.1627 19.458
# - IT01A_bytesReceived_in_bits_s_ellen                 1    0.1988 19.494
# - IT01V_jitterBufferDelay_emissions_aadya             1    0.2078 19.503
# - IT01V_totalProcessingDelay_aadya                    1    0.2367 19.532
# - IT01V_framesPerSecond_ellen                         1    0.2895 19.584
# - RIA_roundTripTime_aadya                             1    0.3406 19.635
# - RIV_roundTripTime_aadya                             1    0.3506 19.645
# - IT01V_totalFreezesDuration_ellen                    1    0.3675 19.662
# - AP_totalPlayoutDelay_ellen                          1    0.4982 19.793
# - IT01V_bytesReceived_in_bits_s_aadya                 1    0.5396 19.834
# - IT01V_totalFreezesDuration_aadya                    1    0.5490 19.844
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    0.6642 19.959
# - OT01V_bytesSent_in_bits_s_aadya                     1    0.6981 19.993
# - IT01V_packetsRecieved_aadya                         1    0.7296 20.024
# - RIV_roundTripTime_ellen                             1    0.7562 20.051
# - OT01V_packetsSent_s_aadya                           1    0.8730 20.168
# - OT01V_totalPacketSendDelay_aadya                    1    0.8844 20.179
# - IT01V_framesPerSecond_aadya                         1    0.9195 20.214
# <none>                                                            19.295
# - OT01V_framesPerSecond_ellen                         1    1.1011 20.396
# - IT01V_jitterBufferDelay_emissions_ellen             1    4.8450 24.140
# - IT01V_totalProcessingDelay_ellen                    1    5.5206 24.815
# - IT01A_jitterBufferDelay_emissions_ellen             1   15.3417 34.637
#                                                          AIC
# - IT01V_bytesReceived_in_bits_s_ellen                 54.895
# - IT01V_packetsRecieved_ellen                         54.896
# - RIA_roundTripTime_ellen                             54.897
# - RIV_fractionLost_aadya                              54.898
# - IT01V_packetsLost_aadya                             54.912
# - IT01V_jitter_ellen                                  54.927
# - IT01A_jitterBufferDelay_emissions_aadya             54.945
# - OT01V_packetsSent_s_ellen                           54.959
# - IT01V_jitter_aadya                                  54.961
# - RIV_fractionLost_ellen                              54.970
# - IT01V_packetsLost_ellen                             54.987
# - IT01V_frameWidth_aadya                              55.000
# - OT01V_frameWidth_aadya                              55.041
# - RIA_fractionLost_ellen                              55.047
# - OT01V_framesPerSecond_aadya                         55.095
# - IT01V_frameWidth_ellen                              55.096
# - ROA_roundTripTime_ellen                             55.299
# - RIA_fractionLost_aadya                              55.312
# - ROA_roundTripTime_aadya                             55.361
# - AP_totalPlayoutDelay_aadya                          55.362
# - IT01A_bytesReceived_in_bits_s_aadya                 55.527
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  55.650
# - IT01A_bytesReceived_in_bits_s_ellen                 55.817
# - IT01V_jitterBufferDelay_emissions_aadya             55.859
# - IT01V_totalProcessingDelay_aadya                    55.992
# - IT01V_framesPerSecond_ellen                         56.235
# - RIA_roundTripTime_aadya                             56.469
# - RIV_roundTripTime_aadya                             56.515
# - IT01V_totalFreezesDuration_ellen                    56.592
# - AP_totalPlayoutDelay_ellen                          57.189
# - IT01V_bytesReceived_in_bits_s_aadya                 57.377
# - IT01V_totalFreezesDuration_aadya                    57.419
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  57.940
# - OT01V_bytesSent_in_bits_s_aadya                     58.093
# - IT01V_packetsRecieved_aadya                         58.235
# - RIV_roundTripTime_ellen                             58.354
# - OT01V_packetsSent_s_aadya                           58.877
# - OT01V_totalPacketSendDelay_aadya                    58.928
# - IT01V_framesPerSecond_aadya                         59.084
# <none>                                                59.394
# - OT01V_framesPerSecond_ellen                         59.889
# - IT01V_jitterBufferDelay_emissions_ellen             75.057
# - IT01V_totalProcessingDelay_ellen                    77.541
# - IT01A_jitterBufferDelay_emissions_ellen            107.551
#
# Step:  AIC=54.9
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitter_ellen + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_aadya +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya + RIV_roundTripTime_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIV_fractionLost_aadya +
#     RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_ellen +
#     RIA_roundTripTime_aadya + ROA_roundTripTime_ellen + ROA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq    RSS
# - IT01V_packetsRecieved_ellen                         1    0.0004 19.295
# - RIA_roundTripTime_ellen                             1    0.0005 19.296
# - RIV_fractionLost_aadya                              1    0.0008 19.296
# - IT01V_packetsLost_aadya                             1    0.0036 19.299
# - IT01V_jitter_ellen                                  1    0.0072 19.302
# - IT01A_jitterBufferDelay_emissions_aadya             1    0.0113 19.306
# - OT01V_packetsSent_s_ellen                           1    0.0137 19.309
# - IT01V_jitter_aadya                                  1    0.0142 19.309
# - RIV_fractionLost_ellen                              1    0.0164 19.311
# - IT01V_packetsLost_ellen                             1    0.0198 19.315
# - IT01V_frameWidth_aadya                              1    0.0226 19.318
# - RIA_fractionLost_ellen                              1    0.0327 19.328
# - OT01V_frameWidth_aadya                              1    0.0359 19.331
# - OT01V_framesPerSecond_aadya                         1    0.0467 19.342
# - IT01V_frameWidth_ellen                              1    0.0520 19.347
# - RIA_fractionLost_aadya                              1    0.0900 19.385
# - ROA_roundTripTime_ellen                             1    0.0901 19.385
# - AP_totalPlayoutDelay_aadya                          1    0.1003 19.395
# - ROA_roundTripTime_aadya                             1    0.1004 19.395
# - IT01A_bytesReceived_in_bits_s_aadya                 1    0.1364 19.431
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    0.1858 19.481
# - IT01A_bytesReceived_in_bits_s_ellen                 1    0.2030 19.498
# - IT01V_jitterBufferDelay_emissions_aadya             1    0.2077 19.503
# - IT01V_totalProcessingDelay_aadya                    1    0.2367 19.532
# - IT01V_framesPerSecond_ellen                         1    0.2982 19.593
# - RIA_roundTripTime_aadya                             1    0.3408 19.636
# - RIV_roundTripTime_aadya                             1    0.3508 19.646
# - IT01V_totalFreezesDuration_ellen                    1    0.3738 19.669
# - AP_totalPlayoutDelay_ellen                          1    0.5098 19.805
# - IT01V_totalFreezesDuration_aadya                    1    0.5491 19.844
# - IT01V_bytesReceived_in_bits_s_aadya                 1    0.5494 19.844
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    0.6662 19.961
# - OT01V_bytesSent_in_bits_s_aadya                     1    0.7168 20.012
# - IT01V_packetsRecieved_aadya                         1    0.7353 20.030
# - RIV_roundTripTime_ellen                             1    0.7624 20.057
# - OT01V_packetsSent_s_aadya                           1    0.8865 20.182
# - OT01V_totalPacketSendDelay_aadya                    1    0.8930 20.188
# - IT01V_framesPerSecond_aadya                         1    0.9239 20.219
# <none>                                                            19.295
# - OT01V_framesPerSecond_ellen                         1    1.1089 20.404
# - IT01V_jitterBufferDelay_emissions_ellen             1    4.8899 24.185
# - IT01V_totalProcessingDelay_ellen                    1    5.5494 24.844
# - IT01A_jitterBufferDelay_emissions_ellen             1   15.4053 34.700
#                                                          AIC
# - IT01V_packetsRecieved_ellen                         50.397
# - RIA_roundTripTime_ellen                             50.398
# - RIV_fractionLost_aadya                              50.399
# - IT01V_packetsLost_aadya                             50.412
# - IT01V_jitter_ellen                                  50.429
# - IT01A_jitterBufferDelay_emissions_aadya             50.448
# - OT01V_packetsSent_s_ellen                           50.459
# - IT01V_jitter_aadya                                  50.461
# - RIV_fractionLost_ellen                              50.472
# - IT01V_packetsLost_ellen                             50.488
# - IT01V_frameWidth_aadya                              50.500
# - RIA_fractionLost_ellen                              50.548
# - OT01V_frameWidth_aadya                              50.563
# - OT01V_framesPerSecond_aadya                         50.613
# - IT01V_frameWidth_ellen                              50.638
# - RIA_fractionLost_aadya                              50.814
# - ROA_roundTripTime_ellen                             50.814
# - AP_totalPlayoutDelay_aadya                          50.862
# - ROA_roundTripTime_aadya                             50.862
# - IT01A_bytesReceived_in_bits_s_aadya                 51.029
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  51.258
# - IT01A_bytesReceived_in_bits_s_ellen                 51.337
# - IT01V_jitterBufferDelay_emissions_aadya             51.359
# - IT01V_totalProcessingDelay_aadya                    51.493
# - IT01V_framesPerSecond_ellen                         51.776
# - RIA_roundTripTime_aadya                             51.971
# - RIV_roundTripTime_aadya                             52.017
# - IT01V_totalFreezesDuration_ellen                    52.122
# - AP_totalPlayoutDelay_ellen                          52.742
# - IT01V_totalFreezesDuration_aadya                    52.921
# - IT01V_bytesReceived_in_bits_s_aadya                 52.922
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  53.451
# - OT01V_bytesSent_in_bits_s_aadya                     53.678
# - IT01V_packetsRecieved_aadya                         53.761
# - RIV_roundTripTime_ellen                             53.883
# - OT01V_packetsSent_s_aadya                           54.438
# - OT01V_totalPacketSendDelay_aadya                    54.467
# - IT01V_framesPerSecond_aadya                         54.605
# <none>                                                54.895
# - OT01V_framesPerSecond_ellen                         55.424
# - IT01V_jitterBufferDelay_emissions_ellen             70.725
# - IT01V_totalProcessingDelay_ellen                    73.146
# - IT01A_jitterBufferDelay_emissions_ellen            103.217
#
# Step:  AIC=50.4
# logistic_transformed_score ~ IT01V_packetsRecieved_aadya + IT01V_packetsLost_ellen +
#     IT01V_packetsLost_aadya + IT01V_frameWidth_ellen + IT01V_frameWidth_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_aadya +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya + RIV_roundTripTime_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIV_fractionLost_aadya +
#     RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_ellen +
#     RIA_roundTripTime_aadya + ROA_roundTripTime_ellen + ROA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq    RSS    AIC
# - RIA_roundTripTime_ellen                             1    0.0006 19.296 45.900
# - RIV_fractionLost_aadya                              1    0.0008 19.296 45.901
# - IT01V_packetsLost_aadya                             1    0.0035 19.299 45.914
# - IT01V_jitter_ellen                                  1    0.0070 19.302 45.930
# - IT01A_jitterBufferDelay_emissions_aadya             1    0.0131 19.308 45.958
# - IT01V_jitter_aadya                                  1    0.0138 19.309 45.962
# - OT01V_packetsSent_s_ellen                           1    0.0156 19.311 45.970
# - RIV_fractionLost_ellen                              1    0.0161 19.311 45.972
# - IT01V_packetsLost_ellen                             1    0.0208 19.316 45.994
# - IT01V_frameWidth_aadya                              1    0.0247 19.320 46.012
# - RIA_fractionLost_ellen                              1    0.0327 19.328 46.050
# - OT01V_frameWidth_aadya                              1    0.0369 19.332 46.069
# - OT01V_framesPerSecond_aadya                         1    0.0520 19.347 46.139
# - IT01V_frameWidth_ellen                              1    0.0545 19.350 46.151
# - RIA_fractionLost_aadya                              1    0.0906 19.386 46.319
# - ROA_roundTripTime_ellen                             1    0.0913 19.387 46.322
# - AP_totalPlayoutDelay_aadya                          1    0.1006 19.396 46.365
# - ROA_roundTripTime_aadya                             1    0.1074 19.403 46.397
# - IT01A_bytesReceived_in_bits_s_aadya                 1    0.1381 19.433 46.539
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    0.1870 19.482 46.765
# - IT01A_bytesReceived_in_bits_s_ellen                 1    0.2041 19.499 46.844
# - IT01V_jitterBufferDelay_emissions_aadya             1    0.2081 19.504 46.863
# - IT01V_totalProcessingDelay_aadya                    1    0.2408 19.536 47.014
# - IT01V_framesPerSecond_ellen                         1    0.3300 19.625 47.423
# - RIA_roundTripTime_aadya                             1    0.3426 19.638 47.481
# - RIV_roundTripTime_aadya                             1    0.3527 19.648 47.528
# - IT01V_totalFreezesDuration_ellen                    1    0.4177 19.713 47.825
# - AP_totalPlayoutDelay_ellen                          1    0.5109 19.806 48.249
# - IT01V_bytesReceived_in_bits_s_aadya                 1    0.5518 19.847 48.435
# - IT01V_totalFreezesDuration_aadya                    1    0.5537 19.849 48.443
# - OT01V_bytesSent_in_bits_s_aadya                     1    0.7317 20.027 49.247
# - IT01V_packetsRecieved_aadya                         1    0.7354 20.031 49.264
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    0.7491 20.044 49.325
# - RIV_roundTripTime_ellen                             1    0.7954 20.091 49.533
# - OT01V_packetsSent_s_aadya                           1    0.8888 20.184 49.950
# - OT01V_totalPacketSendDelay_aadya                    1    0.9088 20.204 50.039
# - IT01V_framesPerSecond_aadya                         1    0.9687 20.264 50.306
# <none>                                                            19.295 50.397
# - OT01V_framesPerSecond_ellen                         1    1.1625 20.458 51.162
# - IT01V_jitterBufferDelay_emissions_ellen             1    5.0880 24.383 66.960
# - IT01V_totalProcessingDelay_ellen                    1    5.7109 25.006 69.231
# - IT01A_jitterBufferDelay_emissions_ellen             1   15.6827 34.978 99.434
#
# Step:  AIC=45.9
# logistic_transformed_score ~ IT01V_packetsRecieved_aadya + IT01V_packetsLost_ellen +
#     IT01V_packetsLost_aadya + IT01V_frameWidth_ellen + IT01V_frameWidth_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_aadya +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya + RIV_roundTripTime_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIV_fractionLost_aadya +
#     RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_aadya +
#     ROA_roundTripTime_ellen + ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen +
#     AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq    RSS    AIC
# - RIV_fractionLost_aadya                              1    0.0009 19.297 41.404
# - IT01V_packetsLost_aadya                             1    0.0035 19.300 41.417
# - IT01V_jitter_ellen                                  1    0.0065 19.303 41.431
# - IT01A_jitterBufferDelay_emissions_aadya             1    0.0131 19.309 41.462
# - IT01V_jitter_aadya                                  1    0.0141 19.310 41.466
# - OT01V_packetsSent_s_ellen                           1    0.0156 19.312 41.473
# - RIV_fractionLost_ellen                              1    0.0157 19.312 41.473
# - IT01V_packetsLost_ellen                             1    0.0206 19.317 41.496
# - IT01V_frameWidth_aadya                              1    0.0246 19.321 41.515
# - RIA_fractionLost_ellen                              1    0.0323 19.328 41.551
# - OT01V_frameWidth_aadya                              1    0.0370 19.333 41.573
# - IT01V_frameWidth_ellen                              1    0.0546 19.351 41.654
# - OT01V_framesPerSecond_aadya                         1    0.0566 19.353 41.664
# - RIA_fractionLost_aadya                              1    0.0921 19.388 41.829
# - ROA_roundTripTime_ellen                             1    0.0935 19.389 41.835
# - AP_totalPlayoutDelay_aadya                          1    0.1004 19.396 41.868
# - ROA_roundTripTime_aadya                             1    0.1069 19.403 41.897
# - IT01A_bytesReceived_in_bits_s_aadya                 1    0.1374 19.433 42.039
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    0.1871 19.483 42.269
# - IT01V_jitterBufferDelay_emissions_aadya             1    0.2088 19.505 42.369
# - IT01A_bytesReceived_in_bits_s_ellen                 1    0.2142 19.510 42.394
# - IT01V_totalProcessingDelay_aadya                    1    0.2421 19.538 42.522
# - RIA_roundTripTime_aadya                             1    0.3447 19.641 42.994
# - RIV_roundTripTime_aadya                             1    0.3549 19.651 43.040
# - IT01V_framesPerSecond_ellen                         1    0.3569 19.653 43.050
# - IT01V_totalFreezesDuration_ellen                    1    0.4171 19.713 43.325
# - AP_totalPlayoutDelay_ellen                          1    0.5205 19.816 43.796
# - IT01V_bytesReceived_in_bits_s_aadya                 1    0.5512 19.847 43.935
# - IT01V_totalFreezesDuration_aadya                    1    0.5536 19.850 43.946
# - OT01V_bytesSent_in_bits_s_aadya                     1    0.7312 20.027 44.748
# - IT01V_packetsRecieved_aadya                         1    0.7353 20.031 44.766
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1    0.7493 20.045 44.829
# - RIV_roundTripTime_ellen                             1    0.7953 20.091 45.035
# - OT01V_packetsSent_s_aadya                           1    0.8886 20.185 45.452
# - OT01V_totalPacketSendDelay_aadya                    1    0.9097 20.206 45.546
# - IT01V_framesPerSecond_aadya                         1    0.9704 20.266 45.816
# <none>                                                            19.296 45.900
# - OT01V_framesPerSecond_ellen                         1    1.2496 20.546 47.048
# - IT01V_jitterBufferDelay_emissions_ellen             1    5.0900 24.386 62.470
# - IT01V_totalProcessingDelay_ellen                    1    5.7259 25.022 64.787
# - IT01A_jitterBufferDelay_emissions_ellen             1   15.6834 34.979 94.938
#
# Step:  AIC=41.4
# logistic_transformed_score ~ IT01V_packetsRecieved_aadya + IT01V_packetsLost_ellen +
#     IT01V_packetsLost_aadya + IT01V_frameWidth_ellen + IT01V_frameWidth_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_aadya +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya + RIV_roundTripTime_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIA_fractionLost_ellen +
#     RIA_fractionLost_aadya + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq    RSS    AIC
# - IT01V_packetsLost_aadya                             1    0.0036 19.300 36.921
# - IT01A_jitterBufferDelay_emissions_aadya             1    0.0125 19.309 36.963
# - IT01V_jitter_ellen                                  1    0.0126 19.309 36.963
# - IT01V_jitter_aadya                                  1    0.0136 19.310 36.968
# - OT01V_packetsSent_s_ellen                           1    0.0152 19.312 36.975
# - RIV_fractionLost_ellen                              1    0.0167 19.314 36.983
# - IT01V_packetsLost_ellen                             1    0.0201 19.317 36.998
# - IT01V_frameWidth_aadya                              1    0.0271 19.324 37.031
# - RIA_fractionLost_ellen                              1    0.0329 19.330 37.058
# - OT01V_frameWidth_aadya                              1    0.0384 19.335 37.083
# - IT01V_frameWidth_ellen                              1    0.0567 19.354 37.169
# - OT01V_framesPerSecond_aadya                         1    0.0587 19.356 37.178
# - RIA_fractionLost_aadya                              1    0.0938 19.391 37.341
# - ROA_roundTripTime_ellen                             1    0.0944 19.391 37.344
# - AP_totalPlayoutDelay_aadya                          1    0.1000 19.397 37.370
# - ROA_roundTripTime_aadya                             1    0.1064 19.403 37.399
# - IT01A_bytesReceived_in_bits_s_aadya                 1    0.1418 19.439 37.564
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1    0.1961 19.493 37.815
# - IT01A_bytesReceived_in_bits_s_ellen                 1    0.2134 19.510 37.894
# - IT01V_jitterBufferDelay_emissions_aadya             1    0.2153 19.512 37.903
# - IT01V_totalProcessingDelay_aadya                    1    0.2414 19.538 38.023
# ...
# - IT01V_totalFreezesDuration_ellen                    1     3.983 26.055
# - AP_totalPlayoutDelay_ellen                          1     4.065 26.137
# - IT01V_totalProcessingDelay_ellen                    1    12.871 34.943
# - IT01V_jitterBufferDelay_emissions_ellen             1    13.273 35.345
# - IT01A_jitterBufferDelay_emissions_ellen             1    37.427 59.499
#                                                          AIC
# - OT01V_bytesSent_in_bits_s_aadya                    -43.493
# - OT01V_packetsSent_s_aadya                          -42.839
# - IT01V_bytesReceived_in_bits_s_aadya                -42.690
# - IT01V_packetsRecieved_aadya                        -42.629
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -41.331
# <none>                                               -40.999
# - RIV_roundTripTime_ellen                            -40.866
# - IT01V_framesPerSecond_aadya                        -39.943
# - IT01V_totalFreezesDuration_aadya                   -38.340
# - OT01V_totalPacketSendDelay_aadya                   -38.233
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -35.682
# - OT01V_framesPerSecond_ellen                        -35.107
# - RIA_roundTripTime_aadya                            -32.895
# - RIV_roundTripTime_aadya                            -32.789
# - IT01V_totalFreezesDuration_ellen                   -30.566
# - AP_totalPlayoutDelay_ellen                         -30.286
# - IT01V_totalProcessingDelay_ellen                    -4.153
# - IT01V_jitterBufferDelay_emissions_ellen             -3.123
# - IT01A_jitterBufferDelay_emissions_ellen             43.750
#
# Step:  AIC=-43.49
# logistic_transformed_score ~ IT01V_packetsRecieved_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_framesPerSecond_ellen +
#     OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya + RIV_roundTripTime_ellen +
#     RIV_roundTripTime_aadya + RIA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq    RSS
# - IT01V_bytesReceived_in_bits_s_aadya                 1     0.671 23.240
# - IT01V_packetsRecieved_aadya                         1     0.673 23.242
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1     0.833 23.403
# <none>                                                            22.569
# - IT01V_framesPerSecond_aadya                         1     1.162 23.732
# - RIV_roundTripTime_ellen                             1     1.199 23.769
# - OT01V_totalPacketSendDelay_aadya                    1     1.653 24.222
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1     2.047 24.616
# - IT01V_totalFreezesDuration_aadya                    1     2.092 24.661
# - OT01V_framesPerSecond_ellen                         1     2.595 25.165
# - OT01V_packetsSent_s_aadya                           1     3.146 25.715
# - RIA_roundTripTime_aadya                             1     3.390 25.960
# - RIV_roundTripTime_aadya                             1     3.429 25.998
# - AP_totalPlayoutDelay_ellen                          1     4.104 26.673
# - IT01V_totalFreezesDuration_ellen                    1     4.491 27.060
# - IT01V_jitterBufferDelay_emissions_ellen             1    13.439 36.008
# - IT01V_totalProcessingDelay_ellen                    1    13.497 36.067
# - IT01A_jitterBufferDelay_emissions_ellen             1    37.376 59.945
#                                                          AIC
# - IT01V_bytesReceived_in_bits_s_aadya                -45.356
# - IT01V_packetsRecieved_aadya                        -45.348
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -44.730
# <none>                                               -43.493
# - IT01V_framesPerSecond_aadya                        -43.473
# - RIV_roundTripTime_ellen                            -43.333
# - OT01V_totalPacketSendDelay_aadya                   -41.632
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -40.180
# - IT01V_totalFreezesDuration_aadya                   -40.016
# - OT01V_framesPerSecond_ellen                        -38.196
# - OT01V_packetsSent_s_aadya                          -36.249
# - RIA_roundTripTime_aadya                            -35.397
# - RIV_roundTripTime_aadya                            -35.264
# - AP_totalPlayoutDelay_ellen                         -32.957
# - IT01V_totalFreezesDuration_ellen                   -31.660
# - IT01V_jitterBufferDelay_emissions_ellen             -5.949
# - IT01V_totalProcessingDelay_ellen                    -5.803
# - IT01A_jitterBufferDelay_emissions_ellen             39.922
#
# Step:  AIC=-45.36
# logistic_transformed_score ~ IT01V_packetsRecieved_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_ellen + OT01V_packetsSent_s_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq    RSS
# - IT01V_packetsRecieved_aadya                         1     0.002 23.243
# - IT01V_framesPerSecond_aadya                         1     0.851 24.091
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1     0.918 24.158
# <none>                                                            23.240
# - RIV_roundTripTime_ellen                             1     1.254 24.494
# - OT01V_totalPacketSendDelay_aadya                    1     1.438 24.679
# - IT01V_totalFreezesDuration_aadya                    1     1.763 25.004
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1     2.339 25.580
# - OT01V_packetsSent_s_aadya                           1     2.871 26.111
# - OT01V_framesPerSecond_ellen                         1     2.908 26.148
# - AP_totalPlayoutDelay_ellen                          1     3.877 27.118
# - IT01V_totalFreezesDuration_ellen                    1     4.609 27.850
# - RIA_roundTripTime_aadya                             1     5.258 28.498
# - RIV_roundTripTime_aadya                             1     5.296 28.537
# - IT01V_totalProcessingDelay_ellen                    1    13.014 36.254
# - IT01V_jitterBufferDelay_emissions_ellen             1    13.062 36.302
# - IT01A_jitterBufferDelay_emissions_ellen             1    36.785 60.025
#                                                          AIC
# - IT01V_packetsRecieved_aadya                        -49.847
# - IT01V_framesPerSecond_aadya                        -46.621
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -46.371
# <none>                                               -45.356
# - RIV_roundTripTime_ellen                            -45.127
# - OT01V_totalPacketSendDelay_aadya                   -44.451
# - IT01V_totalFreezesDuration_aadya                   -43.274
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -41.225
# - OT01V_packetsSent_s_aadya                          -39.373
# - OT01V_framesPerSecond_ellen                        -39.245
# - AP_totalPlayoutDelay_ellen                         -35.970
# - IT01V_totalFreezesDuration_ellen                   -33.572
# - RIA_roundTripTime_aadya                            -31.501
# - RIV_roundTripTime_aadya                            -31.379
# - IT01V_totalProcessingDelay_ellen                    -9.837
# - IT01V_jitterBufferDelay_emissions_ellen             -9.717
# - IT01A_jitterBufferDelay_emissions_ellen             35.543
#
# Step:  AIC=-49.85
# logistic_transformed_score ~ IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_ellen + OT01V_packetsSent_s_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq    RSS
# - IT01V_framesPerSecond_aadya                         1     0.863 24.105
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1     0.933 24.176
# <none>                                                            23.243
# - RIV_roundTripTime_ellen                             1     1.380 24.623
# - OT01V_totalPacketSendDelay_aadya                    1     1.456 24.698
# - IT01V_totalFreezesDuration_aadya                    1     1.761 25.004
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1     2.370 25.612
# - OT01V_packetsSent_s_aadya                           1     2.929 26.172
# - OT01V_framesPerSecond_ellen                         1     3.113 26.356
# - AP_totalPlayoutDelay_ellen                          1     3.957 27.199
# - IT01V_totalFreezesDuration_ellen                    1     4.616 27.859
# - RIA_roundTripTime_aadya                             1     5.321 28.564
# - RIV_roundTripTime_aadya                             1     5.361 28.604
# - IT01V_totalProcessingDelay_ellen                    1    13.082 36.324
# - IT01V_jitterBufferDelay_emissions_ellen             1    13.136 36.378
# - IT01A_jitterBufferDelay_emissions_ellen             1    38.890 62.132
#                                                          AIC
# - IT01V_framesPerSecond_aadya                        -51.066
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -50.804
# <none>                                               -49.847
# - RIV_roundTripTime_ellen                            -49.155
# - OT01V_totalPacketSendDelay_aadya                   -48.880
# - IT01V_totalFreezesDuration_aadya                   -47.772
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -45.609
# - OT01V_packetsSent_s_aadya                          -43.665
# - OT01V_framesPerSecond_ellen                        -43.035
# - AP_totalPlayoutDelay_ellen                         -40.198
# - IT01V_totalFreezesDuration_ellen                   -38.042
# - RIA_roundTripTime_aadya                            -35.793
# - RIV_roundTripTime_aadya                            -35.668
# - IT01V_totalProcessingDelay_ellen                   -14.162
# - IT01V_jitterBufferDelay_emissions_ellen            -14.028
# - IT01A_jitterBufferDelay_emissions_ellen             34.148
#
# Step:  AIC=-51.07
# logistic_transformed_score ~ IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_framesPerSecond_ellen +
#     OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya + RIV_roundTripTime_ellen +
#     RIV_roundTripTime_aadya + RIA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq    RSS
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1     0.658 24.764
# <none>                                                            24.105
# - OT01V_totalPacketSendDelay_aadya                    1     1.487 25.593
# - RIV_roundTripTime_ellen                             1     1.696 25.801
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1     2.286 26.391
# - IT01V_totalFreezesDuration_aadya                    1     2.661 26.766
# - OT01V_packetsSent_s_aadya                           1     3.088 27.193
# - AP_totalPlayoutDelay_ellen                          1     4.208 28.314
# - OT01V_framesPerSecond_ellen                         1     4.271 28.376
# - IT01V_totalFreezesDuration_ellen                    1     4.300 28.406
# - RIA_roundTripTime_aadya                             1     5.674 29.780
# - RIV_roundTripTime_aadya                             1     5.714 29.820
# - IT01V_jitterBufferDelay_emissions_ellen             1    12.339 36.444
# - IT01V_totalProcessingDelay_ellen                    1    12.788 36.893
# - IT01A_jitterBufferDelay_emissions_ellen             1    39.017 63.122
#                                                          AIC
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -53.141
# <none>                                               -51.066
# - OT01V_totalPacketSendDelay_aadya                   -50.178
# - RIV_roundTripTime_ellen                            -49.448
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -47.413
# - IT01V_totalFreezesDuration_aadya                   -46.142
# - OT01V_packetsSent_s_aadya                          -44.719
# - AP_totalPlayoutDelay_ellen                         -41.085
# - OT01V_framesPerSecond_ellen                        -40.885
# - IT01V_totalFreezesDuration_ellen                   -40.793
# - RIA_roundTripTime_aadya                            -36.541
# - RIV_roundTripTime_aadya                            -36.420
# - IT01V_jitterBufferDelay_emissions_ellen            -18.365
# - IT01V_totalProcessingDelay_ellen                   -17.263
# - IT01A_jitterBufferDelay_emissions_ellen             31.071
#
# Step:  AIC=-53.14
# logistic_transformed_score ~ IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_framesPerSecond_ellen +
#     OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq    RSS
# <none>                                                            24.764
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1     2.033 26.797
# - RIV_roundTripTime_ellen                             1     2.405 27.168
# - IT01V_totalFreezesDuration_aadya                    1     3.206 27.970
# - AP_totalPlayoutDelay_ellen                          1     3.672 28.435
# - IT01V_totalFreezesDuration_ellen                    1     3.695 28.458
# - OT01V_packetsSent_s_aadya                           1     3.899 28.663
# - OT01V_totalPacketSendDelay_aadya                    1     4.130 28.893
# - OT01V_framesPerSecond_ellen                         1     4.163 28.927
# - RIA_roundTripTime_aadya                             1     5.460 30.224
# - RIV_roundTripTime_aadya                             1     5.500 30.264
# - IT01V_jitterBufferDelay_emissions_ellen             1    12.004 36.768
# - IT01V_totalProcessingDelay_ellen                    1    12.968 37.732
# - IT01A_jitterBufferDelay_emissions_ellen             1    38.448 63.211
#                                                          AIC
# <none>                                               -53.141
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -50.539
# - RIV_roundTripTime_ellen                            -49.301
# - IT01V_totalFreezesDuration_aadya                   -46.684
# - AP_totalPlayoutDelay_ellen                         -45.199
# - IT01V_totalFreezesDuration_ellen                   -45.126
# - OT01V_packetsSent_s_aadya                          -44.481
# - OT01V_totalPacketSendDelay_aadya                   -43.760
# - OT01V_framesPerSecond_ellen                        -43.657
# - RIA_roundTripTime_aadya                            -39.708
# - RIV_roundTripTime_aadya                            -39.589
# - IT01V_jitterBufferDelay_emissions_ellen            -22.070
# - IT01V_totalProcessingDelay_ellen                   -19.741
# - IT01A_jitterBufferDelay_emissions_ellen             26.698

# %% [markdown]
# # Evaluate all the models

# %%
cat("MSE for AIC:", mse_aic, "\n")
cat("MSE for BIC:", mse_bic, "\n")
cat("MSE for lasso:", mse_lasso, "\n")
cat("MSE for ridge:", mse_ridge, "\n")
# Out:
# MSE for AIC: 0.2303441
# MSE for BIC: 0.2751526
# MSE for lasso: 0.4237797
# MSE for ridge: 0.9162658
