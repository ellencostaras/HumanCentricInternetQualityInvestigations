# %%
install.packages("glmnet")
install.packages("caret")
install.packages("dplyr")
install.packages("pROC")
install.packages("rsample")
install.packages("randomForest")
# Out:
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpqSvbFh/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpqSvbFh/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpqSvbFh/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpqSvbFh/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpqSvbFh/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpqSvbFh/downloaded_packages

# %%
library(glmnet)
library(caret)
library(dplyr)
library(pROC)
library(rsample)
library(randomForest)
# Out:
# Loading required package: Matrix
#
# Loaded glmnet 4.1-8
#
# Loading required package: ggplot2
#
# Loading required package: lattice
#
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Type 'citation("pROC")' for a citation.
#
#
# Attaching package: 'pROC'
#
#
# The following objects are masked from 'package:stats':
#
#     cov, smooth, var
#
#
# Warning message:
# "package 'randomForest' was built under R version 4.3.3"
# randomForest 4.7-1.2
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: 'randomForest'
#
#
# The following object is masked from 'package:dplyr':
#
#     combine
#
#
# The following object is masked from 'package:ggplot2':
#
#     margin

# %% [markdown]
# # Import and format data

# %%
#read in the data
data <- read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression_2_(web_to_serviceable)/regression_tables/fieldwork_regression_table.csv")

#exclude cols and then scale 
exclude_columns <- c("identifier", "score_ellen", "score_aadya", "score_min", "serviceable_ellen", "serviceable_aadya", "serviceable_agg")

# Create a scaled version of the DataFrame excluding specified columns
scaled_data <- data %>%
  select(-one_of(exclude_columns)) %>%        # Exclude specified columns
  scale()                                      # Scale the remaining columns

# Convert the scaled data back to a DataFrame
scaled_data <- as.data.frame(scaled_data)

# Combine the scaled columns with the excluded columns from the original DataFrame
data <- cbind(data[exclude_columns], scaled_data)

#scale the score
data$scaled_score <- data$score_min/5
data$logistic_transformed_score <-  1 / (1 + exp(-data$scaled_score))
table(data$serviceable_agg)
trim_data <- data %>% select(-identifier,-score_min, - scaled_score,  -serviceable_agg, -score_ellen, -score_aadya, -serviceable_ellen, -serviceable_aadya)
# Out:
#  0  1
# 59 31

# %% [markdown]
# # Build a model

# %%
model <- lm(logistic_transformed_score ~ ., data = trim_data)
summary(model)
# Out:
# Call:
# lm(formula = logistic_transformed_score ~ ., data = trim_data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.065312 -0.012229 -0.000162  0.011500  0.057464
#
# Coefficients: (3 not defined because of singularities)
#                                                      Estimate Std. Error
# (Intercept)                                         6.240e-01  3.067e-03
# IT01V_packetsRecieved_ellen                         1.633e-02  1.249e-01
# IT01V_packetsRecieved_aadya                         8.661e-02  1.283e-01
# IT01V_packetsLost_ellen                            -3.612e-03  4.690e-03
# IT01V_packetsLost_aadya                             6.493e-03  5.253e-03
# IT01V_frameWidth_ellen                              4.165e-02  7.176e-02
# IT01V_frameWidth_aadya                              1.371e-02  1.462e-02
# IT01V_frameHeight_ellen                                    NA         NA
# IT01V_frameHeight_aadya                                    NA         NA
# IT01V_totalFreezesDuration_ellen                    2.043e-03  1.213e-02
# IT01V_totalFreezesDuration_aadya                    5.387e-03  7.810e-03
# IT01V_framesPerSecond_ellen                        -4.417e-02  2.678e-02
# IT01V_framesPerSecond_aadya                        -1.729e-02  1.605e-02
# IT01V_bytesReceived_in_bits_s_ellen                -2.685e-02  1.280e-01
# IT01V_bytesReceived_in_bits_s_aadya                -6.912e-02  1.346e-01
# IT01V_totalProcessingDelay_ellen                    1.325e-02  1.260e-02
# IT01V_totalProcessingDelay_aadya                   -9.580e-03  6.716e-03
# IT01V_jitter_ellen                                 -8.742e-05  1.735e-02
# IT01V_jitter_aadya                                 -8.568e-04  9.754e-03
# IT01V_jitterBufferDelay_emissions_ellen            -3.073e-02  2.278e-02
# IT01V_jitterBufferDelay_emissions_aadya             2.404e-03  1.003e-02
# IT01A_bytesReceived_in_bits_s_ellen                 2.638e-03  4.837e-03
# IT01A_bytesReceived_in_bits_s_aadya                 1.767e-03  4.557e-03
# IT01A_jitterBufferDelay_emissions_ellen            -1.584e-02  6.488e-03
# IT01A_jitterBufferDelay_emissions_aadya             8.023e-03  1.176e-02
# OT01V_packetsSent_s_ellen                          -1.136e-01  1.370e-01
# OT01V_packetsSent_s_aadya                           1.225e-02  1.495e-01
# OT01V_bytesSent_in_bits_s_ellen                     8.727e-02  1.385e-01
# OT01V_bytesSent_in_bits_s_aadya                    -6.764e-04  1.518e-01
# OT01V_frameWidth_ellen                                     NA         NA
# OT01V_frameWidth_aadya                             -3.515e-02  7.280e-02
# OT01V_framesPerSecond_ellen                         3.088e-02  1.654e-02
# OT01V_framesPerSecond_aadya                         4.050e-02  2.577e-02
# OT01V_totalPacketSendDelay_ellen                    1.468e-02  9.622e-03
# OT01V_totalPacketSendDelay_aadya                    7.296e-03  1.385e-02
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -1.087e-02  1.239e-02
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -6.756e-03  1.340e-02
# RIV_roundTripTime_ellen                            -4.983e-03  1.231e-02
# RIV_roundTripTime_aadya                             5.812e-01  4.628e-01
# RIV_fractionLost_ellen                             -6.183e-03  5.720e-03
# RIV_fractionLost_aadya                             -4.028e-04  8.499e-03
# RIA_fractionLost_ellen                              3.914e-04  3.956e-03
# RIA_fractionLost_aadya                              6.613e-03  7.466e-03
# RIA_roundTripTime_ellen                            -7.768e-04  4.158e-03
# RIA_roundTripTime_aadya                            -5.809e-01  4.635e-01
# ROA_roundTripTime_ellen                             3.953e-03  1.126e-02
# ROA_roundTripTime_aadya                            -2.823e-03  9.590e-03
# AP_totalPlayoutDelay_ellen                         -9.218e-03  8.363e-03
# AP_totalPlayoutDelay_aadya                         -5.231e-04  7.160e-03
#                                                    t value Pr(>|t|)
# (Intercept)                                        203.470   <2e-16 ***
# IT01V_packetsRecieved_ellen                          0.131   0.8966
# IT01V_packetsRecieved_aadya                          0.675   0.5031
# IT01V_packetsLost_ellen                             -0.770   0.4453
# IT01V_packetsLost_aadya                              1.236   0.2230
# IT01V_frameWidth_ellen                               0.580   0.5646
# IT01V_frameWidth_aadya                               0.937   0.3538
# IT01V_frameHeight_ellen                                 NA       NA
# IT01V_frameHeight_aadya                                 NA       NA
# IT01V_totalFreezesDuration_ellen                     0.168   0.8670
# IT01V_totalFreezesDuration_aadya                     0.690   0.4940
# IT01V_framesPerSecond_ellen                         -1.649   0.1062
# IT01V_framesPerSecond_aadya                         -1.078   0.2870
# IT01V_bytesReceived_in_bits_s_ellen                 -0.210   0.8348
# IT01V_bytesReceived_in_bits_s_aadya                 -0.513   0.6103
# IT01V_totalProcessingDelay_ellen                     1.051   0.2990
# IT01V_totalProcessingDelay_aadya                    -1.426   0.1608
# IT01V_jitter_ellen                                  -0.005   0.9960
# IT01V_jitter_aadya                                  -0.088   0.9304
# IT01V_jitterBufferDelay_emissions_ellen             -1.349   0.1844
# IT01V_jitterBufferDelay_emissions_aadya              0.240   0.8117
# IT01A_bytesReceived_in_bits_s_ellen                  0.545   0.5882
# IT01A_bytesReceived_in_bits_s_aadya                  0.388   0.7001
# IT01A_jitterBufferDelay_emissions_ellen             -2.442   0.0187 *
# IT01A_jitterBufferDelay_emissions_aadya              0.682   0.4987
# OT01V_packetsSent_s_ellen                           -0.829   0.4116
# OT01V_packetsSent_s_aadya                            0.082   0.9350
# OT01V_bytesSent_in_bits_s_ellen                      0.630   0.5318
# OT01V_bytesSent_in_bits_s_aadya                     -0.004   0.9965
# OT01V_frameWidth_ellen                                  NA       NA
# OT01V_frameWidth_aadya                              -0.483   0.6316
# OT01V_framesPerSecond_ellen                          1.867   0.0686 .
# OT01V_framesPerSecond_aadya                          1.572   0.1232
# OT01V_totalPacketSendDelay_ellen                     1.525   0.1343
# OT01V_totalPacketSendDelay_aadya                     0.527   0.6010
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  -0.878   0.3849
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  -0.504   0.6166
# RIV_roundTripTime_ellen                             -0.405   0.6875
# RIV_roundTripTime_aadya                              1.256   0.2159
# RIV_fractionLost_ellen                              -1.081   0.2856
# RIV_fractionLost_aadya                              -0.047   0.9624
# RIA_fractionLost_ellen                               0.099   0.9216
# RIA_fractionLost_aadya                               0.886   0.3806
# RIA_roundTripTime_ellen                             -0.187   0.8527
# RIA_roundTripTime_aadya                             -1.253   0.2167
# ROA_roundTripTime_ellen                              0.351   0.7271
# ROA_roundTripTime_aadya                             -0.294   0.7699
# AP_totalPlayoutDelay_ellen                          -1.102   0.2763
# AP_totalPlayoutDelay_aadya                          -0.073   0.9421
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.02909 on 44 degrees of freedom
# Multiple R-squared:  0.6988,	Adjusted R-squared:  0.3907
# F-statistic: 2.268 on 45 and 44 DF,  p-value: 0.003739

# %% [markdown]
# # Penalised regression

# %% [markdown]
# ## Lasso/ Ridge

# %%
X <- model.matrix(logistic_transformed_score ~ ., data = trim_data)[,-1]
y <- trim_data$logistic_transformed_score

# Fit the lasso model (alpha = 1 for Lasso)
lasso_model <- glmnet(X, y, alpha = 1)

# Predict on training data
lasso_predictions <- predict(lasso_model, X)

# Calculate MSE for lasso model
mse_lasso <- mean((y - lasso_predictions)^2)

# %%
# Fit the ridge model (alpha = 0)
ridge_model <- glmnet(X, y, alpha = 0)

# Predict on training data
ridge_predictions <- predict(ridge_model, X)

# Calculate MSE for lasso model
mse_ridge <- mean((y - ridge_predictions)^2)

# %% [markdown]
# ## AIC

# %%
fit_aic <- step(model)
summary(fit_aic)

aic_predictions <- predict(fit_aic, trim_data)
# par(bg = "white")
# options(repr.plot.width = 10, repr.plot.height = 6)
# plot(predictions, trim_data$logistic_transformed_score, 
#      main = "Prediction performance of AIC stepfit model", 
#      xlab = "Predicted values", ylab = "Recorded values")

# Calculate Mean Squared Error (MSE)
mse_aic <- mean((trim_data$logistic_transformed_score - aic_predictions)^2)
# Out:
# Start:  AIC=-609.11
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_frameHeight_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_ellen + IT01V_bytesReceived_in_bits_s_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitter_ellen + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=-609.11
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_frameHeight_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_ellen + IT01V_bytesReceived_in_bits_s_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitter_ellen + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=-609.11
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=-609.11
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq      RSS
# - OT01V_bytesSent_in_bits_s_aadya                     1 0.0000000 0.037243
# - IT01V_jitter_ellen                                  1 0.0000000 0.037243
# - RIV_fractionLost_aadya                              1 0.0000019 0.037245
# - AP_totalPlayoutDelay_aadya                          1 0.0000045 0.037247
# - OT01V_packetsSent_s_aadya                           1 0.0000057 0.037249
# - IT01V_jitter_aadya                                  1 0.0000065 0.037249
# - RIA_fractionLost_ellen                              1 0.0000083 0.037251
# - IT01V_packetsRecieved_ellen                         1 0.0000145 0.037257
# - IT01V_totalFreezesDuration_ellen                    1 0.0000240 0.037267
# - RIA_roundTripTime_ellen                             1 0.0000295 0.037272
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000372 0.037280
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000486 0.037291
# - ROA_roundTripTime_aadya                             1 0.0000733 0.037316
# - ROA_roundTripTime_ellen                             1 0.0001044 0.037347
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0001272 0.037370
# - RIV_roundTripTime_ellen                             1 0.0001388 0.037382
# - OT01V_frameWidth_aadya                              1 0.0001973 0.037440
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0002152 0.037458
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0002230 0.037466
# - OT01V_totalPacketSendDelay_aadya                    1 0.0002349 0.037478
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0002518 0.037495
# - IT01V_frameWidth_ellen                              1 0.0002851 0.037528
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0003362 0.037579
# - IT01V_packetsRecieved_aadya                         1 0.0003859 0.037629
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0003939 0.037637
# - IT01V_totalFreezesDuration_aadya                    1 0.0004026 0.037645
# - IT01V_packetsLost_ellen                             1 0.0005021 0.037745
# - OT01V_packetsSent_s_ellen                           1 0.0005817 0.037825
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0006520 0.037895
# - RIA_fractionLost_aadya                              1 0.0006640 0.037907
# - IT01V_frameWidth_aadya                              1 0.0007435 0.037986
# <none>                                                            0.037243
# - IT01V_totalProcessingDelay_ellen                    1 0.0009349 0.038178
# - IT01V_framesPerSecond_aadya                         1 0.0009831 0.038226
# - RIV_fractionLost_ellen                              1 0.0009893 0.038232
# - AP_totalPlayoutDelay_ellen                          1 0.0010284 0.038271
# - IT01V_packetsLost_aadya                             1 0.0012930 0.038536
# - RIA_roundTripTime_aadya                             1 0.0013295 0.038572
# - RIV_roundTripTime_aadya                             1 0.0013346 0.038578
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0015393 0.038782
# - IT01V_totalProcessingDelay_aadya                    1 0.0017221 0.038965
# - OT01V_totalPacketSendDelay_ellen                    1 0.0019692 0.039212
# - OT01V_framesPerSecond_aadya                         1 0.0020909 0.039334
# - IT01V_framesPerSecond_ellen                         1 0.0023021 0.039545
# - OT01V_framesPerSecond_ellen                         1 0.0029496 0.040192
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0050473 0.042290
#                                                          AIC
# - OT01V_bytesSent_in_bits_s_aadya                    -611.11
# - IT01V_jitter_ellen                                 -611.11
# - RIV_fractionLost_aadya                             -611.10
# - AP_totalPlayoutDelay_aadya                         -611.10
# - OT01V_packetsSent_s_aadya                          -611.10
# - IT01V_jitter_aadya                                 -611.09
# - RIA_fractionLost_ellen                             -611.09
# - IT01V_packetsRecieved_ellen                        -611.07
# - IT01V_totalFreezesDuration_ellen                   -611.05
# - RIA_roundTripTime_ellen                            -611.04
# - IT01V_bytesReceived_in_bits_s_ellen                -611.02
# - IT01V_jitterBufferDelay_emissions_aadya            -610.99
# - ROA_roundTripTime_aadya                            -610.93
# - ROA_roundTripTime_ellen                            -610.86
# - IT01A_bytesReceived_in_bits_s_aadya                -610.80
# - RIV_roundTripTime_ellen                            -610.77
# - OT01V_frameWidth_aadya                             -610.63
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -610.59
# - IT01V_bytesReceived_in_bits_s_aadya                -610.57
# - OT01V_totalPacketSendDelay_aadya                   -610.54
# - IT01A_bytesReceived_in_bits_s_ellen                -610.50
# - IT01V_frameWidth_ellen                             -610.42
# - OT01V_bytesSent_in_bits_s_ellen                    -610.30
# - IT01V_packetsRecieved_aadya                        -610.18
# - IT01A_jitterBufferDelay_emissions_aadya            -610.16
# - IT01V_totalFreezesDuration_aadya                   -610.14
# - IT01V_packetsLost_ellen                            -609.90
# - OT01V_packetsSent_s_ellen                          -609.71
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -609.55
# - RIA_fractionLost_aadya                             -609.52
# - IT01V_frameWidth_aadya                             -609.33
# <none>                                               -609.11
# - IT01V_totalProcessingDelay_ellen                   -608.88
# - IT01V_framesPerSecond_aadya                        -608.76
# - RIV_fractionLost_ellen                             -608.75
# - AP_totalPlayoutDelay_ellen                         -608.66
# - IT01V_packetsLost_aadya                            -608.04
# - RIA_roundTripTime_aadya                            -607.95
# - RIV_roundTripTime_aadya                            -607.94
# - IT01V_jitterBufferDelay_emissions_ellen            -607.46
# - IT01V_totalProcessingDelay_aadya                   -607.04
# - OT01V_totalPacketSendDelay_ellen                   -606.47
# - OT01V_framesPerSecond_aadya                        -606.19
# - IT01V_framesPerSecond_ellen                        -605.71
# - OT01V_framesPerSecond_ellen                        -604.25
# - IT01A_jitterBufferDelay_emissions_ellen            -599.67
#
# Step:  AIC=-611.11
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq      RSS
# - IT01V_jitter_ellen                                  1 0.0000000 0.037243
# - RIV_fractionLost_aadya                              1 0.0000019 0.037245
# - AP_totalPlayoutDelay_aadya                          1 0.0000046 0.037247
# - IT01V_jitter_aadya                                  1 0.0000067 0.037250
# - RIA_fractionLost_ellen                              1 0.0000085 0.037251
# - IT01V_packetsRecieved_ellen                         1 0.0000149 0.037258
# - IT01V_totalFreezesDuration_ellen                    1 0.0000241 0.037267
# - RIA_roundTripTime_ellen                             1 0.0000295 0.037272
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000390 0.037282
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000490 0.037292
# - ROA_roundTripTime_aadya                             1 0.0000899 0.037333
# - ROA_roundTripTime_ellen                             1 0.0001047 0.037348
# - OT01V_packetsSent_s_aadya                           1 0.0001058 0.037349
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0001325 0.037375
# - RIV_roundTripTime_ellen                             1 0.0001462 0.037389
# - OT01V_frameWidth_aadya                              1 0.0002133 0.037456
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0002158 0.037459
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0002242 0.037467
# - OT01V_totalPacketSendDelay_aadya                    1 0.0002473 0.037490
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0002523 0.037495
# - IT01V_frameWidth_ellen                              1 0.0002992 0.037542
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0003491 0.037592
# - IT01V_packetsRecieved_aadya                         1 0.0003859 0.037629
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0003939 0.037637
# - IT01V_totalFreezesDuration_aadya                    1 0.0004026 0.037646
# - IT01V_packetsLost_ellen                             1 0.0005136 0.037757
# - OT01V_packetsSent_s_ellen                           1 0.0006159 0.037859
# - RIA_fractionLost_aadya                              1 0.0006678 0.037911
# <none>                                                            0.037243
# - IT01V_frameWidth_aadya                              1 0.0008538 0.038097
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0008539 0.038097
# - IT01V_totalProcessingDelay_ellen                    1 0.0009625 0.038205
# - RIV_fractionLost_ellen                              1 0.0010027 0.038246
# - IT01V_framesPerSecond_aadya                         1 0.0010125 0.038255
# - AP_totalPlayoutDelay_ellen                          1 0.0011318 0.038375
# - IT01V_packetsLost_aadya                             1 0.0012930 0.038536
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0015747 0.038818
# - RIA_roundTripTime_aadya                             1 0.0016480 0.038891
# - RIV_roundTripTime_aadya                             1 0.0016559 0.038899
# - IT01V_totalProcessingDelay_aadya                    1 0.0017989 0.039042
# - OT01V_totalPacketSendDelay_ellen                    1 0.0019700 0.039213
# - OT01V_framesPerSecond_aadya                         1 0.0020926 0.039335
# - IT01V_framesPerSecond_ellen                         1 0.0023966 0.039640
# - OT01V_framesPerSecond_ellen                         1 0.0029567 0.040200
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0052211 0.042464
#                                                          AIC
# - IT01V_jitter_ellen                                 -613.11
# - RIV_fractionLost_aadya                             -613.10
# - AP_totalPlayoutDelay_aadya                         -613.10
# - IT01V_jitter_aadya                                 -613.09
# - RIA_fractionLost_ellen                             -613.09
# - IT01V_packetsRecieved_ellen                        -613.07
# - IT01V_totalFreezesDuration_ellen                   -613.05
# - RIA_roundTripTime_ellen                            -613.04
# - IT01V_bytesReceived_in_bits_s_ellen                -613.02
# - IT01V_jitterBufferDelay_emissions_aadya            -612.99
# - ROA_roundTripTime_aadya                            -612.89
# - ROA_roundTripTime_ellen                            -612.86
# - OT01V_packetsSent_s_aadya                          -612.85
# - IT01A_bytesReceived_in_bits_s_aadya                -612.79
# - RIV_roundTripTime_ellen                            -612.76
# - OT01V_frameWidth_aadya                             -612.60
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -612.59
# - IT01V_bytesReceived_in_bits_s_aadya                -612.57
# - OT01V_totalPacketSendDelay_aadya                   -612.51
# - IT01A_bytesReceived_in_bits_s_ellen                -612.50
# - IT01V_frameWidth_ellen                             -612.39
# - OT01V_bytesSent_in_bits_s_ellen                    -612.27
# - IT01V_packetsRecieved_aadya                        -612.18
# - IT01A_jitterBufferDelay_emissions_aadya            -612.16
# - IT01V_totalFreezesDuration_aadya                   -612.14
# - IT01V_packetsLost_ellen                            -611.88
# - OT01V_packetsSent_s_ellen                          -611.63
# - RIA_fractionLost_aadya                             -611.51
# <none>                                               -611.11
# - IT01V_frameWidth_aadya                             -611.07
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -611.07
# - IT01V_totalProcessingDelay_ellen                   -610.81
# - RIV_fractionLost_ellen                             -610.72
# - IT01V_framesPerSecond_aadya                        -610.70
# - AP_totalPlayoutDelay_ellen                         -610.41
# - IT01V_packetsLost_aadya                            -610.04
# - IT01V_jitterBufferDelay_emissions_ellen            -609.38
# - RIA_roundTripTime_aadya                            -609.21
# - RIV_roundTripTime_aadya                            -609.19
# - IT01V_totalProcessingDelay_aadya                   -608.86
# - OT01V_totalPacketSendDelay_ellen                   -608.47
# - OT01V_framesPerSecond_aadya                        -608.19
# - IT01V_framesPerSecond_ellen                        -607.50
# - OT01V_framesPerSecond_ellen                        -606.23
# - IT01A_jitterBufferDelay_emissions_ellen            -601.30
#
# Step:  AIC=-613.11
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq      RSS
# - RIV_fractionLost_aadya                              1 0.0000027 0.037246
# - AP_totalPlayoutDelay_aadya                          1 0.0000046 0.037248
# - IT01V_jitter_aadya                                  1 0.0000069 0.037250
# - RIA_fractionLost_ellen                              1 0.0000086 0.037252
# - IT01V_packetsRecieved_ellen                         1 0.0000151 0.037258
# - IT01V_totalFreezesDuration_ellen                    1 0.0000241 0.037267
# - RIA_roundTripTime_ellen                             1 0.0000300 0.037273
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000398 0.037283
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000500 0.037293
# - ROA_roundTripTime_aadya                             1 0.0000908 0.037334
# - OT01V_packetsSent_s_aadya                           1 0.0001070 0.037350
# - ROA_roundTripTime_ellen                             1 0.0001075 0.037350
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0001346 0.037377
# - RIV_roundTripTime_ellen                             1 0.0001540 0.037397
# - OT01V_frameWidth_aadya                              1 0.0002145 0.037457
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0002158 0.037459
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0002346 0.037477
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0002559 0.037499
# - IT01V_frameWidth_ellen                              1 0.0003028 0.037546
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0003543 0.037597
# - IT01V_totalFreezesDuration_aadya                    1 0.0004040 0.037647
# - IT01V_packetsRecieved_aadya                         1 0.0004102 0.037653
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0004349 0.037678
# - OT01V_totalPacketSendDelay_aadya                    1 0.0004660 0.037709
# - IT01V_packetsLost_ellen                             1 0.0005154 0.037758
# - OT01V_packetsSent_s_ellen                           1 0.0006270 0.037870
# - RIA_fractionLost_aadya                              1 0.0007083 0.037951
# <none>                                                            0.037243
# - IT01V_frameWidth_aadya                              1 0.0008538 0.038097
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0009471 0.038190
# - RIV_fractionLost_ellen                              1 0.0010309 0.038274
# - IT01V_totalProcessingDelay_ellen                    1 0.0010415 0.038284
# - AP_totalPlayoutDelay_ellen                          1 0.0012043 0.038447
# - IT01V_packetsLost_aadya                             1 0.0013141 0.038557
# - IT01V_framesPerSecond_aadya                         1 0.0013254 0.038568
# - RIA_roundTripTime_aadya                             1 0.0017122 0.038955
# - RIV_roundTripTime_aadya                             1 0.0017218 0.038965
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0018545 0.039097
# - IT01V_totalProcessingDelay_aadya                    1 0.0019685 0.039211
# - OT01V_totalPacketSendDelay_ellen                    1 0.0019715 0.039214
# - OT01V_framesPerSecond_aadya                         1 0.0021857 0.039429
# - IT01V_framesPerSecond_ellen                         1 0.0028206 0.040064
# - OT01V_framesPerSecond_ellen                         1 0.0033887 0.040632
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0054197 0.042663
#                                                          AIC
# - RIV_fractionLost_aadya                             -615.10
# - AP_totalPlayoutDelay_aadya                         -615.10
# - IT01V_jitter_aadya                                 -615.09
# - RIA_fractionLost_ellen                             -615.09
# - IT01V_packetsRecieved_ellen                        -615.07
# - IT01V_totalFreezesDuration_ellen                   -615.05
# - RIA_roundTripTime_ellen                            -615.04
# - IT01V_bytesReceived_in_bits_s_ellen                -615.01
# - IT01V_jitterBufferDelay_emissions_aadya            -614.99
# - ROA_roundTripTime_aadya                            -614.89
# - OT01V_packetsSent_s_aadya                          -614.85
# - ROA_roundTripTime_ellen                            -614.85
# - IT01A_bytesReceived_in_bits_s_aadya                -614.78
# - RIV_roundTripTime_ellen                            -614.74
# - OT01V_frameWidth_aadya                             -614.59
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -614.59
# - IT01V_bytesReceived_in_bits_s_aadya                -614.54
# - IT01A_bytesReceived_in_bits_s_ellen                -614.49
# - IT01V_frameWidth_ellen                             -614.38
# - OT01V_bytesSent_in_bits_s_ellen                    -614.26
# - IT01V_totalFreezesDuration_aadya                   -614.14
# - IT01V_packetsRecieved_aadya                        -614.12
# - IT01A_jitterBufferDelay_emissions_aadya            -614.06
# - OT01V_totalPacketSendDelay_aadya                   -613.99
# - IT01V_packetsLost_ellen                            -613.87
# - OT01V_packetsSent_s_ellen                          -613.61
# - RIA_fractionLost_aadya                             -613.41
# <none>                                               -613.11
# - IT01V_frameWidth_aadya                             -613.07
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -612.85
# - RIV_fractionLost_ellen                             -612.65
# - IT01V_totalProcessingDelay_ellen                   -612.63
# - AP_totalPlayoutDelay_ellen                         -612.25
# - IT01V_packetsLost_aadya                            -611.99
# - IT01V_framesPerSecond_aadya                        -611.96
# - RIA_roundTripTime_aadya                            -611.06
# - RIV_roundTripTime_aadya                            -611.04
# - IT01V_jitterBufferDelay_emissions_ellen            -610.74
# - IT01V_totalProcessingDelay_aadya                   -610.47
# - OT01V_totalPacketSendDelay_ellen                   -610.47
# - OT01V_framesPerSecond_aadya                        -609.98
# - IT01V_framesPerSecond_ellen                        -608.54
# - OT01V_framesPerSecond_ellen                        -607.27
# - IT01A_jitterBufferDelay_emissions_ellen            -602.88
#
# Step:  AIC=-615.1
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_ellen +
#     RIA_roundTripTime_aadya + ROA_roundTripTime_ellen + ROA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq      RSS
# - AP_totalPlayoutDelay_aadya                          1 0.0000057 0.037251
# - RIA_fractionLost_ellen                              1 0.0000085 0.037254
# - IT01V_jitter_aadya                                  1 0.0000102 0.037256
# - IT01V_packetsRecieved_ellen                         1 0.0000169 0.037262
# - IT01V_totalFreezesDuration_ellen                    1 0.0000233 0.037269
# - RIA_roundTripTime_ellen                             1 0.0000291 0.037275
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000447 0.037290
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000473 0.037293
# - ROA_roundTripTime_aadya                             1 0.0000902 0.037336
# - ROA_roundTripTime_ellen                             1 0.0001060 0.037352
# - OT01V_packetsSent_s_aadya                           1 0.0001175 0.037363
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0001499 0.037395
# - RIV_roundTripTime_ellen                             1 0.0001527 0.037398
# - OT01V_frameWidth_aadya                              1 0.0002148 0.037460
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0002229 0.037468
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0002412 0.037487
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0002765 0.037522
# - IT01V_frameWidth_ellen                              1 0.0003048 0.037550
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0003603 0.037606
# - IT01V_packetsRecieved_aadya                         1 0.0004226 0.037668
# - IT01V_totalFreezesDuration_aadya                    1 0.0004357 0.037681
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0004469 0.037692
# - OT01V_totalPacketSendDelay_aadya                    1 0.0004658 0.037711
# - IT01V_packetsLost_ellen                             1 0.0005276 0.037773
# - OT01V_packetsSent_s_ellen                           1 0.0006392 0.037885
# - RIA_fractionLost_aadya                              1 0.0007339 0.037979
# <none>                                                            0.037246
# - IT01V_frameWidth_aadya                              1 0.0009282 0.038174
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0010229 0.038268
# - RIV_fractionLost_ellen                              1 0.0010319 0.038278
# - IT01V_totalProcessingDelay_ellen                    1 0.0010963 0.038342
# - AP_totalPlayoutDelay_ellen                          1 0.0012062 0.038452
# - IT01V_packetsLost_aadya                             1 0.0013154 0.038561
# - IT01V_framesPerSecond_aadya                         1 0.0013527 0.038598
# - RIA_roundTripTime_aadya                             1 0.0017125 0.038958
# - RIV_roundTripTime_aadya                             1 0.0017221 0.038968
# - IT01V_totalProcessingDelay_aadya                    1 0.0019667 0.039212
# - OT01V_totalPacketSendDelay_ellen                    1 0.0019731 0.039219
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0021103 0.039356
# - OT01V_framesPerSecond_aadya                         1 0.0023647 0.039610
# - IT01V_framesPerSecond_ellen                         1 0.0030489 0.040295
# - OT01V_framesPerSecond_ellen                         1 0.0034201 0.040666
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0054839 0.042730
#                                                          AIC
# - AP_totalPlayoutDelay_aadya                         -617.09
# - RIA_fractionLost_ellen                             -617.08
# - IT01V_jitter_aadya                                 -617.08
# - IT01V_packetsRecieved_ellen                        -617.06
# - IT01V_totalFreezesDuration_ellen                   -617.05
# - RIA_roundTripTime_ellen                            -617.03
# - IT01V_bytesReceived_in_bits_s_ellen                -616.99
# - IT01V_jitterBufferDelay_emissions_aadya            -616.99
# - ROA_roundTripTime_aadya                            -616.89
# - ROA_roundTripTime_ellen                            -616.85
# - OT01V_packetsSent_s_aadya                          -616.82
# - IT01A_bytesReceived_in_bits_s_aadya                -616.74
# - RIV_roundTripTime_ellen                            -616.73
# - OT01V_frameWidth_aadya                             -616.59
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -616.57
# - IT01V_bytesReceived_in_bits_s_aadya                -616.52
# - IT01A_bytesReceived_in_bits_s_ellen                -616.44
# - IT01V_frameWidth_ellen                             -616.37
# - OT01V_bytesSent_in_bits_s_ellen                    -616.24
# - IT01V_packetsRecieved_aadya                        -616.09
# - IT01V_totalFreezesDuration_aadya                   -616.06
# - IT01A_jitterBufferDelay_emissions_aadya            -616.03
# - OT01V_totalPacketSendDelay_aadya                   -615.98
# - IT01V_packetsLost_ellen                            -615.84
# - OT01V_packetsSent_s_ellen                          -615.57
# - RIA_fractionLost_aadya                             -615.35
# <none>                                               -615.10
# - IT01V_frameWidth_aadya                             -614.89
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -614.66
# - RIV_fractionLost_ellen                             -614.64
# - IT01V_totalProcessingDelay_ellen                   -614.49
# - AP_totalPlayoutDelay_ellen                         -614.23
# - IT01V_packetsLost_aadya                            -613.98
# - IT01V_framesPerSecond_aadya                        -613.89
# - RIA_roundTripTime_aadya                            -613.06
# - RIV_roundTripTime_aadya                            -613.03
# - IT01V_totalProcessingDelay_aadya                   -612.47
# - OT01V_totalPacketSendDelay_ellen                   -612.46
# - IT01V_jitterBufferDelay_emissions_ellen            -612.14
# - OT01V_framesPerSecond_aadya                        -611.56
# - IT01V_framesPerSecond_ellen                        -610.02
# - OT01V_framesPerSecond_ellen                        -609.20
# - IT01A_jitterBufferDelay_emissions_ellen            -604.74
#
# Step:  AIC=-617.09
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_ellen +
#     RIA_roundTripTime_aadya + ROA_roundTripTime_ellen + ROA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq      RSS
# - RIA_fractionLost_ellen                              1 0.0000070 0.037258
# - IT01V_jitter_aadya                                  1 0.0000109 0.037262
# - IT01V_packetsRecieved_ellen                         1 0.0000182 0.037269
# - IT01V_totalFreezesDuration_ellen                    1 0.0000262 0.037277
# - RIA_roundTripTime_ellen                             1 0.0000356 0.037287
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000452 0.037296
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000474 0.037299
# - ROA_roundTripTime_aadya                             1 0.0000861 0.037337
# - OT01V_packetsSent_s_aadya                           1 0.0001119 0.037363
# - ROA_roundTripTime_ellen                             1 0.0001131 0.037364
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0001457 0.037397
# - RIV_roundTripTime_ellen                             1 0.0001858 0.037437
# - OT01V_frameWidth_aadya                              1 0.0002156 0.037467
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0002173 0.037469
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0002708 0.037522
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0002715 0.037523
# - IT01V_frameWidth_ellen                              1 0.0003059 0.037557
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0004229 0.037674
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0004517 0.037703
# - IT01V_totalFreezesDuration_aadya                    1 0.0004530 0.037704
# - IT01V_packetsRecieved_aadya                         1 0.0004704 0.037722
# - OT01V_totalPacketSendDelay_aadya                    1 0.0004766 0.037728
# - IT01V_packetsLost_ellen                             1 0.0005260 0.037777
# - RIA_fractionLost_aadya                              1 0.0007414 0.037993
# - OT01V_packetsSent_s_ellen                           1 0.0007434 0.037995
# <none>                                                            0.037251
# - IT01V_frameWidth_aadya                              1 0.0009266 0.038178
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0010314 0.038283
# - IT01V_totalProcessingDelay_ellen                    1 0.0010915 0.038343
# - RIV_fractionLost_ellen                              1 0.0011564 0.038408
# - IT01V_packetsLost_aadya                             1 0.0013101 0.038561
# - IT01V_framesPerSecond_aadya                         1 0.0013816 0.038633
# - RIA_roundTripTime_aadya                             1 0.0017407 0.038992
# - RIV_roundTripTime_aadya                             1 0.0017498 0.039001
# - IT01V_totalProcessingDelay_aadya                    1 0.0019611 0.039212
# - OT01V_totalPacketSendDelay_ellen                    1 0.0019741 0.039225
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0021048 0.039356
# - OT01V_framesPerSecond_aadya                         1 0.0024486 0.039700
# - AP_totalPlayoutDelay_ellen                          1 0.0024704 0.039722
# - IT01V_framesPerSecond_ellen                         1 0.0030894 0.040341
# - OT01V_framesPerSecond_ellen                         1 0.0037883 0.041040
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0056066 0.042858
#                                                          AIC
# - RIA_fractionLost_ellen                             -619.07
# - IT01V_jitter_aadya                                 -619.06
# - IT01V_packetsRecieved_ellen                        -619.05
# - IT01V_totalFreezesDuration_ellen                   -619.03
# - RIA_roundTripTime_ellen                            -619.00
# - IT01V_bytesReceived_in_bits_s_ellen                -618.98
# - IT01V_jitterBufferDelay_emissions_aadya            -618.97
# - ROA_roundTripTime_aadya                            -618.88
# - OT01V_packetsSent_s_aadya                          -618.82
# - ROA_roundTripTime_ellen                            -618.82
# - IT01A_bytesReceived_in_bits_s_aadya                -618.74
# - RIV_roundTripTime_ellen                            -618.64
# - OT01V_frameWidth_aadya                             -618.57
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -618.57
# - IT01A_bytesReceived_in_bits_s_ellen                -618.44
# - IT01V_bytesReceived_in_bits_s_aadya                -618.44
# - IT01V_frameWidth_ellen                             -618.35
# - OT01V_bytesSent_in_bits_s_ellen                    -618.07
# - IT01A_jitterBufferDelay_emissions_aadya            -618.00
# - IT01V_totalFreezesDuration_aadya                   -618.00
# - IT01V_packetsRecieved_aadya                        -617.96
# - OT01V_totalPacketSendDelay_aadya                   -617.95
# - IT01V_packetsLost_ellen                            -617.83
# - RIA_fractionLost_aadya                             -617.32
# - OT01V_packetsSent_s_ellen                          -617.31
# <none>                                               -617.09
# - IT01V_frameWidth_aadya                             -616.88
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -616.63
# - IT01V_totalProcessingDelay_ellen                   -616.49
# - RIV_fractionLost_ellen                             -616.34
# - IT01V_packetsLost_aadya                            -615.98
# - IT01V_framesPerSecond_aadya                        -615.81
# - RIA_roundTripTime_aadya                            -614.98
# - RIV_roundTripTime_aadya                            -614.96
# - IT01V_totalProcessingDelay_aadya                   -614.47
# - OT01V_totalPacketSendDelay_ellen                   -614.44
# - IT01V_jitterBufferDelay_emissions_ellen            -614.14
# - OT01V_framesPerSecond_aadya                        -613.36
# - AP_totalPlayoutDelay_ellen                         -613.31
# - IT01V_framesPerSecond_ellen                        -611.92
# - OT01V_framesPerSecond_ellen                        -610.37
# - IT01A_jitterBufferDelay_emissions_ellen            -606.47
#
# Step:  AIC=-619.07
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIA_fractionLost_aadya + RIA_roundTripTime_ellen + RIA_roundTripTime_aadya +
#     ROA_roundTripTime_ellen + ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq      RSS
# - IT01V_jitter_aadya                                  1 0.0000126 0.037271
# - IT01V_packetsRecieved_ellen                         1 0.0000168 0.037275
# - IT01V_totalFreezesDuration_ellen                    1 0.0000277 0.037286
# - RIA_roundTripTime_ellen                             1 0.0000354 0.037294
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000427 0.037301
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000448 0.037303
# - ROA_roundTripTime_aadya                             1 0.0000913 0.037350
# - OT01V_packetsSent_s_aadya                           1 0.0001078 0.037366
# - ROA_roundTripTime_ellen                             1 0.0001182 0.037376
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0001416 0.037400
# - RIV_roundTripTime_ellen                             1 0.0001974 0.037456
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0002119 0.037470
# - OT01V_frameWidth_aadya                              1 0.0002146 0.037473
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0002660 0.037524
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0002741 0.037532
# - IT01V_frameWidth_ellen                              1 0.0003039 0.037562
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0004514 0.037710
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0004537 0.037712
# - IT01V_packetsRecieved_aadya                         1 0.0004692 0.037727
# - OT01V_totalPacketSendDelay_aadya                    1 0.0004698 0.037728
# - IT01V_totalFreezesDuration_aadya                    1 0.0004728 0.037731
# - IT01V_packetsLost_ellen                             1 0.0005287 0.037787
# - RIA_fractionLost_aadya                              1 0.0007477 0.038006
# - OT01V_packetsSent_s_ellen                           1 0.0007812 0.038039
# <none>                                                            0.037258
# - IT01V_frameWidth_aadya                              1 0.0009720 0.038230
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0010273 0.038286
# - IT01V_totalProcessingDelay_ellen                    1 0.0011100 0.038368
# - RIV_fractionLost_ellen                              1 0.0011734 0.038432
# - IT01V_packetsLost_aadya                             1 0.0013069 0.038565
# - IT01V_framesPerSecond_aadya                         1 0.0014096 0.038668
# - RIA_roundTripTime_aadya                             1 0.0017620 0.039020
# - RIV_roundTripTime_aadya                             1 0.0017708 0.039029
# - IT01V_totalProcessingDelay_aadya                    1 0.0019577 0.039216
# - OT01V_totalPacketSendDelay_ellen                    1 0.0019728 0.039231
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0021197 0.039378
# - OT01V_framesPerSecond_aadya                         1 0.0024450 0.039703
# - AP_totalPlayoutDelay_ellen                          1 0.0025275 0.039786
# - IT01V_framesPerSecond_ellen                         1 0.0030907 0.040349
# - OT01V_framesPerSecond_ellen                         1 0.0038426 0.041101
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0056080 0.042866
#                                                          AIC
# - IT01V_jitter_aadya                                 -621.04
# - IT01V_packetsRecieved_ellen                        -621.03
# - IT01V_totalFreezesDuration_ellen                   -621.01
# - RIA_roundTripTime_ellen                            -620.99
# - IT01V_bytesReceived_in_bits_s_ellen                -620.97
# - IT01V_jitterBufferDelay_emissions_aadya            -620.96
# ...
# - OT01V_totalPacketSendDelay_ellen                   -639.95
# - RIV_fractionLost_ellen                             -639.59
# - RIA_fractionLost_aadya                             -638.07
# - IT01V_framesPerSecond_ellen                        -637.49
# - OT01V_framesPerSecond_aadya                        -635.41
# - OT01V_framesPerSecond_ellen                        -632.67
# - RIV_roundTripTime_aadya                            -631.22
# - RIA_roundTripTime_aadya                            -631.11
# - IT01A_jitterBufferDelay_emissions_ellen            -620.25
#
# Step:  AIC=-646.89
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_frameWidth_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_bytesSent_in_bits_s_ellen + OT01V_framesPerSecond_ellen +
#     OT01V_framesPerSecond_aadya + OT01V_totalPacketSendDelay_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq      RSS
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0004995 0.042219
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0006494 0.042369
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0007746 0.042494
# <none>                                                            0.041720
# - OT01V_packetsSent_s_ellen                           1 0.0009603 0.042680
# - IT01V_frameWidth_aadya                              1 0.0011048 0.042825
# - IT01V_packetsLost_aadya                             1 0.0012930 0.043013
# - IT01V_totalProcessingDelay_ellen                    1 0.0015170 0.043237
# - IT01V_framesPerSecond_aadya                         1 0.0017480 0.043468
# - IT01V_totalProcessingDelay_aadya                    1 0.0024521 0.044172
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0031146 0.044834
# - AP_totalPlayoutDelay_ellen                          1 0.0034230 0.045143
# - OT01V_totalPacketSendDelay_ellen                    1 0.0036245 0.045344
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0039901 0.045710
# - RIV_fractionLost_ellen                              1 0.0043806 0.046100
# - IT01V_framesPerSecond_ellen                         1 0.0047303 0.046450
# - OT01V_framesPerSecond_aadya                         1 0.0057349 0.047455
# - RIA_fractionLost_aadya                              1 0.0061807 0.047900
# - OT01V_framesPerSecond_ellen                         1 0.0075084 0.049228
# - RIV_roundTripTime_aadya                             1 0.0081508 0.049871
# - RIA_roundTripTime_aadya                             1 0.0082050 0.049925
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0143793 0.056099
#                                                          AIC
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -647.82
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -647.50
# - OT01V_bytesSent_in_bits_s_ellen                    -647.24
# <none>                                               -646.89
# - OT01V_packetsSent_s_ellen                          -646.85
# - IT01V_frameWidth_aadya                             -646.54
# - IT01V_packetsLost_aadya                            -646.15
# - IT01V_totalProcessingDelay_ellen                   -645.68
# - IT01V_framesPerSecond_aadya                        -645.20
# - IT01V_totalProcessingDelay_aadya                   -643.75
# - IT01A_jitterBufferDelay_emissions_aadya            -642.41
# - AP_totalPlayoutDelay_ellen                         -641.80
# - OT01V_totalPacketSendDelay_ellen                   -641.40
# - IT01V_jitterBufferDelay_emissions_ellen            -640.67
# - RIV_fractionLost_ellen                             -639.91
# - IT01V_framesPerSecond_ellen                        -639.23
# - OT01V_framesPerSecond_aadya                        -637.30
# - RIA_fractionLost_aadya                             -636.46
# - OT01V_framesPerSecond_ellen                        -634.00
# - RIV_roundTripTime_aadya                            -632.83
# - RIA_roundTripTime_aadya                            -632.73
# - IT01A_jitterBufferDelay_emissions_ellen            -622.24
#
# Step:  AIC=-647.82
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_frameWidth_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_bytesSent_in_bits_s_ellen + OT01V_framesPerSecond_ellen +
#     OT01V_framesPerSecond_aadya + OT01V_totalPacketSendDelay_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + RIV_roundTripTime_aadya +
#     RIV_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq      RSS
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0006843 0.042903
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0007900 0.043009
# <none>                                                            0.042219
# - OT01V_packetsSent_s_ellen                           1 0.0009979 0.043217
# - IT01V_packetsLost_aadya                             1 0.0011939 0.043413
# - IT01V_frameWidth_aadya                              1 0.0013295 0.043549
# - IT01V_framesPerSecond_aadya                         1 0.0020293 0.044249
# - IT01V_totalProcessingDelay_aadya                    1 0.0020307 0.044250
# - IT01V_totalProcessingDelay_ellen                    1 0.0027335 0.044953
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0029637 0.045183
# - OT01V_totalPacketSendDelay_ellen                    1 0.0037365 0.045956
# - IT01V_framesPerSecond_ellen                         1 0.0042357 0.046455
# - RIV_fractionLost_ellen                              1 0.0045986 0.046818
# - AP_totalPlayoutDelay_ellen                          1 0.0049196 0.047139
# - OT01V_framesPerSecond_aadya                         1 0.0052502 0.047469
# - RIA_fractionLost_aadya                              1 0.0067286 0.048948
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0074733 0.049693
# - OT01V_framesPerSecond_ellen                         1 0.0076250 0.049844
# - RIV_roundTripTime_aadya                             1 0.0079973 0.050217
# - RIA_roundTripTime_aadya                             1 0.0080437 0.050263
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0139669 0.056186
#                                                          AIC
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -648.38
# - OT01V_bytesSent_in_bits_s_ellen                    -648.15
# <none>                                               -647.82
# - OT01V_packetsSent_s_ellen                          -647.72
# - IT01V_packetsLost_aadya                            -647.31
# - IT01V_frameWidth_aadya                             -647.03
# - IT01V_framesPerSecond_aadya                        -645.60
# - IT01V_totalProcessingDelay_aadya                   -645.59
# - IT01V_totalProcessingDelay_ellen                   -644.18
# - IT01A_jitterBufferDelay_emissions_aadya            -643.72
# - OT01V_totalPacketSendDelay_ellen                   -642.19
# - IT01V_framesPerSecond_ellen                        -641.22
# - RIV_fractionLost_ellen                             -640.52
# - AP_totalPlayoutDelay_ellen                         -639.90
# - OT01V_framesPerSecond_aadya                        -639.27
# - RIA_fractionLost_aadya                             -636.51
# - IT01V_jitterBufferDelay_emissions_ellen            -635.15
# - OT01V_framesPerSecond_ellen                        -634.88
# - RIV_roundTripTime_aadya                            -634.21
# - RIA_roundTripTime_aadya                            -634.13
# - IT01A_jitterBufferDelay_emissions_ellen            -624.10
#
# Step:  AIC=-648.38
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_frameWidth_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_bytesSent_in_bits_s_ellen + OT01V_framesPerSecond_ellen +
#     OT01V_framesPerSecond_aadya + OT01V_totalPacketSendDelay_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen
#
#                                           Df Sum of Sq      RSS     AIC
# - IT01V_frameWidth_aadya                   1 0.0007155 0.043619 -648.89
# - IT01V_packetsLost_aadya                  1 0.0008159 0.043719 -648.68
# <none>                                                 0.042903 -648.38
# - OT01V_bytesSent_in_bits_s_ellen          1 0.0010014 0.043905 -648.30
# - OT01V_packetsSent_s_ellen                1 0.0011193 0.044023 -648.06
# - IT01V_totalProcessingDelay_aadya         1 0.0014113 0.044315 -647.46
# - IT01V_framesPerSecond_aadya              1 0.0018624 0.044766 -646.55
# - IT01V_totalProcessingDelay_ellen         1 0.0023430 0.045246 -645.59
# - IT01A_jitterBufferDelay_emissions_aadya  1 0.0025996 0.045503 -645.08
# - OT01V_totalPacketSendDelay_ellen         1 0.0038811 0.046785 -642.58
# - RIV_fractionLost_ellen                   1 0.0040809 0.046984 -642.20
# - AP_totalPlayoutDelay_ellen               1 0.0042722 0.047176 -641.83
# - IT01V_framesPerSecond_ellen              1 0.0044016 0.047305 -641.59
# - OT01V_framesPerSecond_aadya              1 0.0056706 0.048574 -639.20
# - RIA_fractionLost_aadya                   1 0.0063976 0.049301 -637.87
# - IT01V_jitterBufferDelay_emissions_ellen  1 0.0069269 0.049830 -636.90
# - OT01V_framesPerSecond_ellen              1 0.0076353 0.050539 -635.63
# - RIV_roundTripTime_aadya                  1 0.0088217 0.051725 -633.55
# - RIA_roundTripTime_aadya                  1 0.0088807 0.051784 -633.44
# - IT01A_jitterBufferDelay_emissions_ellen  1 0.0134706 0.056374 -625.80
#
# Step:  AIC=-648.89
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + RIV_roundTripTime_aadya +
#     RIV_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                           Df Sum of Sq      RSS     AIC
# <none>                                                 0.043619 -648.89
# - IT01V_totalProcessingDelay_aadya         1 0.0009873 0.044606 -648.87
# - IT01V_framesPerSecond_aadya              1 0.0014475 0.045066 -647.95
# - IT01V_totalProcessingDelay_ellen         1 0.0017130 0.045332 -647.42
# - OT01V_packetsSent_s_ellen                1 0.0017848 0.045404 -647.28
# - OT01V_bytesSent_in_bits_s_ellen          1 0.0019082 0.045527 -647.03
# - IT01A_jitterBufferDelay_emissions_aadya  1 0.0021923 0.045811 -646.47
# - IT01V_packetsLost_aadya                  1 0.0022852 0.045904 -646.29
# - AP_totalPlayoutDelay_ellen               1 0.0036785 0.047298 -643.60
# - RIV_fractionLost_ellen                   1 0.0037084 0.047327 -643.54
# - IT01V_framesPerSecond_ellen              1 0.0042531 0.047872 -642.51
# - OT01V_framesPerSecond_aadya              1 0.0057863 0.049405 -639.68
# - RIA_fractionLost_aadya                   1 0.0059575 0.049576 -639.36
# - IT01V_jitterBufferDelay_emissions_ellen  1 0.0063084 0.049927 -638.73
# - OT01V_totalPacketSendDelay_ellen         1 0.0070126 0.050632 -637.47
# - OT01V_framesPerSecond_ellen              1 0.0073795 0.050998 -636.82
# - RIV_roundTripTime_aadya                  1 0.0081143 0.051733 -635.53
# - RIA_roundTripTime_aadya                  1 0.0081728 0.051792 -635.43
# - IT01A_jitterBufferDelay_emissions_ellen  1 0.0137094 0.057328 -626.29
# Call:
# lm(formula = logistic_transformed_score ~ IT01V_packetsLost_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_bytesSent_in_bits_s_ellen + OT01V_framesPerSecond_ellen +
#     OT01V_framesPerSecond_aadya + OT01V_totalPacketSendDelay_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen, data = trim_data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.055596 -0.012933  0.000302  0.014761  0.055469
#
# Coefficients:
#                                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)                              0.623985   0.002613 238.829  < 2e-16
# IT01V_packetsLost_aadya                  0.005807   0.003011   1.929 0.057772
# IT01V_framesPerSecond_ellen             -0.041048   0.015601  -2.631 0.010431
# IT01V_framesPerSecond_aadya             -0.012798   0.008338  -1.535 0.129231
# IT01V_totalProcessingDelay_ellen         0.010124   0.006063   1.670 0.099356
# IT01V_totalProcessingDelay_aadya        -0.004341   0.003425  -1.268 0.209057
# IT01V_jitterBufferDelay_emissions_ellen -0.026814   0.008368  -3.204 0.002028
# IT01A_jitterBufferDelay_emissions_ellen -0.015819   0.003349  -4.724 1.13e-05
# IT01A_jitterBufferDelay_emissions_aadya  0.007893   0.004178   1.889 0.062972
# OT01V_packetsSent_s_ellen               -0.126380   0.074146  -1.704 0.092666
# OT01V_bytesSent_in_bits_s_ellen          0.126338   0.071686   1.762 0.082308
# OT01V_framesPerSecond_ellen              0.031527   0.009097   3.466 0.000901
# OT01V_framesPerSecond_aadya              0.044957   0.014649   3.069 0.003041
# OT01V_totalPacketSendDelay_ellen         0.012132   0.003591   3.379 0.001186
# RIV_roundTripTime_aadya                  0.743267   0.204516   3.634 0.000524
# RIV_fractionLost_ellen                  -0.007281   0.002963  -2.457 0.016460
# RIA_fractionLost_aadya                   0.010542   0.003385   3.114 0.002661
# RIA_roundTripTime_aadya                 -0.745371   0.204360  -3.647 0.000502
# AP_totalPlayoutDelay_ellen              -0.008013   0.003275  -2.447 0.016883
#
# (Intercept)                             ***
# IT01V_packetsLost_aadya                 .
# IT01V_framesPerSecond_ellen             *
# IT01V_framesPerSecond_aadya
# IT01V_totalProcessingDelay_ellen        .
# IT01V_totalProcessingDelay_aadya
# IT01V_jitterBufferDelay_emissions_ellen **
# IT01A_jitterBufferDelay_emissions_ellen ***
# IT01A_jitterBufferDelay_emissions_aadya .
# OT01V_packetsSent_s_ellen               .
# OT01V_bytesSent_in_bits_s_ellen         .
# OT01V_framesPerSecond_ellen             ***
# OT01V_framesPerSecond_aadya             **
# OT01V_totalPacketSendDelay_ellen        **
# RIV_roundTripTime_aadya                 ***
# RIV_fractionLost_ellen                  *
# RIA_fractionLost_aadya                  **
# RIA_roundTripTime_aadya                 ***
# AP_totalPlayoutDelay_ellen              *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.02479 on 71 degrees of freedom
# Multiple R-squared:  0.6472,	Adjusted R-squared:  0.5578
# F-statistic: 7.236 on 18 and 71 DF,  p-value: 4.84e-10

# %% [markdown]
# ## BIC

# %%
fit_bic<- step(model, k = log(length(trim_data$logistic_transformed_score)))
#summary(fit_aic)

bic_predictions <- predict(fit_bic, trim_data)
# par(bg = "white")
# options(repr.plot.width = 10, repr.plot.height = 6)
# plot(predictions, trim_data$logistic_transformed_score, 
#      main = "Prediction performance of AIC stepfit model", 
#      xlab = "Predicted values", ylab = "Recorded values")

# Calculate Mean Squared Error (MSE)
mse_bic <- mean((trim_data$logistic_transformed_score - bic_predictions)^2)
# Out:
# Start:  AIC=-494.12
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_frameHeight_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_ellen + IT01V_bytesReceived_in_bits_s_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitter_ellen + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=-494.12
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_frameHeight_aadya +
#     IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_bytesReceived_in_bits_s_ellen + IT01V_bytesReceived_in_bits_s_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitter_ellen + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=-494.12
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_frameHeight_ellen + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#
# Step:  AIC=-494.12
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_aadya +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq      RSS
# - OT01V_bytesSent_in_bits_s_aadya                     1 0.0000000 0.037243
# - IT01V_jitter_ellen                                  1 0.0000000 0.037243
# - RIV_fractionLost_aadya                              1 0.0000019 0.037245
# - AP_totalPlayoutDelay_aadya                          1 0.0000045 0.037247
# - OT01V_packetsSent_s_aadya                           1 0.0000057 0.037249
# - IT01V_jitter_aadya                                  1 0.0000065 0.037249
# - RIA_fractionLost_ellen                              1 0.0000083 0.037251
# - IT01V_packetsRecieved_ellen                         1 0.0000145 0.037257
# - IT01V_totalFreezesDuration_ellen                    1 0.0000240 0.037267
# - RIA_roundTripTime_ellen                             1 0.0000295 0.037272
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000372 0.037280
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000486 0.037291
# - ROA_roundTripTime_aadya                             1 0.0000733 0.037316
# - ROA_roundTripTime_ellen                             1 0.0001044 0.037347
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0001272 0.037370
# - RIV_roundTripTime_ellen                             1 0.0001388 0.037382
# - OT01V_frameWidth_aadya                              1 0.0001973 0.037440
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0002152 0.037458
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0002230 0.037466
# - OT01V_totalPacketSendDelay_aadya                    1 0.0002349 0.037478
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0002518 0.037495
# - IT01V_frameWidth_ellen                              1 0.0002851 0.037528
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0003362 0.037579
# - IT01V_packetsRecieved_aadya                         1 0.0003859 0.037629
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0003939 0.037637
# - IT01V_totalFreezesDuration_aadya                    1 0.0004026 0.037645
# - IT01V_packetsLost_ellen                             1 0.0005021 0.037745
# - OT01V_packetsSent_s_ellen                           1 0.0005817 0.037825
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0006520 0.037895
# - RIA_fractionLost_aadya                              1 0.0006640 0.037907
# - IT01V_frameWidth_aadya                              1 0.0007435 0.037986
# - IT01V_totalProcessingDelay_ellen                    1 0.0009349 0.038178
# - IT01V_framesPerSecond_aadya                         1 0.0009831 0.038226
# - RIV_fractionLost_ellen                              1 0.0009893 0.038232
# - AP_totalPlayoutDelay_ellen                          1 0.0010284 0.038271
# - IT01V_packetsLost_aadya                             1 0.0012930 0.038536
# - RIA_roundTripTime_aadya                             1 0.0013295 0.038572
# - RIV_roundTripTime_aadya                             1 0.0013346 0.038578
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0015393 0.038782
# - IT01V_totalProcessingDelay_aadya                    1 0.0017221 0.038965
# <none>                                                            0.037243
# - OT01V_totalPacketSendDelay_ellen                    1 0.0019692 0.039212
# - OT01V_framesPerSecond_aadya                         1 0.0020909 0.039334
# - IT01V_framesPerSecond_ellen                         1 0.0023021 0.039545
# - OT01V_framesPerSecond_ellen                         1 0.0029496 0.040192
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0050473 0.042290
#                                                          AIC
# - OT01V_bytesSent_in_bits_s_aadya                    -498.62
# - IT01V_jitter_ellen                                 -498.62
# - RIV_fractionLost_aadya                             -498.61
# - AP_totalPlayoutDelay_aadya                         -498.61
# - OT01V_packetsSent_s_aadya                          -498.60
# - IT01V_jitter_aadya                                 -498.60
# - RIA_fractionLost_ellen                             -498.60
# - IT01V_packetsRecieved_ellen                        -498.58
# - IT01V_totalFreezesDuration_ellen                   -498.56
# - RIA_roundTripTime_ellen                            -498.55
# - IT01V_bytesReceived_in_bits_s_ellen                -498.53
# - IT01V_jitterBufferDelay_emissions_aadya            -498.50
# - ROA_roundTripTime_aadya                            -498.44
# - ROA_roundTripTime_ellen                            -498.37
# - IT01A_bytesReceived_in_bits_s_aadya                -498.31
# - RIV_roundTripTime_ellen                            -498.28
# - OT01V_frameWidth_aadya                             -498.14
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -498.10
# - IT01V_bytesReceived_in_bits_s_aadya                -498.08
# - OT01V_totalPacketSendDelay_aadya                   -498.05
# - IT01A_bytesReceived_in_bits_s_ellen                -498.01
# - IT01V_frameWidth_ellen                             -497.93
# - OT01V_bytesSent_in_bits_s_ellen                    -497.81
# - IT01V_packetsRecieved_aadya                        -497.69
# - IT01A_jitterBufferDelay_emissions_aadya            -497.67
# - IT01V_totalFreezesDuration_aadya                   -497.65
# - IT01V_packetsLost_ellen                            -497.41
# - OT01V_packetsSent_s_ellen                          -497.22
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -497.06
# - RIA_fractionLost_aadya                             -497.03
# - IT01V_frameWidth_aadya                             -496.84
# - IT01V_totalProcessingDelay_ellen                   -496.39
# - IT01V_framesPerSecond_aadya                        -496.27
# - RIV_fractionLost_ellen                             -496.26
# - AP_totalPlayoutDelay_ellen                         -496.17
# - IT01V_packetsLost_aadya                            -495.55
# - RIA_roundTripTime_aadya                            -495.46
# - RIV_roundTripTime_aadya                            -495.45
# - IT01V_jitterBufferDelay_emissions_ellen            -494.97
# - IT01V_totalProcessingDelay_aadya                   -494.55
# <none>                                               -494.12
# - OT01V_totalPacketSendDelay_ellen                   -493.98
# - OT01V_framesPerSecond_aadya                        -493.70
# - IT01V_framesPerSecond_ellen                        -493.22
# - OT01V_framesPerSecond_ellen                        -491.76
# - IT01A_jitterBufferDelay_emissions_ellen            -487.18
#
# Step:  AIC=-498.62
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq      RSS
# - IT01V_jitter_ellen                                  1 0.0000000 0.037243
# - RIV_fractionLost_aadya                              1 0.0000019 0.037245
# - AP_totalPlayoutDelay_aadya                          1 0.0000046 0.037247
# - IT01V_jitter_aadya                                  1 0.0000067 0.037250
# - RIA_fractionLost_ellen                              1 0.0000085 0.037251
# - IT01V_packetsRecieved_ellen                         1 0.0000149 0.037258
# - IT01V_totalFreezesDuration_ellen                    1 0.0000241 0.037267
# - RIA_roundTripTime_ellen                             1 0.0000295 0.037272
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000390 0.037282
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000490 0.037292
# - ROA_roundTripTime_aadya                             1 0.0000899 0.037333
# - ROA_roundTripTime_ellen                             1 0.0001047 0.037348
# - OT01V_packetsSent_s_aadya                           1 0.0001058 0.037349
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0001325 0.037375
# - RIV_roundTripTime_ellen                             1 0.0001462 0.037389
# - OT01V_frameWidth_aadya                              1 0.0002133 0.037456
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0002158 0.037459
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0002242 0.037467
# - OT01V_totalPacketSendDelay_aadya                    1 0.0002473 0.037490
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0002523 0.037495
# - IT01V_frameWidth_ellen                              1 0.0002992 0.037542
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0003491 0.037592
# - IT01V_packetsRecieved_aadya                         1 0.0003859 0.037629
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0003939 0.037637
# - IT01V_totalFreezesDuration_aadya                    1 0.0004026 0.037646
# - IT01V_packetsLost_ellen                             1 0.0005136 0.037757
# - OT01V_packetsSent_s_ellen                           1 0.0006159 0.037859
# - RIA_fractionLost_aadya                              1 0.0006678 0.037911
# - IT01V_frameWidth_aadya                              1 0.0008538 0.038097
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0008539 0.038097
# - IT01V_totalProcessingDelay_ellen                    1 0.0009625 0.038205
# - RIV_fractionLost_ellen                              1 0.0010027 0.038246
# - IT01V_framesPerSecond_aadya                         1 0.0010125 0.038255
# - AP_totalPlayoutDelay_ellen                          1 0.0011318 0.038375
# - IT01V_packetsLost_aadya                             1 0.0012930 0.038536
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0015747 0.038818
# - RIA_roundTripTime_aadya                             1 0.0016480 0.038891
# - RIV_roundTripTime_aadya                             1 0.0016559 0.038899
# - IT01V_totalProcessingDelay_aadya                    1 0.0017989 0.039042
# <none>                                                            0.037243
# - OT01V_totalPacketSendDelay_ellen                    1 0.0019700 0.039213
# - OT01V_framesPerSecond_aadya                         1 0.0020926 0.039335
# - IT01V_framesPerSecond_ellen                         1 0.0023966 0.039640
# - OT01V_framesPerSecond_ellen                         1 0.0029567 0.040200
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0052211 0.042464
#                                                          AIC
# - IT01V_jitter_ellen                                 -503.12
# - RIV_fractionLost_aadya                             -503.11
# - AP_totalPlayoutDelay_aadya                         -503.11
# - IT01V_jitter_aadya                                 -503.10
# - RIA_fractionLost_ellen                             -503.10
# - IT01V_packetsRecieved_ellen                        -503.08
# - IT01V_totalFreezesDuration_ellen                   -503.06
# - RIA_roundTripTime_ellen                            -503.05
# - IT01V_bytesReceived_in_bits_s_ellen                -503.02
# - IT01V_jitterBufferDelay_emissions_aadya            -503.00
# - ROA_roundTripTime_aadya                            -502.90
# - ROA_roundTripTime_ellen                            -502.87
# - OT01V_packetsSent_s_aadya                          -502.86
# - IT01A_bytesReceived_in_bits_s_aadya                -502.80
# - RIV_roundTripTime_ellen                            -502.77
# - OT01V_frameWidth_aadya                             -502.60
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -502.60
# - IT01V_bytesReceived_in_bits_s_aadya                -502.58
# - OT01V_totalPacketSendDelay_aadya                   -502.52
# - IT01A_bytesReceived_in_bits_s_ellen                -502.51
# - IT01V_frameWidth_ellen                             -502.40
# - OT01V_bytesSent_in_bits_s_ellen                    -502.28
# - IT01V_packetsRecieved_aadya                        -502.19
# - IT01A_jitterBufferDelay_emissions_aadya            -502.17
# - IT01V_totalFreezesDuration_aadya                   -502.15
# - IT01V_packetsLost_ellen                            -501.88
# - OT01V_packetsSent_s_ellen                          -501.64
# - RIA_fractionLost_aadya                             -501.52
# - IT01V_frameWidth_aadya                             -501.08
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -501.08
# - IT01V_totalProcessingDelay_ellen                   -500.82
# - RIV_fractionLost_ellen                             -500.73
# - IT01V_framesPerSecond_aadya                        -500.70
# - AP_totalPlayoutDelay_ellen                         -500.42
# - IT01V_packetsLost_aadya                            -500.05
# - IT01V_jitterBufferDelay_emissions_ellen            -499.39
# - RIA_roundTripTime_aadya                            -499.22
# - RIV_roundTripTime_aadya                            -499.20
# - IT01V_totalProcessingDelay_aadya                   -498.87
# <none>                                               -498.62
# - OT01V_totalPacketSendDelay_ellen                   -498.48
# - OT01V_framesPerSecond_aadya                        -498.20
# - IT01V_framesPerSecond_ellen                        -497.50
# - OT01V_framesPerSecond_ellen                        -496.24
# - IT01A_jitterBufferDelay_emissions_ellen            -491.31
#
# Step:  AIC=-503.12
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq      RSS
# - RIV_fractionLost_aadya                              1 0.0000027 0.037246
# - AP_totalPlayoutDelay_aadya                          1 0.0000046 0.037248
# - IT01V_jitter_aadya                                  1 0.0000069 0.037250
# - RIA_fractionLost_ellen                              1 0.0000086 0.037252
# - IT01V_packetsRecieved_ellen                         1 0.0000151 0.037258
# - IT01V_totalFreezesDuration_ellen                    1 0.0000241 0.037267
# - RIA_roundTripTime_ellen                             1 0.0000300 0.037273
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000398 0.037283
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000500 0.037293
# - ROA_roundTripTime_aadya                             1 0.0000908 0.037334
# - OT01V_packetsSent_s_aadya                           1 0.0001070 0.037350
# - ROA_roundTripTime_ellen                             1 0.0001075 0.037350
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0001346 0.037377
# - RIV_roundTripTime_ellen                             1 0.0001540 0.037397
# - OT01V_frameWidth_aadya                              1 0.0002145 0.037457
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0002158 0.037459
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0002346 0.037477
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0002559 0.037499
# - IT01V_frameWidth_ellen                              1 0.0003028 0.037546
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0003543 0.037597
# - IT01V_totalFreezesDuration_aadya                    1 0.0004040 0.037647
# - IT01V_packetsRecieved_aadya                         1 0.0004102 0.037653
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0004349 0.037678
# - OT01V_totalPacketSendDelay_aadya                    1 0.0004660 0.037709
# - IT01V_packetsLost_ellen                             1 0.0005154 0.037758
# - OT01V_packetsSent_s_ellen                           1 0.0006270 0.037870
# - RIA_fractionLost_aadya                              1 0.0007083 0.037951
# - IT01V_frameWidth_aadya                              1 0.0008538 0.038097
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0009471 0.038190
# - RIV_fractionLost_ellen                              1 0.0010309 0.038274
# - IT01V_totalProcessingDelay_ellen                    1 0.0010415 0.038284
# - AP_totalPlayoutDelay_ellen                          1 0.0012043 0.038447
# - IT01V_packetsLost_aadya                             1 0.0013141 0.038557
# - IT01V_framesPerSecond_aadya                         1 0.0013254 0.038568
# - RIA_roundTripTime_aadya                             1 0.0017122 0.038955
# - RIV_roundTripTime_aadya                             1 0.0017218 0.038965
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0018545 0.039097
# <none>                                                            0.037243
# - IT01V_totalProcessingDelay_aadya                    1 0.0019685 0.039211
# - OT01V_totalPacketSendDelay_ellen                    1 0.0019715 0.039214
# - OT01V_framesPerSecond_aadya                         1 0.0021857 0.039429
# - IT01V_framesPerSecond_ellen                         1 0.0028206 0.040064
# - OT01V_framesPerSecond_ellen                         1 0.0033887 0.040632
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0054197 0.042663
#                                                          AIC
# - RIV_fractionLost_aadya                             -507.61
# - AP_totalPlayoutDelay_aadya                         -507.61
# - IT01V_jitter_aadya                                 -507.60
# - RIA_fractionLost_ellen                             -507.60
# - IT01V_packetsRecieved_ellen                        -507.58
# - IT01V_totalFreezesDuration_ellen                   -507.56
# - RIA_roundTripTime_ellen                            -507.54
# - IT01V_bytesReceived_in_bits_s_ellen                -507.52
# - IT01V_jitterBufferDelay_emissions_aadya            -507.50
# - ROA_roundTripTime_aadya                            -507.40
# - OT01V_packetsSent_s_aadya                          -507.36
# - ROA_roundTripTime_ellen                            -507.36
# - IT01A_bytesReceived_in_bits_s_aadya                -507.29
# - RIV_roundTripTime_ellen                            -507.25
# - OT01V_frameWidth_aadya                             -507.10
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -507.10
# - IT01V_bytesReceived_in_bits_s_aadya                -507.05
# - IT01A_bytesReceived_in_bits_s_ellen                -507.00
# - IT01V_frameWidth_ellen                             -506.89
# - OT01V_bytesSent_in_bits_s_ellen                    -506.77
# - IT01V_totalFreezesDuration_aadya                   -506.65
# - IT01V_packetsRecieved_aadya                        -506.63
# - IT01A_jitterBufferDelay_emissions_aadya            -506.57
# - OT01V_totalPacketSendDelay_aadya                   -506.50
# - IT01V_packetsLost_ellen                            -506.38
# - OT01V_packetsSent_s_ellen                          -506.11
# - RIA_fractionLost_aadya                             -505.92
# - IT01V_frameWidth_aadya                             -505.58
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -505.36
# - RIV_fractionLost_ellen                             -505.16
# - IT01V_totalProcessingDelay_ellen                   -505.14
# - AP_totalPlayoutDelay_ellen                         -504.75
# - IT01V_packetsLost_aadya                            -504.50
# - IT01V_framesPerSecond_aadya                        -504.47
# - RIA_roundTripTime_aadya                            -503.57
# - RIV_roundTripTime_aadya                            -503.55
# - IT01V_jitterBufferDelay_emissions_ellen            -503.24
# <none>                                               -503.12
# - IT01V_totalProcessingDelay_aadya                   -502.98
# - OT01V_totalPacketSendDelay_ellen                   -502.98
# - OT01V_framesPerSecond_aadya                        -502.48
# - IT01V_framesPerSecond_ellen                        -501.05
# - OT01V_framesPerSecond_ellen                        -499.78
# - IT01A_jitterBufferDelay_emissions_ellen            -495.39
#
# Step:  AIC=-507.61
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_ellen +
#     RIA_roundTripTime_aadya + ROA_roundTripTime_ellen + ROA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya
#
#                                                      Df Sum of Sq      RSS
# - AP_totalPlayoutDelay_aadya                          1 0.0000057 0.037251
# - RIA_fractionLost_ellen                              1 0.0000085 0.037254
# - IT01V_jitter_aadya                                  1 0.0000102 0.037256
# - IT01V_packetsRecieved_ellen                         1 0.0000169 0.037262
# - IT01V_totalFreezesDuration_ellen                    1 0.0000233 0.037269
# - RIA_roundTripTime_ellen                             1 0.0000291 0.037275
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000447 0.037290
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000473 0.037293
# - ROA_roundTripTime_aadya                             1 0.0000902 0.037336
# - ROA_roundTripTime_ellen                             1 0.0001060 0.037352
# - OT01V_packetsSent_s_aadya                           1 0.0001175 0.037363
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0001499 0.037395
# - RIV_roundTripTime_ellen                             1 0.0001527 0.037398
# - OT01V_frameWidth_aadya                              1 0.0002148 0.037460
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0002229 0.037468
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0002412 0.037487
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0002765 0.037522
# - IT01V_frameWidth_ellen                              1 0.0003048 0.037550
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0003603 0.037606
# - IT01V_packetsRecieved_aadya                         1 0.0004226 0.037668
# - IT01V_totalFreezesDuration_aadya                    1 0.0004357 0.037681
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0004469 0.037692
# - OT01V_totalPacketSendDelay_aadya                    1 0.0004658 0.037711
# - IT01V_packetsLost_ellen                             1 0.0005276 0.037773
# - OT01V_packetsSent_s_ellen                           1 0.0006392 0.037885
# - RIA_fractionLost_aadya                              1 0.0007339 0.037979
# - IT01V_frameWidth_aadya                              1 0.0009282 0.038174
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0010229 0.038268
# - RIV_fractionLost_ellen                              1 0.0010319 0.038278
# - IT01V_totalProcessingDelay_ellen                    1 0.0010963 0.038342
# - AP_totalPlayoutDelay_ellen                          1 0.0012062 0.038452
# - IT01V_packetsLost_aadya                             1 0.0013154 0.038561
# - IT01V_framesPerSecond_aadya                         1 0.0013527 0.038598
# - RIA_roundTripTime_aadya                             1 0.0017125 0.038958
# - RIV_roundTripTime_aadya                             1 0.0017221 0.038968
# <none>                                                            0.037246
# - IT01V_totalProcessingDelay_aadya                    1 0.0019667 0.039212
# - OT01V_totalPacketSendDelay_ellen                    1 0.0019731 0.039219
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0021103 0.039356
# - OT01V_framesPerSecond_aadya                         1 0.0023647 0.039610
# - IT01V_framesPerSecond_ellen                         1 0.0030489 0.040295
# - OT01V_framesPerSecond_ellen                         1 0.0034201 0.040666
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0054839 0.042730
#                                                          AIC
# - AP_totalPlayoutDelay_aadya                         -512.10
# - RIA_fractionLost_ellen                             -512.09
# - IT01V_jitter_aadya                                 -512.09
# - IT01V_packetsRecieved_ellen                        -512.07
# - IT01V_totalFreezesDuration_ellen                   -512.05
# - RIA_roundTripTime_ellen                            -512.04
# - IT01V_bytesReceived_in_bits_s_ellen                -512.00
# - IT01V_jitterBufferDelay_emissions_aadya            -512.00
# - ROA_roundTripTime_aadya                            -511.89
# - ROA_roundTripTime_ellen                            -511.86
# - OT01V_packetsSent_s_aadya                          -511.83
# - IT01A_bytesReceived_in_bits_s_aadya                -511.75
# - RIV_roundTripTime_ellen                            -511.74
# - OT01V_frameWidth_aadya                             -511.59
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -511.57
# - IT01V_bytesReceived_in_bits_s_aadya                -511.53
# - IT01A_bytesReceived_in_bits_s_ellen                -511.45
# - IT01V_frameWidth_ellen                             -511.38
# - OT01V_bytesSent_in_bits_s_ellen                    -511.24
# - IT01V_packetsRecieved_aadya                        -511.10
# - IT01V_totalFreezesDuration_aadya                   -511.06
# - IT01A_jitterBufferDelay_emissions_aadya            -511.04
# - OT01V_totalPacketSendDelay_aadya                   -510.99
# - IT01V_packetsLost_ellen                            -510.84
# - OT01V_packetsSent_s_ellen                          -510.58
# - RIA_fractionLost_aadya                             -510.35
# - IT01V_frameWidth_aadya                             -509.90
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -509.67
# - RIV_fractionLost_ellen                             -509.65
# - IT01V_totalProcessingDelay_ellen                   -509.50
# - AP_totalPlayoutDelay_ellen                         -509.24
# - IT01V_packetsLost_aadya                            -508.99
# - IT01V_framesPerSecond_aadya                        -508.90
# - RIA_roundTripTime_aadya                            -508.07
# - RIV_roundTripTime_aadya                            -508.04
# <none>                                               -507.61
# - IT01V_totalProcessingDelay_aadya                   -507.48
# - OT01V_totalPacketSendDelay_ellen                   -507.47
# - IT01V_jitterBufferDelay_emissions_ellen            -507.15
# - OT01V_framesPerSecond_aadya                        -506.57
# - IT01V_framesPerSecond_ellen                        -505.03
# - OT01V_framesPerSecond_ellen                        -504.20
# - IT01A_jitterBufferDelay_emissions_ellen            -499.75
#
# Step:  AIC=-512.1
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_ellen +
#     RIA_roundTripTime_aadya + ROA_roundTripTime_ellen + ROA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq      RSS
# - RIA_fractionLost_ellen                              1 0.0000070 0.037258
# - IT01V_jitter_aadya                                  1 0.0000109 0.037262
# - IT01V_packetsRecieved_ellen                         1 0.0000182 0.037269
# - IT01V_totalFreezesDuration_ellen                    1 0.0000262 0.037277
# - RIA_roundTripTime_ellen                             1 0.0000356 0.037287
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000452 0.037296
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000474 0.037299
# - ROA_roundTripTime_aadya                             1 0.0000861 0.037337
# - OT01V_packetsSent_s_aadya                           1 0.0001119 0.037363
# - ROA_roundTripTime_ellen                             1 0.0001131 0.037364
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0001457 0.037397
# - RIV_roundTripTime_ellen                             1 0.0001858 0.037437
# - OT01V_frameWidth_aadya                              1 0.0002156 0.037467
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0002173 0.037469
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0002708 0.037522
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0002715 0.037523
# - IT01V_frameWidth_ellen                              1 0.0003059 0.037557
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0004229 0.037674
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0004517 0.037703
# - IT01V_totalFreezesDuration_aadya                    1 0.0004530 0.037704
# - IT01V_packetsRecieved_aadya                         1 0.0004704 0.037722
# - OT01V_totalPacketSendDelay_aadya                    1 0.0004766 0.037728
# - IT01V_packetsLost_ellen                             1 0.0005260 0.037777
# - RIA_fractionLost_aadya                              1 0.0007414 0.037993
# - OT01V_packetsSent_s_ellen                           1 0.0007434 0.037995
# - IT01V_frameWidth_aadya                              1 0.0009266 0.038178
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0010314 0.038283
# - IT01V_totalProcessingDelay_ellen                    1 0.0010915 0.038343
# - RIV_fractionLost_ellen                              1 0.0011564 0.038408
# - IT01V_packetsLost_aadya                             1 0.0013101 0.038561
# - IT01V_framesPerSecond_aadya                         1 0.0013816 0.038633
# - RIA_roundTripTime_aadya                             1 0.0017407 0.038992
# - RIV_roundTripTime_aadya                             1 0.0017498 0.039001
# <none>                                                            0.037251
# - IT01V_totalProcessingDelay_aadya                    1 0.0019611 0.039212
# - OT01V_totalPacketSendDelay_ellen                    1 0.0019741 0.039225
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0021048 0.039356
# - OT01V_framesPerSecond_aadya                         1 0.0024486 0.039700
# - AP_totalPlayoutDelay_ellen                          1 0.0024704 0.039722
# - IT01V_framesPerSecond_ellen                         1 0.0030894 0.040341
# - OT01V_framesPerSecond_ellen                         1 0.0037883 0.041040
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0056066 0.042858
#                                                          AIC
# - RIA_fractionLost_ellen                             -516.58
# - IT01V_jitter_aadya                                 -516.57
# - IT01V_packetsRecieved_ellen                        -516.55
# - IT01V_totalFreezesDuration_ellen                   -516.53
# - RIA_roundTripTime_ellen                            -516.51
# - IT01V_bytesReceived_in_bits_s_ellen                -516.49
# - IT01V_jitterBufferDelay_emissions_aadya            -516.48
# - ROA_roundTripTime_aadya                            -516.39
# - OT01V_packetsSent_s_aadya                          -516.33
# - ROA_roundTripTime_ellen                            -516.32
# - IT01A_bytesReceived_in_bits_s_aadya                -516.25
# - RIV_roundTripTime_ellen                            -516.15
# - OT01V_frameWidth_aadya                             -516.08
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya -516.07
# - IT01A_bytesReceived_in_bits_s_ellen                -515.94
# - IT01V_bytesReceived_in_bits_s_aadya                -515.94
# - IT01V_frameWidth_ellen                             -515.86
# - OT01V_bytesSent_in_bits_s_ellen                    -515.58
# - IT01A_jitterBufferDelay_emissions_aadya            -515.51
# - IT01V_totalFreezesDuration_aadya                   -515.51
# - IT01V_packetsRecieved_aadya                        -515.47
# - OT01V_totalPacketSendDelay_aadya                   -515.45
# - IT01V_packetsLost_ellen                            -515.34
# - RIA_fractionLost_aadya                             -514.82
# - OT01V_packetsSent_s_ellen                          -514.82
# - IT01V_frameWidth_aadya                             -514.39
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -514.14
# - IT01V_totalProcessingDelay_ellen                   -514.00
# - RIV_fractionLost_ellen                             -513.85
# - IT01V_packetsLost_aadya                            -513.49
# - IT01V_framesPerSecond_aadya                        -513.32
# - RIA_roundTripTime_aadya                            -512.49
# - RIV_roundTripTime_aadya                            -512.47
# <none>                                               -512.10
# - IT01V_totalProcessingDelay_aadya                   -511.98
# - OT01V_totalPacketSendDelay_ellen                   -511.95
# - IT01V_jitterBufferDelay_emissions_ellen            -511.65
# - OT01V_framesPerSecond_aadya                        -510.87
# - AP_totalPlayoutDelay_ellen                         -510.82
# - IT01V_framesPerSecond_ellen                        -509.43
# - OT01V_framesPerSecond_ellen                        -507.88
# - IT01A_jitterBufferDelay_emissions_ellen            -503.98
#
# Step:  AIC=-516.58
# logistic_transformed_score ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01V_jitterBufferDelay_emissions_aadya + IT01A_bytesReceived_in_bits_s_ellen +
#     IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#     RIA_fractionLost_aadya + RIA_roundTripTime_ellen + RIA_roundTripTime_aadya +
#     ROA_roundTripTime_ellen + ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq      RSS
# - IT01V_jitter_aadya                                  1 0.0000126 0.037271
# - IT01V_packetsRecieved_ellen                         1 0.0000168 0.037275
# - IT01V_totalFreezesDuration_ellen                    1 0.0000277 0.037286
# - RIA_roundTripTime_ellen                             1 0.0000354 0.037294
# - IT01V_bytesReceived_in_bits_s_ellen                 1 0.0000427 0.037301
# - IT01V_jitterBufferDelay_emissions_aadya             1 0.0000448 0.037303
# - ROA_roundTripTime_aadya                             1 0.0000913 0.037350
# - OT01V_packetsSent_s_aadya                           1 0.0001078 0.037366
# - ROA_roundTripTime_ellen                             1 0.0001182 0.037376
# - IT01A_bytesReceived_in_bits_s_aadya                 1 0.0001416 0.037400
# - RIV_roundTripTime_ellen                             1 0.0001974 0.037456
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  1 0.0002119 0.037470
# - OT01V_frameWidth_aadya                              1 0.0002146 0.037473
# - IT01A_bytesReceived_in_bits_s_ellen                 1 0.0002660 0.037524
# - IT01V_bytesReceived_in_bits_s_aadya                 1 0.0002741 0.037532
# - IT01V_frameWidth_ellen                              1 0.0003039 0.037562
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0004514 0.037710
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0004537 0.037712
# - IT01V_packetsRecieved_aadya                         1 0.0004692 0.037727
# - OT01V_totalPacketSendDelay_aadya                    1 0.0004698 0.037728
# - IT01V_totalFreezesDuration_aadya                    1 0.0004728 0.037731
# - IT01V_packetsLost_ellen                             1 0.0005287 0.037787
# - RIA_fractionLost_aadya                              1 0.0007477 0.038006
# - OT01V_packetsSent_s_ellen                           1 0.0007812 0.038039
# - IT01V_frameWidth_aadya                              1 0.0009720 0.038230
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0010273 0.038286
# - IT01V_totalProcessingDelay_ellen                    1 0.0011100 0.038368
# - RIV_fractionLost_ellen                              1 0.0011734 0.038432
# - IT01V_packetsLost_aadya                             1 0.0013069 0.038565
# - IT01V_framesPerSecond_aadya                         1 0.0014096 0.038668
# - RIA_roundTripTime_aadya                             1 0.0017620 0.039020
# - RIV_roundTripTime_aadya                             1 0.0017708 0.039029
# <none>                                                            0.037258
# - IT01V_totalProcessingDelay_aadya                    1 0.0019577 0.039216
# - OT01V_totalPacketSendDelay_ellen                    1 0.0019728 0.039231
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0021197 0.039378
# - OT01V_framesPerSecond_aadya                         1 0.0024450 0.039703
# - AP_totalPlayoutDelay_ellen                          1 0.0025275 0.039786
# - IT01V_framesPerSecond_ellen                         1 0.0030907 0.040349
# - OT01V_framesPerSecond_ellen                         1 0.0038426 0.041101
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0056080 0.042866
#                                                          AIC
# - IT01V_jitter_aadya                                 -521.05
# - IT01V_packetsRecieved_ellen                        -521.04
# - IT01V_totalFreezesDuration_ellen                   -521.01
# - RIA_roundTripTime_ellen                            -520.99
# - IT01V_bytesReceived_in_bits_s_ellen                -520.98
# - IT01V_jitterBufferDelay_emissions_aadya            -520.97
# ...
# - AP_totalPlayoutDelay_ellen                         -589.30
# - OT01V_totalPacketSendDelay_ellen                   -588.90
# - IT01V_jitterBufferDelay_emissions_ellen            -588.18
# - RIV_fractionLost_ellen                             -587.41
# - IT01V_framesPerSecond_ellen                        -586.73
# - OT01V_framesPerSecond_aadya                        -584.81
# - RIA_fractionLost_aadya                             -583.96
# - OT01V_framesPerSecond_ellen                        -581.50
# - RIV_roundTripTime_aadya                            -580.34
# - RIA_roundTripTime_aadya                            -580.24
# - IT01A_jitterBufferDelay_emissions_ellen            -569.74
#
# Step:  AIC=-595.33
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_frameWidth_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_bytesSent_in_bits_s_ellen + OT01V_framesPerSecond_ellen +
#     OT01V_framesPerSecond_aadya + OT01V_totalPacketSendDelay_ellen +
#     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + RIV_roundTripTime_aadya +
#     RIV_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                                      Df Sum of Sq      RSS
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  1 0.0006843 0.042903
# - OT01V_bytesSent_in_bits_s_ellen                     1 0.0007900 0.043009
# - OT01V_packetsSent_s_ellen                           1 0.0009979 0.043217
# - IT01V_packetsLost_aadya                             1 0.0011939 0.043413
# - IT01V_frameWidth_aadya                              1 0.0013295 0.043549
# - IT01V_framesPerSecond_aadya                         1 0.0020293 0.044249
# - IT01V_totalProcessingDelay_aadya                    1 0.0020307 0.044250
# <none>                                                            0.042219
# - IT01V_totalProcessingDelay_ellen                    1 0.0027335 0.044953
# - IT01A_jitterBufferDelay_emissions_aadya             1 0.0029637 0.045183
# - OT01V_totalPacketSendDelay_ellen                    1 0.0037365 0.045956
# - IT01V_framesPerSecond_ellen                         1 0.0042357 0.046455
# - RIV_fractionLost_ellen                              1 0.0045986 0.046818
# - AP_totalPlayoutDelay_ellen                          1 0.0049196 0.047139
# - OT01V_framesPerSecond_aadya                         1 0.0052502 0.047469
# - RIA_fractionLost_aadya                              1 0.0067286 0.048948
# - IT01V_jitterBufferDelay_emissions_ellen             1 0.0074733 0.049693
# - OT01V_framesPerSecond_ellen                         1 0.0076250 0.049844
# - RIV_roundTripTime_aadya                             1 0.0079973 0.050217
# - RIA_roundTripTime_aadya                             1 0.0080437 0.050263
# - IT01A_jitterBufferDelay_emissions_ellen             1 0.0139669 0.056186
#                                                          AIC
# - OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen -598.38
# - OT01V_bytesSent_in_bits_s_ellen                    -598.16
# - OT01V_packetsSent_s_ellen                          -597.72
# - IT01V_packetsLost_aadya                            -597.32
# - IT01V_frameWidth_aadya                             -597.04
# - IT01V_framesPerSecond_aadya                        -595.60
# - IT01V_totalProcessingDelay_aadya                   -595.60
# <none>                                               -595.33
# - IT01V_totalProcessingDelay_ellen                   -594.18
# - IT01A_jitterBufferDelay_emissions_aadya            -593.72
# - OT01V_totalPacketSendDelay_ellen                   -592.19
# - IT01V_framesPerSecond_ellen                        -591.22
# - RIV_fractionLost_ellen                             -590.52
# - AP_totalPlayoutDelay_ellen                         -589.91
# - OT01V_framesPerSecond_aadya                        -589.28
# - RIA_fractionLost_aadya                             -586.52
# - IT01V_jitterBufferDelay_emissions_ellen            -585.16
# - OT01V_framesPerSecond_ellen                        -584.88
# - RIV_roundTripTime_aadya                            -584.21
# - RIA_roundTripTime_aadya                            -584.13
# - IT01A_jitterBufferDelay_emissions_ellen            -574.10
#
# Step:  AIC=-598.38
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_frameWidth_aadya +
#     IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya +
#     IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_bytesSent_in_bits_s_ellen + OT01V_framesPerSecond_ellen +
#     OT01V_framesPerSecond_aadya + OT01V_totalPacketSendDelay_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen
#
#                                           Df Sum of Sq      RSS     AIC
# - IT01V_frameWidth_aadya                   1 0.0007155 0.043619 -601.39
# - IT01V_packetsLost_aadya                  1 0.0008159 0.043719 -601.18
# - OT01V_bytesSent_in_bits_s_ellen          1 0.0010014 0.043905 -600.80
# - OT01V_packetsSent_s_ellen                1 0.0011193 0.044023 -600.56
# - IT01V_totalProcessingDelay_aadya         1 0.0014113 0.044315 -599.97
# - IT01V_framesPerSecond_aadya              1 0.0018624 0.044766 -599.05
# <none>                                                 0.042903 -598.38
# - IT01V_totalProcessingDelay_ellen         1 0.0023430 0.045246 -598.09
# - IT01A_jitterBufferDelay_emissions_aadya  1 0.0025996 0.045503 -597.58
# - OT01V_totalPacketSendDelay_ellen         1 0.0038811 0.046785 -595.08
# - RIV_fractionLost_ellen                   1 0.0040809 0.046984 -594.70
# - AP_totalPlayoutDelay_ellen               1 0.0042722 0.047176 -594.34
# - IT01V_framesPerSecond_ellen              1 0.0044016 0.047305 -594.09
# - OT01V_framesPerSecond_aadya              1 0.0056706 0.048574 -591.71
# - RIA_fractionLost_aadya                   1 0.0063976 0.049301 -590.37
# - IT01V_jitterBufferDelay_emissions_ellen  1 0.0069269 0.049830 -589.41
# - OT01V_framesPerSecond_ellen              1 0.0076353 0.050539 -588.14
# - RIV_roundTripTime_aadya                  1 0.0088217 0.051725 -586.05
# - RIA_roundTripTime_aadya                  1 0.0088807 0.051784 -585.95
# - IT01A_jitterBufferDelay_emissions_ellen  1 0.0134706 0.056374 -578.30
#
# Step:  AIC=-601.39
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_totalProcessingDelay_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + RIV_roundTripTime_aadya +
#     RIV_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                           Df Sum of Sq      RSS     AIC
# - IT01V_totalProcessingDelay_aadya         1 0.0009873 0.044606 -603.88
# - IT01V_framesPerSecond_aadya              1 0.0014475 0.045066 -602.95
# - IT01V_totalProcessingDelay_ellen         1 0.0017130 0.045332 -602.42
# - OT01V_packetsSent_s_ellen                1 0.0017848 0.045404 -602.28
# - OT01V_bytesSent_in_bits_s_ellen          1 0.0019082 0.045527 -602.04
# - IT01A_jitterBufferDelay_emissions_aadya  1 0.0021923 0.045811 -601.48
# <none>                                                 0.043619 -601.39
# - IT01V_packetsLost_aadya                  1 0.0022852 0.045904 -601.29
# - AP_totalPlayoutDelay_ellen               1 0.0036785 0.047298 -598.60
# - RIV_fractionLost_ellen                   1 0.0037084 0.047327 -598.55
# - IT01V_framesPerSecond_ellen              1 0.0042531 0.047872 -597.52
# - OT01V_framesPerSecond_aadya              1 0.0057863 0.049405 -594.68
# - RIA_fractionLost_aadya                   1 0.0059575 0.049576 -594.37
# - IT01V_jitterBufferDelay_emissions_ellen  1 0.0063084 0.049927 -593.73
# - OT01V_totalPacketSendDelay_ellen         1 0.0070126 0.050632 -592.47
# - OT01V_framesPerSecond_ellen              1 0.0073795 0.050998 -591.82
# - RIV_roundTripTime_aadya                  1 0.0081143 0.051733 -590.54
# - RIA_roundTripTime_aadya                  1 0.0081728 0.051792 -590.43
# - IT01A_jitterBufferDelay_emissions_ellen  1 0.0137094 0.057328 -581.29
#
# Step:  AIC=-603.88
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_totalProcessingDelay_ellen +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen +
#     OT01V_bytesSent_in_bits_s_ellen + OT01V_framesPerSecond_ellen +
#     OT01V_framesPerSecond_aadya + OT01V_totalPacketSendDelay_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen
#
#                                           Df Sum of Sq      RSS     AIC
# - IT01V_totalProcessingDelay_ellen         1 0.0013181 0.045924 -605.75
# - IT01V_framesPerSecond_aadya              1 0.0014952 0.046101 -605.41
# - OT01V_packetsSent_s_ellen                1 0.0017852 0.046391 -604.84
# - OT01V_bytesSent_in_bits_s_ellen          1 0.0019030 0.046509 -604.62
# - IT01V_packetsLost_aadya                  1 0.0022512 0.046857 -603.94
# <none>                                                 0.044606 -603.88
# - IT01A_jitterBufferDelay_emissions_aadya  1 0.0022910 0.046897 -603.87
# - AP_totalPlayoutDelay_ellen               1 0.0039939 0.048600 -600.66
# - RIV_fractionLost_ellen                   1 0.0049347 0.049541 -598.93
# - IT01V_framesPerSecond_ellen              1 0.0051788 0.049785 -598.49
# - RIA_fractionLost_aadya                   1 0.0056558 0.050262 -597.63
# - OT01V_totalPacketSendDelay_ellen         1 0.0060380 0.050644 -596.95
# - IT01V_jitterBufferDelay_emissions_ellen  1 0.0066509 0.051257 -595.87
# - OT01V_framesPerSecond_aadya              1 0.0067447 0.051351 -595.70
# - OT01V_framesPerSecond_ellen              1 0.0071779 0.051784 -594.95
# - RIV_roundTripTime_aadya                  1 0.0082484 0.052855 -593.10
# - RIA_roundTripTime_aadya                  1 0.0083129 0.052919 -593.00
# - IT01A_jitterBufferDelay_emissions_ellen  1 0.0137421 0.058348 -584.21
#
# Step:  AIC=-605.75
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#     OT01V_packetsSent_s_ellen + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + RIV_roundTripTime_aadya +
#     RIV_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                           Df Sum of Sq      RSS     AIC
# - IT01A_jitterBufferDelay_emissions_aadya  1 0.0017760 0.047700 -606.84
# - IT01V_framesPerSecond_aadya              1 0.0018642 0.047789 -606.67
# <none>                                                 0.045924 -605.75
# - IT01V_packetsLost_aadya                  1 0.0025177 0.048442 -605.45
# - AP_totalPlayoutDelay_ellen               1 0.0027812 0.048705 -604.96
# - OT01V_packetsSent_s_ellen                1 0.0031359 0.049060 -604.31
# - OT01V_bytesSent_in_bits_s_ellen          1 0.0033031 0.049227 -604.00
# - RIA_fractionLost_aadya                   1 0.0048396 0.050764 -601.24
# - RIV_fractionLost_ellen                   1 0.0048798 0.050804 -601.17
# - IT01V_framesPerSecond_ellen              1 0.0049191 0.050843 -601.10
# - OT01V_framesPerSecond_aadya              1 0.0068533 0.052778 -597.74
# - IT01V_jitterBufferDelay_emissions_ellen  1 0.0070676 0.052992 -597.37
# - OT01V_totalPacketSendDelay_ellen         1 0.0070977 0.053022 -597.32
# - RIV_roundTripTime_aadya                  1 0.0074907 0.053415 -596.66
# - RIA_roundTripTime_aadya                  1 0.0075595 0.053484 -596.54
# - OT01V_framesPerSecond_ellen              1 0.0088983 0.054823 -594.31
# - IT01A_jitterBufferDelay_emissions_ellen  1 0.0144532 0.060377 -585.63
#
# Step:  AIC=-606.84
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_framesPerSecond_aadya + IT01V_jitterBufferDelay_emissions_ellen +
#     IT01A_jitterBufferDelay_emissions_ellen + OT01V_packetsSent_s_ellen +
#     OT01V_bytesSent_in_bits_s_ellen + OT01V_framesPerSecond_ellen +
#     OT01V_framesPerSecond_aadya + OT01V_totalPacketSendDelay_ellen +
#     RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIA_fractionLost_aadya +
#     RIA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen
#
#                                           Df Sum of Sq      RSS     AIC
# - IT01V_framesPerSecond_aadya              1 0.0015750 0.049275 -608.42
# <none>                                                 0.047700 -606.84
# - IT01V_packetsLost_aadya                  1 0.0025341 0.050234 -606.68
# - OT01V_packetsSent_s_ellen                1 0.0028062 0.050506 -606.19
# - OT01V_bytesSent_in_bits_s_ellen          1 0.0028964 0.050597 -606.03
# - AP_totalPlayoutDelay_ellen               1 0.0029298 0.050630 -605.97
# - RIA_fractionLost_aadya                   1 0.0041110 0.051811 -603.90
# - RIV_fractionLost_ellen                   1 0.0048058 0.052506 -602.70
# - IT01V_jitterBufferDelay_emissions_ellen  1 0.0053222 0.053022 -601.82
# - IT01V_framesPerSecond_ellen              1 0.0053441 0.053044 -601.78
# - OT01V_totalPacketSendDelay_ellen         1 0.0065522 0.054253 -599.76
# - RIV_roundTripTime_aadya                  1 0.0071669 0.054867 -598.74
# - RIA_roundTripTime_aadya                  1 0.0072143 0.054915 -598.66
# - OT01V_framesPerSecond_aadya              1 0.0075322 0.055232 -598.14
# - OT01V_framesPerSecond_ellen              1 0.0084927 0.056193 -596.59
# - IT01A_jitterBufferDelay_emissions_ellen  1 0.0138160 0.061516 -588.45
#
# Step:  AIC=-608.42
# logistic_transformed_score ~ IT01V_packetsLost_aadya + IT01V_framesPerSecond_ellen +
#     IT01V_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_ellen +
#     OT01V_packetsSent_s_ellen + OT01V_bytesSent_in_bits_s_ellen +
#     OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#     OT01V_totalPacketSendDelay_ellen + RIV_roundTripTime_aadya +
#     RIV_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_aadya +
#     AP_totalPlayoutDelay_ellen
#
#                                           Df Sum of Sq      RSS     AIC
# <none>                                                 0.049275 -608.42
# - OT01V_packetsSent_s_ellen                1 0.0027325 0.052008 -608.06
# - IT01V_packetsLost_aadya                  1 0.0027572 0.052032 -608.02
# - OT01V_bytesSent_in_bits_s_ellen          1 0.0027907 0.052066 -607.96
# - AP_totalPlayoutDelay_ellen               1 0.0038251 0.053100 -606.19
# - IT01V_jitterBufferDelay_emissions_ellen  1 0.0043837 0.053659 -605.25
# - RIV_fractionLost_ellen                   1 0.0044450 0.053720 -605.14
# - RIA_fractionLost_aadya                   1 0.0044609 0.053736 -605.12
# - IT01V_framesPerSecond_ellen              1 0.0046852 0.053961 -604.74
# - OT01V_framesPerSecond_aadya              1 0.0067407 0.056016 -601.38
# - RIV_roundTripTime_aadya                  1 0.0070711 0.056346 -600.85
# - OT01V_totalPacketSendDelay_ellen         1 0.0070732 0.056348 -600.84
# - RIA_roundTripTime_aadya                  1 0.0071196 0.056395 -600.77
# - OT01V_framesPerSecond_ellen              1 0.0099965 0.059272 -596.29
# - IT01A_jitterBufferDelay_emissions_ellen  1 0.0131627 0.062438 -591.61

# %% [markdown]
# # Random forest

# %%
rf_model <- randomForest(logistic_transformed_score ~ ., data = trim_data)
# Make predictions
rf_predictions <- predict(rf_model, trim_data)
mse_rf <- mean((trim_data$logistic_transformed_score - rf_predictions)^2)

# %% [markdown]
# # Evaluate all the models

# %%
cat("MSE for AIC:", mse_aic, "\n")
cat("MSE for BIC:", mse_bic, "\n")
cat("MSE for lasso:", mse_lasso, "\n")
cat("MSE for ridge:", mse_ridge, "\n")
# Out:
# MSE for AIC: 0.0004846552
# MSE for BIC: 0.0005475032
# MSE for lasso: 0.0005733799
# MSE for ridge: 0.0009025711
