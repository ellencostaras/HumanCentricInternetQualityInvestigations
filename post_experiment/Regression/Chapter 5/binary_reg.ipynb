# %%
install.packages("pROC")
install.packages("vctrs")
install.packages("caret")
install.packages("nnet")
install.packages("cowplot")
install.packages("ggplot2")
install.packages("MASS")
# Out:
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpGmmtVP/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpGmmtVP/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpGmmtVP/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpGmmtVP/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpGmmtVP/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpGmmtVP/downloaded_packages
# Warning message:
# "package 'MASS' is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages"

# %%
all_table <- read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression/regression_tables/fieldwork/subjective_and_objective_table.csv")

# %% [markdown]
# # Visualise MOS distribution

# %%
install.packages("ordinal")
# Out:
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpY5lVhS/downloaded_packages

# %%
options(repr.plot.width = 10, repr.plot.height = 6)
#plot the target variable
par(bg = "white")  # set background color to white
hist(all_table$serviceable_agg,
     col = "black",
     border = "white")
# Out:
# Plot with title "Histogram of all_table$serviceable_agg"

# %% [markdown]
# ## add a new ordinal variable that represents the levels of serviceable agg

# %%
library(ordinal)
all_table$rounded_serviceable_agg <- round(as.numeric(all_table$serviceable_agg), digits = 2)
all_table$ordered <- factor(all_table$rounded_serviceable_agg, 
levels =c(0.00,0.33, 0.5, 0.67, 1.00), 
ordered = TRUE)

# %% [markdown]
# ### fit a big model with all vars to this ordinal var

# %%
fit <- clm(ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter + avg_pl_ellen
    + avg_up_aadya + avg_down_aadya + avg_rtt_aadya + avg_jitter_aadya + avg_pl_aadya 
    + sd_up_ellen + sd_down_ellen + sd_rtt_ellen + sd_jitter_ellen + sd_pl_ellen 
    + sd_up_aadya + sd_down_aadya + sd_rtt_aadya + sd_jitter_aadya + sd_pl_aadya,
    #+ avg_down_google + avg_up_google + avg_rtt_google + sd_down_google + sd_up_google + sd_rtt_google, 
    data = all_table)
summary(fit)
# Out:
# formula:
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter + avg_pl_ellen + avg_up_aadya + avg_down_aadya + avg_rtt_aadya + avg_jitter_aadya + avg_pl_aadya + sd_up_ellen + sd_down_ellen + sd_rtt_ellen + sd_jitter_ellen + sd_pl_ellen + sd_up_aadya + sd_down_aadya + sd_rtt_aadya + sd_jitter_aadya + sd_pl_aadya
# data:    all_table
#
#  link  threshold nobs logLik AIC    niter max.grad cond.H
#  logit flexible  37   -31.20 110.41 10(2) 3.13e-09 8.2e+06
#
# Coefficients:
#                  Estimate Std. Error z value Pr(>|z|)
# avg_up_ellen     -0.16947    0.11935  -1.420   0.1556
# avg_down_ellen    0.06252    0.05823   1.074   0.2829
# avg_rtt_ellen    -0.20172    0.16688  -1.209   0.2267
# avg_ellen_jitter -0.13739    0.19852  -0.692   0.4889
# avg_pl_ellen      0.01536    0.20605   0.075   0.9406
# avg_up_aadya      0.12575    0.09925   1.267   0.2052
# avg_down_aadya   -0.08124    0.06953  -1.168   0.2426
# avg_rtt_aadya     0.05451    0.20134   0.271   0.7866
# avg_jitter_aadya  0.08118    0.16937   0.479   0.6317
# avg_pl_aadya      5.36507    6.00663   0.893   0.3718
# sd_up_ellen       0.33474    0.24949   1.342   0.1797
# sd_down_ellen    -0.12730    0.08595  -1.481   0.1386
# sd_rtt_ellen      0.31165    0.31544   0.988   0.3232
# sd_jitter_ellen   0.07962    0.10988   0.725   0.4687
# sd_pl_ellen      -0.38476    0.98465  -0.391   0.6960
# sd_up_aadya       0.45788    0.25602   1.788   0.0737 .
# sd_down_aadya     0.12896    0.10927   1.180   0.2380
# sd_rtt_aadya     -0.20688    0.37099  -0.558   0.5771
# sd_jitter_aadya  -0.04685    0.13592  -0.345   0.7303
# sd_pl_aadya      -7.59322    6.40031  -1.186   0.2355
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Threshold coefficients:
#          Estimate Std. Error z value
# 0|0.33    -3.4273     6.4952  -0.528
# 0.33|0.5  -2.2830     6.4463  -0.354
# 0.5|0.67  -2.0368     6.4317  -0.317
# 0.67|1    -0.8188     6.4323  -0.127

# %% [markdown]
# ### perform and plot the predictions

# %%
preds <- predict(fit, all_table)
AIC(fit)
BIC(fit)
options(repr.plot.width = 10, repr.plot.height = 6)
#plot the target variable
par(bg = "white")  # set background color to white
hist(preds$fit,
     col = "black",
     border = "white")
# Out:
# [1] 110.4062
# [1] 149.0682
# Plot with title "Histogram of preds$fit"

# %%
predicted_classes <- ifelse(preds$fit > 0.8, "1", "0")  # Example for binary outcome
table(predicted_classes, all_table$ordered)
# Out:
#
# predicted_classes  0 0.33 0.5 0.67  1
#                 0 10    5   1    4  4
#                 1 10    0   0    0  3

# %%
par(bg = "white")
preds <- predict(fit, all_table)
plot(preds$fit, all_table$ordered)
# Out:
# plot without title

# %% [markdown]
# # Penalised regression
# ### AIC

# %%
fit_aic <- step(fit) #stepwise regression to optimse a linear model
summary(fit_aic)
par(bg = "white")
preds_aic <-predict(fit_aic, all_table)
plot(preds_aic$fit, all_table$ordered)
# Out:
# Start:  AIC=110.41
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_pl_ellen + avg_up_aadya + avg_down_aadya + avg_rtt_aadya +
#     avg_jitter_aadya + avg_pl_aadya + sd_up_ellen + sd_down_ellen +
#     sd_rtt_ellen + sd_jitter_ellen + sd_pl_ellen + sd_up_aadya +
#     sd_down_aadya + sd_rtt_aadya + sd_jitter_aadya + sd_pl_aadya
#
#                    Df    AIC
# - avg_pl_ellen      1 108.41
# - avg_rtt_aadya     1 108.48
# - sd_jitter_aadya   1 108.53
# - sd_pl_ellen       1 108.56
# - avg_jitter_aadya  1 108.64
# - sd_rtt_aadya      1 108.70
# - avg_ellen_jitter  1 108.90
# - sd_jitter_ellen   1 108.97
# - avg_pl_aadya      1 109.28
# - sd_rtt_ellen      1 109.46
# - avg_down_ellen    1 109.61
# - avg_down_aadya    1 109.93
# - avg_rtt_ellen     1 109.94
# - sd_down_aadya     1 110.05
# - sd_pl_aadya       1 110.07
# - sd_up_ellen       1 110.11
# <none>                110.41
# - avg_up_aadya      1 110.48
# - sd_down_ellen     1 110.76
# - avg_up_ellen      1 111.18
# - sd_up_aadya       1 112.34
#
# Step:  AIC=108.41
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_up_aadya + avg_down_aadya + avg_rtt_aadya + avg_jitter_aadya +
#     avg_pl_aadya + sd_up_ellen + sd_down_ellen + sd_rtt_ellen +
#     sd_jitter_ellen + sd_pl_ellen + sd_up_aadya + sd_down_aadya +
#     sd_rtt_aadya + sd_jitter_aadya + sd_pl_aadya
#
#                    Df    AIC
# - avg_rtt_aadya     1 106.48
# - sd_jitter_aadya   1 106.54
# - sd_pl_ellen       1 106.62
# - avg_jitter_aadya  1 106.64
# - sd_rtt_aadya      1 106.78
# - avg_ellen_jitter  1 106.92
# - sd_jitter_ellen   1 106.97
# - avg_pl_aadya      1 107.29
# - sd_rtt_ellen      1 107.49
# - avg_down_ellen    1 107.93
# - sd_pl_aadya       1 108.07
# - sd_down_aadya     1 108.26
# - avg_rtt_ellen     1 108.28
# <none>                108.41
# - avg_up_aadya      1 108.48
# - sd_up_ellen       1 108.58
# - avg_down_aadya    1 108.73
# - sd_down_ellen     1 108.76
# - avg_up_ellen      1 109.18
# - sd_up_aadya       1 110.34
#
# Step:  AIC=106.48
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_up_aadya + avg_down_aadya + avg_jitter_aadya + avg_pl_aadya +
#     sd_up_ellen + sd_down_ellen + sd_rtt_ellen + sd_jitter_ellen +
#     sd_pl_ellen + sd_up_aadya + sd_down_aadya + sd_rtt_aadya +
#     sd_jitter_aadya + sd_pl_aadya
#
#                    Df    AIC
# - sd_pl_ellen       1 104.65
# - sd_jitter_aadya   1 104.68
# - sd_rtt_aadya      1 104.78
# - avg_jitter_aadya  1 104.93
# - avg_ellen_jitter  1 105.01
# - sd_jitter_ellen   1 105.12
# - sd_rtt_ellen      1 105.56
# - avg_pl_aadya      1 105.64
# - avg_down_ellen    1 106.04
# - avg_rtt_ellen     1 106.38
# <none>                106.48
# - sd_down_aadya     1 106.49
# - sd_pl_aadya       1 106.54
# - sd_up_ellen       1 106.59
# - avg_up_aadya      1 106.61
# - avg_down_aadya    1 106.74
# - sd_down_ellen     1 106.77
# - avg_up_ellen      1 107.44
# - sd_up_aadya       1 109.47
#
# Step:  AIC=104.65
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_up_aadya + avg_down_aadya + avg_jitter_aadya + avg_pl_aadya +
#     sd_up_ellen + sd_down_ellen + sd_rtt_ellen + sd_jitter_ellen +
#     sd_up_aadya + sd_down_aadya + sd_rtt_aadya + sd_jitter_aadya +
#     sd_pl_aadya
#
#                    Df    AIC
# - sd_jitter_aadya   1 102.83
# - sd_rtt_aadya      1 102.96
# - avg_jitter_aadya  1 103.08
# - avg_ellen_jitter  1 103.16
# - sd_jitter_ellen   1 103.24
# - avg_pl_aadya      1 103.77
# - sd_rtt_ellen      1 104.00
# - sd_up_ellen       1 104.59
# - sd_pl_aadya       1 104.62
# <none>                104.65
# - avg_up_aadya      1 104.77
# - avg_down_ellen    1 104.78
# - sd_down_aadya     1 104.81
# - avg_rtt_ellen     1 104.82
# - avg_down_aadya    1 105.40
# - avg_up_ellen      1 105.60
# - sd_down_ellen     1 105.99
# - sd_up_aadya       1 107.53
#
# Step:  AIC=102.83
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_up_aadya + avg_down_aadya + avg_jitter_aadya + avg_pl_aadya +
#     sd_up_ellen + sd_down_ellen + sd_rtt_ellen + sd_jitter_ellen +
#     sd_up_aadya + sd_down_aadya + sd_rtt_aadya + sd_pl_aadya
#
#                    Df    AIC
# - sd_rtt_aadya      1 101.08
# - avg_jitter_aadya  1 101.18
# - avg_ellen_jitter  1 101.32
# - sd_jitter_ellen   1 101.44
# - avg_pl_aadya      1 101.89
# - sd_rtt_ellen      1 102.18
# - sd_up_ellen       1 102.63
# - sd_pl_aadya       1 102.70
# - avg_up_aadya      1 102.83
# <none>                102.83
# - sd_down_aadya     1 102.88
# - avg_down_ellen    1 102.91
# - avg_rtt_ellen     1 102.91
# - avg_down_aadya    1 103.40
# - avg_up_ellen      1 103.60
# - sd_down_ellen     1 104.06
# - sd_up_aadya       1 105.65
#
# Step:  AIC=101.08
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_up_aadya + avg_down_aadya + avg_jitter_aadya + avg_pl_aadya +
#     sd_up_ellen + sd_down_ellen + sd_rtt_ellen + sd_jitter_ellen +
#     sd_up_aadya + sd_down_aadya + sd_pl_aadya
#
#                    Df     AIC
# - avg_jitter_aadya  1  99.285
# - avg_ellen_jitter  1  99.854
# - sd_jitter_ellen   1  99.893
# - avg_pl_aadya      1 100.096
# - sd_rtt_ellen      1 100.369
# - sd_up_ellen       1 100.684
# - sd_pl_aadya       1 100.875
# - avg_rtt_ellen     1 100.910
# - avg_down_ellen    1 100.911
# <none>                101.079
# - sd_down_aadya     1 101.122
# - avg_down_aadya    1 101.604
# - avg_up_aadya      1 101.861
# - avg_up_ellen      1 101.868
# - sd_down_ellen     1 102.113
# - sd_up_aadya       1 103.668
#
# Step:  AIC=99.29
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_up_aadya + avg_down_aadya + avg_pl_aadya + sd_up_ellen +
#     sd_down_ellen + sd_rtt_ellen + sd_jitter_ellen + sd_up_aadya +
#     sd_down_aadya + sd_pl_aadya
#
#                    Df     AIC
# - sd_jitter_ellen   1  97.959
# - avg_ellen_jitter  1  98.093
# - avg_pl_aadya      1  98.514
# - sd_up_ellen       1  98.735
# - avg_down_ellen    1  98.912
# - avg_rtt_ellen     1  98.919
# - sd_rtt_ellen      1  98.977
# - sd_down_aadya     1  99.124
# - sd_pl_aadya       1  99.251
# <none>                 99.285
# - avg_down_aadya    1  99.865
# - avg_up_aadya      1  99.940
# - avg_up_ellen      1  99.983
# - sd_down_ellen     1 100.120
# - sd_up_aadya       1 101.669
#
# Step:  AIC=97.96
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_up_aadya + avg_down_aadya + avg_pl_aadya + sd_up_ellen +
#     sd_down_ellen + sd_rtt_ellen + sd_up_aadya + sd_down_aadya +
#     sd_pl_aadya
#
#                    Df     AIC
# - avg_ellen_jitter  1  96.102
# - avg_pl_aadya      1  96.897
# - sd_rtt_ellen      1  97.055
# - sd_down_aadya     1  97.218
# - sd_up_ellen       1  97.474
# - sd_pl_aadya       1  97.610
# - avg_rtt_ellen     1  97.668
# <none>                 97.959
# - avg_down_aadya    1  98.074
# - avg_down_ellen    1  98.236
# - avg_up_ellen      1  98.513
# - sd_down_ellen     1  98.572
# - avg_up_aadya      1  99.350
# - sd_up_aadya       1 100.016
#
# Step:  AIC=96.1
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_up_aadya +
#     avg_down_aadya + avg_pl_aadya + sd_up_ellen + sd_down_ellen +
#     sd_rtt_ellen + sd_up_aadya + sd_down_aadya + sd_pl_aadya
#
#                  Df    AIC
# - avg_pl_aadya    1 94.904
# - sd_rtt_ellen    1 95.103
# - sd_down_aadya   1 95.292
# - sd_up_ellen     1 95.564
# - sd_pl_aadya     1 95.611
# <none>              96.102
# - avg_rtt_ellen   1 96.136
# - avg_down_aadya  1 96.205
# - avg_up_ellen    1 96.537
# - sd_down_ellen   1 97.213
# - avg_up_aadya    1 97.355
# - avg_down_ellen  1 97.956
# - sd_up_aadya     1 98.074
#
# Step:  AIC=94.9
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_up_aadya +
#     avg_down_aadya + sd_up_ellen + sd_down_ellen + sd_rtt_ellen +
#     sd_up_aadya + sd_down_aadya + sd_pl_aadya
#
#                  Df    AIC
# - sd_up_ellen     1 94.062
# - sd_rtt_ellen    1 94.350
# - avg_down_aadya  1 94.426
# - avg_up_ellen    1 94.566
# - sd_down_aadya   1 94.779
# - avg_rtt_ellen   1 94.823
# <none>              94.904
# - avg_up_aadya    1 95.484
# - sd_pl_aadya     1 95.600
# - sd_up_aadya     1 96.185
# - sd_down_ellen   1 96.733
# - avg_down_ellen  1 97.546
#
# Step:  AIC=94.06
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_up_aadya +
#     avg_down_aadya + sd_down_ellen + sd_rtt_ellen + sd_up_aadya +
#     sd_down_aadya + sd_pl_aadya
#
#                  Df    AIC
# - avg_up_ellen    1 92.765
# - avg_down_aadya  1 93.041
# - sd_down_aadya   1 93.152
# - sd_pl_aadya     1 93.667
# - sd_rtt_ellen    1 93.739
# - avg_rtt_ellen   1 94.025
# <none>              94.062
# - sd_up_aadya     1 94.269
# - avg_up_aadya    1 94.469
# - sd_down_ellen   1 95.132
# - avg_down_ellen  1 96.072
#
# Step:  AIC=92.77
# ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya + avg_down_aadya +
#     sd_down_ellen + sd_rtt_ellen + sd_up_aadya + sd_down_aadya +
#     sd_pl_aadya
#
#                  Df    AIC
# - sd_down_aadya   1 91.402
# - avg_down_aadya  1 91.461
# - sd_pl_aadya     1 91.896
# - sd_rtt_ellen    1 92.378
# - sd_up_aadya     1 92.441
# - avg_up_aadya    1 92.473
# - avg_rtt_ellen   1 92.748
# <none>              92.765
# - sd_down_ellen   1 93.192
# - avg_down_ellen  1 94.808
#
# Step:  AIC=91.4
# ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya + avg_down_aadya +
#     sd_down_ellen + sd_rtt_ellen + sd_up_aadya + sd_pl_aadya
#
#                  Df    AIC
# - avg_down_aadya  1 89.797
# - sd_pl_aadya     1 90.103
# - sd_rtt_ellen    1 90.805
# - avg_up_aadya    1 91.305
# - sd_up_aadya     1 91.340
# <none>              91.402
# - sd_down_ellen   1 91.458
# - avg_rtt_ellen   1 92.518
# - avg_down_ellen  1 93.138
#
# Step:  AIC=89.8
# ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya + sd_down_ellen +
#     sd_rtt_ellen + sd_up_aadya + sd_pl_aadya
#
#                  Df    AIC
# - sd_pl_aadya     1 88.275
# - sd_rtt_ellen    1 88.885
# - sd_up_aadya     1 89.434
# - avg_up_aadya    1 89.617
# <none>              89.797
# - sd_down_ellen   1 89.883
# - avg_rtt_ellen   1 90.572
# - avg_down_ellen  1 91.564
#
# Step:  AIC=88.27
# ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya + sd_down_ellen +
#     sd_rtt_ellen + sd_up_aadya
#
#                  Df    AIC
# - sd_rtt_ellen    1 87.328
# - sd_up_aadya     1 87.770
# - avg_up_aadya    1 88.199
# <none>              88.275
# - sd_down_ellen   1 88.668
# - avg_rtt_ellen   1 89.167
# - avg_down_ellen  1 90.307
#
# Step:  AIC=87.33
# ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya + sd_down_ellen +
#     sd_up_aadya
#
#                  Df    AIC
# - sd_up_aadya     1 86.513
# - sd_down_ellen   1 87.075
# - avg_rtt_ellen   1 87.170
# <none>              87.328
# - avg_down_ellen  1 88.313
# - avg_up_aadya    1 89.058
#
# Step:  AIC=86.51
# ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya + sd_down_ellen
#
#                  Df    AIC
# - sd_down_ellen   1 85.815
# - avg_rtt_ellen   1 85.926
# <none>              86.513
# - avg_down_ellen  1 87.818
# - avg_up_aadya    1 94.951
#
# Step:  AIC=85.82
# ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya
#
#                  Df    AIC
# <none>              85.815
# - avg_down_ellen  1 86.253
# - avg_rtt_ellen   1 86.546
# - avg_up_aadya    1 94.361
# formula: ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya
# data:    all_table
#
#  link  threshold nobs logLik AIC   niter max.grad cond.H
#  logit flexible  37   -35.91 85.82 7(2)  1.42e-12 5.4e+05
#
# Coefficients:
#                Estimate Std. Error z value Pr(>|z|)
# avg_down_ellen  0.02965    0.01936   1.531  0.12577
# avg_rtt_ellen  -0.11109    0.07299  -1.522  0.12801
# avg_up_aadya    0.11053    0.03802   2.907  0.00365 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Threshold coefficients:
#          Estimate Std. Error z value
# 0|0.33    -0.4758     2.2469  -0.212
# 0.33|0.5   0.4156     2.2296   0.186
# 0.5|0.67   0.6101     2.2244   0.274
# 0.67|1     1.5568     2.2536   0.691
# plot without title

# %% [markdown]
# ### BIC

# %%
fit_bic <- step(fit, k = log(length(all_table$ordered)))
summary(fit_bic)
par(bg = "white")
par(bg = "white")
preds_bic <-predict(fit_bic, all_table)
plot(preds_bic$fit, all_table$ordered)
# Out:
# Start:  AIC=149.07
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_pl_ellen + avg_up_aadya + avg_down_aadya + avg_rtt_aadya +
#     avg_jitter_aadya + avg_pl_aadya + sd_up_ellen + sd_down_ellen +
#     sd_rtt_ellen + sd_jitter_ellen + sd_pl_ellen + sd_up_aadya +
#     sd_down_aadya + sd_rtt_aadya + sd_jitter_aadya + sd_pl_aadya
#
#                    Df    AIC
# - avg_pl_ellen      1 145.46
# - avg_rtt_aadya     1 145.53
# - sd_jitter_aadya   1 145.58
# - sd_pl_ellen       1 145.62
# - avg_jitter_aadya  1 145.69
# - sd_rtt_aadya      1 145.76
# - avg_ellen_jitter  1 145.95
# - sd_jitter_ellen   1 146.02
# - avg_pl_aadya      1 146.33
# - sd_rtt_ellen      1 146.51
# - avg_down_ellen    1 146.67
# - avg_down_aadya    1 146.98
# - avg_rtt_ellen     1 146.99
# - sd_down_aadya     1 147.10
# - sd_pl_aadya       1 147.12
# - sd_up_ellen       1 147.16
# - avg_up_aadya      1 147.53
# - sd_down_ellen     1 147.81
# - avg_up_ellen      1 148.23
# <none>                149.07
# - sd_up_aadya       1 149.39
#
# Step:  AIC=145.46
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_up_aadya + avg_down_aadya + avg_rtt_aadya + avg_jitter_aadya +
#     avg_pl_aadya + sd_up_ellen + sd_down_ellen + sd_rtt_ellen +
#     sd_jitter_ellen + sd_pl_ellen + sd_up_aadya + sd_down_aadya +
#     sd_rtt_aadya + sd_jitter_aadya + sd_pl_aadya
#
#                    Df    AIC
# - avg_rtt_aadya     1 141.92
# - sd_jitter_aadya   1 141.98
# - sd_pl_ellen       1 142.06
# - avg_jitter_aadya  1 142.08
# - sd_rtt_aadya      1 142.22
# - avg_ellen_jitter  1 142.36
# - sd_jitter_ellen   1 142.41
# - avg_pl_aadya      1 142.73
# - sd_rtt_ellen      1 142.93
# - avg_down_ellen    1 143.37
# - sd_pl_aadya       1 143.51
# - sd_down_aadya     1 143.70
# - avg_rtt_ellen     1 143.72
# - avg_up_aadya      1 143.92
# - sd_up_ellen       1 144.02
# - avg_down_aadya    1 144.17
# - sd_down_ellen     1 144.20
# - avg_up_ellen      1 144.62
# <none>                145.46
# - sd_up_aadya       1 145.78
#
# Step:  AIC=141.92
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_up_aadya + avg_down_aadya + avg_jitter_aadya + avg_pl_aadya +
#     sd_up_ellen + sd_down_ellen + sd_rtt_ellen + sd_jitter_ellen +
#     sd_pl_ellen + sd_up_aadya + sd_down_aadya + sd_rtt_aadya +
#     sd_jitter_aadya + sd_pl_aadya
#
#                    Df    AIC
# - sd_pl_ellen       1 138.48
# - sd_jitter_aadya   1 138.51
# - sd_rtt_aadya      1 138.61
# - avg_jitter_aadya  1 138.76
# - avg_ellen_jitter  1 138.84
# - sd_jitter_ellen   1 138.95
# - sd_rtt_ellen      1 139.39
# - avg_pl_aadya      1 139.47
# - avg_down_ellen    1 139.87
# - avg_rtt_ellen     1 140.21
# - sd_down_aadya     1 140.32
# - sd_pl_aadya       1 140.37
# - sd_up_ellen       1 140.42
# - avg_up_aadya      1 140.43
# - avg_down_aadya    1 140.57
# - sd_down_ellen     1 140.60
# - avg_up_ellen      1 141.27
# <none>                141.92
# - sd_up_aadya       1 143.30
#
# Step:  AIC=138.48
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_up_aadya + avg_down_aadya + avg_jitter_aadya + avg_pl_aadya +
#     sd_up_ellen + sd_down_ellen + sd_rtt_ellen + sd_jitter_ellen +
#     sd_up_aadya + sd_down_aadya + sd_rtt_aadya + sd_jitter_aadya +
#     sd_pl_aadya
#
#                    Df    AIC
# - sd_jitter_aadya   1 135.05
# - sd_rtt_aadya      1 135.18
# - avg_jitter_aadya  1 135.29
# - avg_ellen_jitter  1 135.38
# - sd_jitter_ellen   1 135.46
# - avg_pl_aadya      1 135.99
# - sd_rtt_ellen      1 136.21
# - sd_up_ellen       1 136.81
# - sd_pl_aadya       1 136.84
# - avg_up_aadya      1 136.99
# - avg_down_ellen    1 137.00
# - sd_down_aadya     1 137.03
# - avg_rtt_ellen     1 137.03
# - avg_down_aadya    1 137.62
# - avg_up_ellen      1 137.82
# - sd_down_ellen     1 138.21
# <none>                138.48
# - sd_up_aadya       1 139.75
#
# Step:  AIC=135.05
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_up_aadya + avg_down_aadya + avg_jitter_aadya + avg_pl_aadya +
#     sd_up_ellen + sd_down_ellen + sd_rtt_ellen + sd_jitter_ellen +
#     sd_up_aadya + sd_down_aadya + sd_rtt_aadya + sd_pl_aadya
#
#                    Df    AIC
# - sd_rtt_aadya      1 131.69
# - avg_jitter_aadya  1 131.78
# - avg_ellen_jitter  1 131.93
# - sd_jitter_ellen   1 132.05
# - avg_pl_aadya      1 132.50
# - sd_rtt_ellen      1 132.78
# - sd_up_ellen       1 133.23
# - sd_pl_aadya       1 133.30
# - avg_up_aadya      1 133.44
# - sd_down_aadya     1 133.49
# - avg_down_ellen    1 133.51
# - avg_rtt_ellen     1 133.52
# - avg_down_aadya    1 134.01
# - avg_up_ellen      1 134.21
# - sd_down_ellen     1 134.67
# <none>                135.05
# - sd_up_aadya       1 136.25
#
# Step:  AIC=131.69
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_up_aadya + avg_down_aadya + avg_jitter_aadya + avg_pl_aadya +
#     sd_up_ellen + sd_down_ellen + sd_rtt_ellen + sd_jitter_ellen +
#     sd_up_aadya + sd_down_aadya + sd_pl_aadya
#
#                    Df    AIC
# - avg_jitter_aadya  1 128.28
# - avg_ellen_jitter  1 128.85
# - sd_jitter_ellen   1 128.89
# - avg_pl_aadya      1 129.09
# - sd_rtt_ellen      1 129.37
# - sd_up_ellen       1 129.68
# - sd_pl_aadya       1 129.87
# - avg_rtt_ellen     1 129.91
# - avg_down_ellen    1 129.91
# - sd_down_aadya     1 130.12
# - avg_down_aadya    1 130.60
# - avg_up_aadya      1 130.86
# - avg_up_ellen      1 130.87
# - sd_down_ellen     1 131.11
# <none>                131.69
# - sd_up_aadya       1 132.66
#
# Step:  AIC=128.28
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_up_aadya + avg_down_aadya + avg_pl_aadya + sd_up_ellen +
#     sd_down_ellen + sd_rtt_ellen + sd_jitter_ellen + sd_up_aadya +
#     sd_down_aadya + sd_pl_aadya
#
#                    Df    AIC
# - sd_jitter_ellen   1 125.34
# - avg_ellen_jitter  1 125.48
# - avg_pl_aadya      1 125.90
# - sd_up_ellen       1 126.12
# - avg_down_ellen    1 126.30
# - avg_rtt_ellen     1 126.30
# - sd_rtt_ellen      1 126.36
# - sd_down_aadya     1 126.51
# - sd_pl_aadya       1 126.64
# - avg_down_aadya    1 127.25
# - avg_up_aadya      1 127.33
# - avg_up_ellen      1 127.37
# - sd_down_ellen     1 127.51
# <none>                128.28
# - sd_up_aadya       1 129.05
#
# Step:  AIC=125.34
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_ellen_jitter +
#     avg_up_aadya + avg_down_aadya + avg_pl_aadya + sd_up_ellen +
#     sd_down_ellen + sd_rtt_ellen + sd_up_aadya + sd_down_aadya +
#     sd_pl_aadya
#
#                    Df    AIC
# - avg_ellen_jitter  1 121.88
# - avg_pl_aadya      1 122.67
# - sd_rtt_ellen      1 122.83
# - sd_down_aadya     1 122.99
# - sd_up_ellen       1 123.25
# - sd_pl_aadya       1 123.39
# - avg_rtt_ellen     1 123.44
# - avg_down_aadya    1 123.85
# - avg_down_ellen    1 124.01
# - avg_up_ellen      1 124.29
# - sd_down_ellen     1 124.35
# - avg_up_aadya      1 125.12
# <none>                125.34
# - sd_up_aadya       1 125.79
#
# Step:  AIC=121.88
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_up_aadya +
#     avg_down_aadya + avg_pl_aadya + sd_up_ellen + sd_down_ellen +
#     sd_rtt_ellen + sd_up_aadya + sd_down_aadya + sd_pl_aadya
#
#                  Df    AIC
# - avg_pl_aadya    1 119.07
# - sd_rtt_ellen    1 119.27
# - sd_down_aadya   1 119.46
# - sd_up_ellen     1 119.73
# - sd_pl_aadya     1 119.77
# - avg_rtt_ellen   1 120.30
# - avg_down_aadya  1 120.37
# - avg_up_ellen    1 120.70
# - sd_down_ellen   1 121.38
# - avg_up_aadya    1 121.52
# <none>              121.88
# - avg_down_ellen  1 122.12
# - sd_up_aadya     1 122.24
#
# Step:  AIC=119.07
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_up_aadya +
#     avg_down_aadya + sd_up_ellen + sd_down_ellen + sd_rtt_ellen +
#     sd_up_aadya + sd_down_aadya + sd_pl_aadya
#
#                  Df    AIC
# - sd_up_ellen     1 116.61
# - sd_rtt_ellen    1 116.90
# - avg_down_aadya  1 116.98
# - avg_up_ellen    1 117.12
# - sd_down_aadya   1 117.33
# - avg_rtt_ellen   1 117.38
# - avg_up_aadya    1 118.04
# - sd_pl_aadya     1 118.15
# - sd_up_aadya     1 118.74
# <none>              119.07
# - sd_down_ellen   1 119.29
# - avg_down_ellen  1 120.10
#
# Step:  AIC=116.61
# ordered ~ avg_up_ellen + avg_down_ellen + avg_rtt_ellen + avg_up_aadya +
#     avg_down_aadya + sd_down_ellen + sd_rtt_ellen + sd_up_aadya +
#     sd_down_aadya + sd_pl_aadya
#
#                  Df    AIC
# - avg_up_ellen    1 113.71
# - avg_down_aadya  1 113.98
# - sd_down_aadya   1 114.09
# - sd_pl_aadya     1 114.61
# - sd_rtt_ellen    1 114.68
# - avg_rtt_ellen   1 114.97
# - sd_up_aadya     1 115.21
# - avg_up_aadya    1 115.41
# - sd_down_ellen   1 116.07
# <none>              116.61
# - avg_down_ellen  1 117.01
#
# Step:  AIC=113.71
# ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya + avg_down_aadya +
#     sd_down_ellen + sd_rtt_ellen + sd_up_aadya + sd_down_aadya +
#     sd_pl_aadya
#
#                  Df    AIC
# - sd_down_aadya   1 110.73
# - avg_down_aadya  1 110.79
# - sd_pl_aadya     1 111.23
# - sd_rtt_ellen    1 111.71
# - sd_up_aadya     1 111.77
# - avg_up_aadya    1 111.80
# - avg_rtt_ellen   1 112.08
# - sd_down_ellen   1 112.52
# <none>              113.71
# - avg_down_ellen  1 114.14
#
# Step:  AIC=110.73
# ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya + avg_down_aadya +
#     sd_down_ellen + sd_rtt_ellen + sd_up_aadya + sd_pl_aadya
#
#                  Df    AIC
# - avg_down_aadya  1 107.52
# - sd_pl_aadya     1 107.82
# - sd_rtt_ellen    1 108.53
# - avg_up_aadya    1 109.03
# - sd_up_aadya     1 109.06
# - sd_down_ellen   1 109.18
# - avg_rtt_ellen   1 110.24
# <none>              110.73
# - avg_down_ellen  1 110.86
#
# Step:  AIC=107.52
# ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya + sd_down_ellen +
#     sd_rtt_ellen + sd_up_aadya + sd_pl_aadya
#
#                  Df    AIC
# - sd_pl_aadya     1 104.38
# - sd_rtt_ellen    1 104.99
# - sd_up_aadya     1 105.54
# - avg_up_aadya    1 105.73
# - sd_down_ellen   1 105.99
# - avg_rtt_ellen   1 106.68
# <none>              107.52
# - avg_down_ellen  1 107.67
#
# Step:  AIC=104.38
# ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya + sd_down_ellen +
#     sd_rtt_ellen + sd_up_aadya
#
#                  Df    AIC
# - sd_rtt_ellen    1 101.83
# - sd_up_aadya     1 102.27
# - avg_up_aadya    1 102.70
# - sd_down_ellen   1 103.17
# - avg_rtt_ellen   1 103.67
# <none>              104.38
# - avg_down_ellen  1 104.81
#
# Step:  AIC=101.83
# ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya + sd_down_ellen +
#     sd_up_aadya
#
#                  Df     AIC
# - sd_up_aadya     1  99.400
# - sd_down_ellen   1  99.963
# - avg_rtt_ellen   1 100.057
# - avg_down_ellen  1 101.200
# <none>              101.826
# - avg_up_aadya    1 101.945
#
# Step:  AIC=99.4
# ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya + sd_down_ellen
#
#                  Df     AIC
# - sd_down_ellen   1  97.092
# - avg_rtt_ellen   1  97.203
# - avg_down_ellen  1  99.095
# <none>               99.400
# - avg_up_aadya    1 106.227
#
# Step:  AIC=97.09
# ordered ~ avg_down_ellen + avg_rtt_ellen + avg_up_aadya
#
#                  Df     AIC
# - avg_down_ellen  1  95.919
# - avg_rtt_ellen   1  96.212
# <none>               97.092
# - avg_up_aadya    1 104.027
#
# Step:  AIC=95.92
# ordered ~ avg_rtt_ellen + avg_up_aadya
#
#                 Df     AIC
# - avg_rtt_ellen  1  94.639
# <none>              95.919
# - avg_up_aadya   1 107.408
#
# Step:  AIC=94.64
# ordered ~ avg_up_aadya
#
#                Df     AIC
# <none>             94.639
# - avg_up_aadya  1 107.395
# formula: ordered ~ avg_up_aadya
# data:    all_table
#
#  link  threshold nobs logLik AIC   niter max.grad cond.H
#  logit flexible  37   -38.29 86.58 6(2)  3.23e-10 4.2e+03
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# avg_up_aadya  0.12350    0.03504   3.525 0.000424 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Threshold coefficients:
#          Estimate Std. Error z value
# 0|0.33     1.7134     0.5781   2.964
# 0.33|0.5   2.5040     0.6534   3.832
# 0.5|0.67   2.6832     0.6730   3.987
# 0.67|1     3.5967     0.8080   4.451
# plot without title

# %% [markdown]
# ## regression with webRTC vars

# %%
subjective <- read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression/regression_tables/fieldwork/subjective_table.csv")

# %%
subjective <- read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression/regression_tables/fieldwork/subjective_table.csv")
web_stats <- read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression_2_(web_to_serviceable)/independent_vars_tables/fieldwork_independent_vars_table.csv")
#rename the id col in subjective to perform a merge
names(subjective)[names(subjective) == "identifier"] <- "ID"
#add the ordinal var to web_stats
web_stats <- merge(web_stats, subjective[, c("ID", "serviceable_agg")], by = "ID", all.x = TRUE)
unique(subjective$serviceable_agg)
# Out:
# [1] 0 1

# %% [markdown]
# ### fit a big regression
# vars removed : 0 columns
# linearly dependent cols: frame heights removed

# %%
fit_rtc <- glm(serviceable_agg ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya + IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen + IT01V_frameWidth_aadya 
+ IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen + IT01V_bytesReceived_in_bits_s_aadya 
+ IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya + IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya 
+ IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya + OT01V_packetsSent_s_ellen 
+ OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen + OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_ellen + OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya 
+ OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya + RIV_roundTripTime_ellen 
+ RIV_roundTripTime_aadya + RIV_fractionLost_ellen + RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya + RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen 
+ ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya

, data = web_stats, family = binomial())
summary(fit_rtc)
# Out:
# Error in family$linkfun(mustart): Argument mu must be a nonempty numeric vector
# Traceback:
#
# 1. glm(serviceable_agg ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya +
#  .     IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + IT01V_frameWidth_ellen +
#  .     IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen +
#  .     IT01V_totalFreezesDuration_aadya + IT01V_framesPerSecond_ellen +
#  .     IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen +
#  .     IT01V_bytesReceived_in_bits_s_aadya + IT01V_totalProcessingDelay_ellen +
#  .     IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya +
#  .     IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya +
#  .     IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya +
#  .     IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya +
#  .     OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen +
#  .     OT01V_bytesSent_in_bits_s_aadya + OT01V_frameWidth_ellen +
#  .     OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya +
#  .     OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya +
#  .     OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya +
#  .     RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + RIV_fractionLost_ellen +
#  .     RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya +
#  .     RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen +
#  .     ROA_roundTripTime_aadya + AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya,
#  .     data = web_stats, family = binomial())
# 2. eval(call(if (is.function(method)) "method" else method, x = X,
#  .     y = Y, weights = weights, start = start, etastart = etastart,
#  .     mustart = mustart, offset = offset, family = family, control = control,
#  .     intercept = attr(mt, "intercept") > 0L, singular.ok = singular.ok))
# 3. eval(call(if (is.function(method)) "method" else method, x = X,
#  .     y = Y, weights = weights, start = start, etastart = etastart,
#  .     mustart = mustart, offset = offset, family = family, control = control,
#  .     intercept = attr(mt, "intercept") > 0L, singular.ok = singular.ok))
# 4. glm.fit(x = structure(numeric(0), dim = c(0L, 47L), dimnames = list(
#  .     NULL, c("(Intercept)", "IT01V_packetsRecieved_ellen", "IT01V_packetsRecieved_aadya",
#  .     "IT01V_packetsLost_ellen", "IT01V_packetsLost_aadya", "IT01V_frameWidth_ellen",
#  .     "IT01V_frameWidth_aadya", "IT01V_totalFreezesDuration_ellen",
#  .     "IT01V_totalFreezesDuration_aadya", "IT01V_framesPerSecond_ellen",
#  .     "IT01V_framesPerSecond_aadya", "IT01V_bytesReceived_in_bits_s_ellen",
#  .     "IT01V_bytesReceived_in_bits_s_aadya", "IT01V_totalProcessingDelay_ellen",
#  .     "IT01V_totalProcessingDelay_aadya", "IT01V_jitter_ellen",
#  .     "IT01V_jitter_aadya", "IT01V_jitterBufferDelay_emissions_ellen",
#  .     "IT01V_jitterBufferDelay_emissions_aadya", "IT01A_bytesReceived_in_bits_s_ellen",
#  .     "IT01A_bytesReceived_in_bits_s_aadya", "IT01A_jitterBufferDelay_emissions_ellen",
#  .     "IT01A_jitterBufferDelay_emissions_aadya", "OT01V_packetsSent_s_ellen",
#  .     "OT01V_packetsSent_s_aadya", "OT01V_bytesSent_in_bits_s_ellen",
#  .     "OT01V_bytesSent_in_bits_s_aadya", "OT01V_frameWidth_ellen",
#  .     "OT01V_frameWidth_aadya", "OT01V_framesPerSecond_ellen",
#  .     "OT01V_framesPerSecond_aadya", "OT01V_totalPacketSendDelay_ellen",
#  .     "OT01V_totalPacketSendDelay_aadya", "OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen",
#  .     "OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya", "RIV_roundTripTime_ellen",
#  .     "RIV_roundTripTime_aadya", "RIV_fractionLost_ellen", "RIV_fractionLost_aadya",
#  .     "RIA_fractionLost_ellen", "RIA_fractionLost_aadya", "RIA_roundTripTime_ellen",
#  .     "RIA_roundTripTime_aadya", "ROA_roundTripTime_ellen", "ROA_roundTripTime_aadya",
#  .     "AP_totalPlayoutDelay_ellen", "AP_totalPlayoutDelay_aadya"
#  .     )), assign = 0:46), y = integer(0), weights = NULL, start = NULL,
#  .     etastart = NULL, mustart = NULL, offset = NULL, family = structure(list(
#  .         family = "binomial", link = "logit", linkfun = function (mu)
#  .         .Call(C_logit_link, mu), linkinv = function (eta)
#  .         .Call(C_logit_linkinv, eta), variance = function (mu)
#  .         mu * (1 - mu), dev.resids = function (y, mu, wt)
#  .         .Call(C_binomial_dev_resids, y, mu, wt), aic = function (y,
#  .             n, mu, wt, dev)
#  .         {
#  .             m <- if (any(n > 1))
#  .                 n
#  .             else wt
#  .             -2 * sum(ifelse(m > 0, (wt/m), 0) * dbinom(round(m *
#  .                 y), round(m), mu, log = TRUE))
#  .         }, mu.eta = function (eta)
#  .         .Call(C_logit_mu_eta, eta), initialize = {
#  .             if (NCOL(y) == 1) {
#  .                 if (is.factor(y))
#  .                   y <- y != levels(y)[1L]
#  .                 n <- rep.int(1, nobs)
#  .                 y[weights == 0] <- 0
#  .                 if (any(y < 0 | y > 1))
#  .                   stop("y values must be 0 <= y <= 1")
#  .                 mustart <- (weights * y + 0.5)/(weights + 1)
#  .                 m <- weights * y
#  .                 if ("binomial" == "binomial" && any(abs(m - round(m)) >
#  .                   0.001))
#  .                   warning(gettextf("non-integer #successes in a %s glm!",
#  .                     "binomial"), domain = NA)
#  .             }
#  .             else if (NCOL(y) == 2) {
#  .                 if ("binomial" == "binomial" && any(abs(y - round(y)) >
#  .                   0.001))
#  .                   warning(gettextf("non-integer counts in a %s glm!",
#  .                     "binomial"), domain = NA)
#  .                 n <- (y1 <- y[, 1L]) + y[, 2L]
#  .                 y <- y1/n
#  .                 if (any(n0 <- n == 0))
#  .                   y[n0] <- 0
#  .                 weights <- weights * n
#  .                 mustart <- (n * y + 0.5)/(n + 1)
#  .             }
#  .             else stop(gettextf("for the '%s' family, y must be a vector of 0 and 1's\nor a 2 column matrix where col 1 is no. successes and col 2 is no. failures",
#  .                 "binomial"), domain = NA)
#  .         }, validmu = function (mu)
#  .         all(is.finite(mu)) && all(mu > 0 & mu < 1), valideta = function (eta)
#  .         TRUE, simulate = function (object, nsim)
#  .         {
#  .             ftd <- fitted(object)
#  .             n <- length(ftd)
#  .             ntot <- n * nsim
#  .             wts <- object$prior.weights
#  .             if (any(wts%%1 != 0))
#  .                 stop("cannot simulate from non-integer prior.weights")
#  .             if (!is.null(m <- object$model)) {
#  .                 y <- model.response(m)
#  .                 if (is.factor(y)) {
#  .                   yy <- factor(1 + rbinom(ntot, size = 1, prob = ftd),
#  .                     labels = levels(y))
#  .                   split(yy, rep(seq_len(nsim), each = n))
#  .                 }
#  .                 else if (is.matrix(y) && ncol(y) == 2) {
#  .                   yy <- vector("list", nsim)
#  .                   for (i in seq_len(nsim)) {
#  .                     Y <- rbinom(n, size = wts, prob = ftd)
#  .                     YY <- cbind(Y, wts - Y)
#  .                     colnames(YY) <- colnames(y)
#  .                     yy[[i]] <- YY
#  .                   }
#  .                   yy
#  .                 }
#  .                 else rbinom(ntot, size = wts, prob = ftd)/wts
#  .             }
#  .             else rbinom(ntot, size = wts, prob = ftd)/wts
#  .         }, dispersion = 1), class = "family"), control = list(
#  .         epsilon = 1e-08, maxit = 25, trace = FALSE), intercept = TRUE,
#  .     singular.ok = TRUE)
# 5. etastart %||% {
#  .     if (!is.null(start))
#  .         if (length(start) != nvars)
#  .             stop(gettextf("length of 'start' should equal %d and correspond to initial coefs for %s",
#  .                 nvars, paste(deparse(xnames), collapse = ", ")),
#  .                 domain = NA)
#  .         else {
#  .             coefold <- start
#  .             offset + as.vector(if (NCOL(x) == 1L)
#  .                 x * start
#  .             else x %*% start)
#  .         }
#  .     else family$linkfun(mustart)
#  . }
# 6. family$linkfun(mustart)

# %%
par(bg = "white")
plot(predict(fit_rtc, web_stats), web_stats$serviceable_agg)
# Out:
# plot without title

# %%
install.packages("glmnet")
library(glmnet)
library(pROC)
source("wrapper.R")
my.pred.stats <- function(prob, target)
{
  classes = levels(target)
  
  # Convert probabilities to best guesses at classes
  pred = factor(prob > 1/2, c(F,T), classes)
  
  cat("---------------------------------------------------------------------------\n")
  cat("Performance statistics:\n")
  cat("\n")
  cat("Confusion matrix:\n\n")
  T = table(pred,target)
  print(T)
  cat("\n")
  cat("Classification accuracy =", mean(pred==target), "\n")
  cat("Sensitivity             =", T[2,2]/(T[1,2]+T[2,2]), "\n")
  cat("Specificity             =", T[1,1]/(T[1,1]+T[2,1]), "\n")
  roc.obj = roc(response=as.vector(as.numeric(target))-1, as.vector(prob), quiet=TRUE)
  cat("Area-under-curve        =", roc.obj$auc, "\n")
  
  # Prob is probability of success, so if the target is not a success, flip the probability
  # to get probability of failure
  prob[target==classes[1]] = 1 - prob[target==classes[1]]
  # Also make sure we never get exactly zero or one for probabilities due to numerical rounding
  prob = (prob+1e-10)/(1+2e-10)
  
  cat("Logarithmic loss        =", -sum(log(prob)), "\n")
  cat("\n")
  
  plot(roc.obj)
  
  cat("---------------------------------------------------------------------------\n")
}
# Out:
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpyGic5f/downloaded_packages
# Type 'citation("pROC")' for a citation.
#
#
# Attaching package: 'pROC'
#
#
# The following objects are masked from 'package:stats':
#
#     cov, smooth, var

# %%
names(web_stats)
# Out:
#  [1] "ID"
#  [2] "IT01V_packetsRecieved_ellen"
#  [3] "IT01V_packetsRecieved_aadya"
#  [4] "IT01V_packetsLost_ellen"
#  [5] "IT01V_packetsLost_aadya"
#  [6] "IT01V_frameWidth_ellen"
#  [7] "IT01V_frameWidth_aadya"
#  [8] "IT01V_frameHeight_ellen"
#  [9] "IT01V_frameHeight_aadya"
# [10] "IT01V_totalFreezesDuration_ellen"
# [11] "IT01V_totalFreezesDuration_aadya"
# [12] "IT01V_framesPerSecond_ellen"
# [13] "IT01V_framesPerSecond_aadya"
# [14] "IT01V_bytesReceived_in_bits_s_ellen"
# [15] "IT01V_bytesReceived_in_bits_s_aadya"
# [16] "IT01V_totalProcessingDelay_ellen"
# [17] "IT01V_totalProcessingDelay_aadya"
# [18] "IT01V_jitter_ellen"
# [19] "IT01V_jitter_aadya"
# [20] "IT01V_jitterBufferDelay_emissions_ellen"
# [21] "IT01V_jitterBufferDelay_emissions_aadya"
# [22] "IT01A_bytesReceived_in_bits_s_ellen"
# [23] "IT01A_bytesReceived_in_bits_s_aadya"
# [24] "IT01A_jitterBufferDelay_emissions_ellen"
# [25] "IT01A_jitterBufferDelay_emissions_aadya"
# [26] "OT01V_packetsSent_s_ellen"
# [27] "OT01V_packetsSent_s_aadya"
# [28] "OT01V_bytesSent_in_bits_s_ellen"
# [29] "OT01V_bytesSent_in_bits_s_aadya"
# [30] "OT01V_frameWidth_ellen"
# [31] "OT01V_frameWidth_aadya"
# [32] "OT01V_framesPerSecond_ellen"
# [33] "OT01V_framesPerSecond_aadya"
# [34] "OT01V_totalPacketSendDelay_ellen"
# [35] "OT01V_totalPacketSendDelay_aadya"
# [36] "OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen"
# [37] "OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya"
# [38] "RIV_roundTripTime_ellen"
# [39] "RIV_roundTripTime_aadya"
# [40] "RIV_fractionLost_ellen"
# [41] "RIV_fractionLost_aadya"
# [42] "RIA_fractionLost_ellen"
# [43] "RIA_fractionLost_aadya"
# [44] "RIA_roundTripTime_ellen"
# [45] "RIA_roundTripTime_aadya"
# [46] "ROA_roundTripTime_ellen"
# [47] "ROA_roundTripTime_aadya"
# [48] "AP_totalPlayoutDelay_ellen"
# [49] "AP_totalPlayoutDelay_aadya"
# [50] "serviceable_agg"

# %%
# Clean the data
web_stats_clean <- na.omit(web_stats)

# Set seed for reproducibility
set.seed(123)

# Calculate the row indices for the 70% training set
train_indices <- sample(1:nrow(web_stats_clean), size = 0.7 * nrow(web_stats_clean))

# Split the data into training and testing sets
train_data <- web_stats_clean[train_indices, ]
test_data <- web_stats_clean[-train_indices, ]

# Create the response variable from the training data
response <- factor(train_data$serviceable_agg, levels = c(0, 1))

# Create predictors matrix for the training data
train_predictors <- as.matrix(train_data[, c('IT01V_packetsRecieved_ellen','IT01V_packetsRecieved_aadya','IT01V_packetsLost_ellen','IT01V_packetsLost_aadya',
'IT01V_frameWidth_ellen','IT01V_frameWidth_aadya','IT01V_frameHeight_ellen','IT01V_frameHeight_aadya','IT01V_totalFreezesDuration_ellen','IT01V_totalFreezesDuration_aadya',
'IT01V_framesPerSecond_ellen','IT01V_framesPerSecond_aadya','IT01V_bytesReceived_in_bits_s_ellen','IT01V_bytesReceived_in_bits_s_aadya',
'IT01V_totalProcessingDelay_ellen','IT01V_totalProcessingDelay_aadya','IT01V_jitter_ellen','IT01V_jitter_aadya','IT01V_jitterBufferDelay_emissions_ellen',
'IT01V_jitterBufferDelay_emissions_aadya','IT01A_bytesReceived_in_bits_s_ellen','IT01A_bytesReceived_in_bits_s_aadya','IT01A_jitterBufferDelay_emissions_ellen',
'IT01A_jitterBufferDelay_emissions_aadya','OT01V_packetsSent_s_ellen','OT01V_packetsSent_s_aadya','OT01V_bytesSent_in_bits_s_ellen','OT01V_bytesSent_in_bits_s_aadya',
'OT01V_frameWidth_ellen','OT01V_frameWidth_aadya','OT01V_framesPerSecond_ellen','OT01V_framesPerSecond_aadya','OT01V_totalPacketSendDelay_ellen',
'OT01V_totalPacketSendDelay_aadya','OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen','OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya',
'RIV_roundTripTime_ellen','RIV_roundTripTime_aadya','RIV_fractionLost_ellen','RIV_fractionLost_aadya','RIA_fractionLost_ellen','RIA_fractionLost_aadya',
'RIA_roundTripTime_ellen','RIA_roundTripTime_aadya','ROA_roundTripTime_ellen','ROA_roundTripTime_aadya','AP_totalPlayoutDelay_ellen','AP_totalPlayoutDelay_aadya')])

# Fit the model using the training data
lasso.fit = glmnet.f(response ~ train_predictors, data = train_data, family = "binomial", lambda = 0)
# Out:
# Error in if (is.null(np) | (np[2] <= 1)) stop("x should be a matrix with 2 or more columns"): argument is of length zero
# Traceback:
#
# 1. glmnet.f(response ~ train_predictors, data = train_data, family = "binomial",
#  .     lambda = 0)
# 2. glmnet(X, y, ...)

# %%
# Create the predictors matrix for the test data
test_predictors <- as.matrix(test_data[, c('IT01V_packetsRecieved_ellen','IT01V_packetsRecieved_aadya','IT01V_packetsLost_ellen','IT01V_packetsLost_aadya',
'IT01V_frameWidth_ellen','IT01V_frameWidth_aadya','IT01V_frameHeight_ellen','IT01V_frameHeight_aadya','IT01V_totalFreezesDuration_ellen','IT01V_totalFreezesDuration_aadya',
'IT01V_framesPerSecond_ellen','IT01V_framesPerSecond_aadya','IT01V_bytesReceived_in_bits_s_ellen','IT01V_bytesReceived_in_bits_s_aadya',
'IT01V_totalProcessingDelay_ellen','IT01V_totalProcessingDelay_aadya','IT01V_jitter_ellen','IT01V_jitter_aadya','IT01V_jitterBufferDelay_emissions_ellen',
'IT01V_jitterBufferDelay_emissions_aadya','IT01A_bytesReceived_in_bits_s_ellen','IT01A_bytesReceived_in_bits_s_aadya','IT01A_jitterBufferDelay_emissions_ellen',
'IT01A_jitterBufferDelay_emissions_aadya','OT01V_packetsSent_s_ellen','OT01V_packetsSent_s_aadya','OT01V_bytesSent_in_bits_s_ellen','OT01V_bytesSent_in_bits_s_aadya',
'OT01V_frameWidth_ellen','OT01V_frameWidth_aadya','OT01V_framesPerSecond_ellen','OT01V_framesPerSecond_aadya','OT01V_totalPacketSendDelay_ellen',
'OT01V_totalPacketSendDelay_aadya','OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen','OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya',
'RIV_roundTripTime_ellen','RIV_roundTripTime_aadya','RIV_fractionLost_ellen','RIV_fractionLost_aadya','RIA_fractionLost_ellen','RIA_fractionLost_aadya',
'RIA_roundTripTime_ellen','RIA_roundTripTime_aadya','ROA_roundTripTime_ellen','ROA_roundTripTime_aadya','AP_totalPlayoutDelay_ellen','AP_totalPlayoutDelay_aadya')])

# Ensure test_predictors has the correct number of columns
if (ncol(test_predictors) != ncol(train_predictors)) {
  stop("Mismatch in number of columns between test_predictors and train_predictors.")
}

# Assuming lasso_fit has been trained
prob <- predict(lasso.fit, newx = test_predictors, type = "response")

# Check if prob is NULL or has no values
if (is.null(prob) || length(prob) == 0) {
  stop("The predicted probabilities are NULL or empty.")
}

# Ensure 'prob' is numeric
if (!is.numeric(prob)) {
  stop("The predicted probabilities are not numeric.")
}

# Convert probabilities to binary classifications
predicted_class <- ifelse(prob > 0.5, levels(web_stats_clean$serviceable_agg)[2], levels(web_stats_clean$serviceable_agg)[1])

# Check if predicted_class is NULL or has length zero
if (is.null(predicted_class) || length(predicted_class) == 0) {
  stop("predicted_class is NULL or has length zero.")
}

predicted_class <- factor(predicted_class, levels = levels(web_stats_clean$serviceable_agg))

# Calculate performance metrics
my.pred.stats(predicted_class, test_data$serviceable_agg)  # Use test_data instead of web_stats_clean
# Out:
# Error in eval(expr, envir, enclos): object 'lasso.fit' not found
# Traceback:
#
# 1. predict(lasso.fit, newx = test_predictors, type = "response")

# %%
test_predictors <- as.matrix(test_data[, c('IT01V_packetsRecieved_ellen','IT01V_packetsRecieved_aadya','IT01V_packetsLost_ellen','IT01V_packetsLost_aadya',
'IT01V_frameWidth_ellen','IT01V_frameWidth_aadya','IT01V_frameHeight_ellen','IT01V_frameHeight_aadya','IT01V_totalFreezesDuration_ellen','IT01V_totalFreezesDuration_aadya',
'IT01V_framesPerSecond_ellen','IT01V_framesPerSecond_aadya','IT01V_bytesReceived_in_bits_s_ellen','IT01V_bytesReceived_in_bits_s_aadya',
'IT01V_totalProcessingDelay_ellen','IT01V_totalProcessingDelay_aadya','IT01V_jitter_ellen','IT01V_jitter_aadya','IT01V_jitterBufferDelay_emissions_ellen',
'IT01V_jitterBufferDelay_emissions_aadya','IT01A_bytesReceived_in_bits_s_ellen','IT01A_bytesReceived_in_bits_s_aadya','IT01A_jitterBufferDelay_emissions_ellen',
'IT01A_jitterBufferDelay_emissions_aadya','OT01V_packetsSent_s_ellen','OT01V_packetsSent_s_aadya','OT01V_bytesSent_in_bits_s_ellen','OT01V_bytesSent_in_bits_s_aadya',
'OT01V_frameWidth_ellen','OT01V_frameWidth_aadya','OT01V_framesPerSecond_ellen','OT01V_framesPerSecond_aadya','OT01V_totalPacketSendDelay_ellen',
'OT01V_totalPacketSendDelay_aadya','OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen','OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya',
'RIV_roundTripTime_ellen','RIV_roundTripTime_aadya','RIV_fractionLost_ellen','RIV_fractionLost_aadya','RIA_fractionLost_ellen','RIA_fractionLost_aadya',
'RIA_roundTripTime_ellen','RIA_roundTripTime_aadya','ROA_roundTripTime_ellen','ROA_roundTripTime_aadya','AP_totalPlayoutDelay_ellen','AP_totalPlayoutDelay_aadya')])

prob <- predict(lasso.fit, newx = test_predictors, type = "response")

if (!is.numeric(prob)) {
  stop("The predicted probabilities are not numeric.")
}

predicted_class <- ifelse(prob > 0.5, levels(web_stats_clean$serviceable_agg)[2], levels(web_stats_clean$serviceable_agg)[1])
predicted_class <- factor(predicted_class, levels = levels(web_stats_clean$serviceable_agg))

# Calculate performance metrics
my.pred.stats(predicted_class, test_data$serviceable_agg)  # Use test_data instead of web_stats_clean
# Out:
# Error in h(simpleError(msg, call)): error in evaluating the argument 'x' in selecting a method for function 'as.matrix': object 'test_data' not found
# Traceback:
#
# 1. as.matrix(test_data[, c("IT01V_packetsRecieved_ellen", "IT01V_packetsRecieved_aadya",
#  .     "IT01V_packetsLost_ellen", "IT01V_packetsLost_aadya", "IT01V_frameWidth_ellen",
#  .     "IT01V_frameWidth_aadya", "IT01V_frameHeight_ellen", "IT01V_frameHeight_aadya",
#  .     "IT01V_totalFreezesDuration_ellen", "IT01V_totalFreezesDuration_aadya",
#  .     "IT01V_framesPerSecond_ellen", "IT01V_framesPerSecond_aadya",
#  .     "IT01V_bytesReceived_in_bits_s_ellen", "IT01V_bytesReceived_in_bits_s_aadya",
#  .     "IT01V_totalProcessingDelay_ellen", "IT01V_totalProcessingDelay_aadya",
#  .     "IT01V_jitter_ellen", "IT01V_jitter_aadya", "IT01V_jitterBufferDelay_emissions_ellen",
#  .     "IT01V_jitterBufferDelay_emissions_aadya", "IT01A_bytesReceived_in_bits_s_ellen",
#  .     "IT01A_bytesReceived_in_bits_s_aadya", "IT01A_jitterBufferDelay_emissions_ellen",
#  .     "IT01A_jitterBufferDelay_emissions_aadya", "OT01V_packetsSent_s_ellen",
#  .     "OT01V_packetsSent_s_aadya", "OT01V_bytesSent_in_bits_s_ellen",
#  .     "OT01V_bytesSent_in_bits_s_aadya", "OT01V_frameWidth_ellen",
#  .     "OT01V_frameWidth_aadya", "OT01V_framesPerSecond_ellen",
#  .     "OT01V_framesPerSecond_aadya", "OT01V_totalPacketSendDelay_ellen",
#  .     "OT01V_totalPacketSendDelay_aadya", "OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen",
#  .     "OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya", "RIV_roundTripTime_ellen",
#  .     "RIV_roundTripTime_aadya", "RIV_fractionLost_ellen", "RIV_fractionLost_aadya",
#  .     "RIA_fractionLost_ellen", "RIA_fractionLost_aadya", "RIA_roundTripTime_ellen",
#  .     "RIA_roundTripTime_aadya", "ROA_roundTripTime_ellen", "ROA_roundTripTime_aadya",
#  .     "AP_totalPlayoutDelay_ellen", "AP_totalPlayoutDelay_aadya")])
# 2. .handleSimpleError(function (cond)
#  . .Internal(C_tryCatchHelper(addr, 1L, cond)), "object 'test_data' not found",
#  .     base::quote(eval(expr, envir, enclos)))
# 3. h(simpleError(msg, call))

# %%
classes <- levels(test_data$serviceable_agg)

# %%
lasso_model <- glmnet(predictors, response, alpha = 1)
print(lasso_model)
# Out:
# Call:  glmnet(x = predictors, y = response, alpha = 1)
#
#    Df  %Dev   Lambda
# 1   0  0.00 0.197200
# 2   1  2.93 0.179700
# 3   1  5.35 0.163800
# 4   1  7.37 0.149200
# 5   1  9.04 0.136000
# 6   3 11.33 0.123900
# 7   3 13.35 0.112900
# 8   3 15.02 0.102800
# 9   5 16.79 0.093710
# 10  7 18.79 0.085380
# 11  7 21.37 0.077800
# 12  8 23.72 0.070890
# 13  8 25.80 0.064590
# 14  9 27.87 0.058850
# 15 10 29.79 0.053620
# 16 11 31.54 0.048860
# 17 12 33.04 0.044520
# 18 13 34.59 0.040560
# 19 15 35.92 0.036960
# 20 15 37.09 0.033680
# 21 16 38.19 0.030680
# 22 16 39.11 0.027960
# 23 17 39.94 0.025470
# 24 18 40.78 0.023210
# 25 19 41.71 0.021150
# 26 18 42.59 0.019270
# 27 19 43.29 0.017560
# 28 20 43.96 0.016000
# 29 21 44.59 0.014580
# 30 21 45.23 0.013280
# 31 20 45.75 0.012100
# 32 21 46.18 0.011030
# 33 21 46.60 0.010050
# 34 25 46.97 0.009155
# 35 26 47.33 0.008342
# 36 27 47.68 0.007601
# 37 27 47.99 0.006926
# 38 27 48.25 0.006310
# 39 27 48.47 0.005750
# 40 27 48.64 0.005239
# 41 29 48.82 0.004774
# 42 30 48.97 0.004349
# 43 29 49.10 0.003963
# 44 32 49.21 0.003611
# 45 34 49.32 0.003290
# 46 34 49.44 0.002998
# 47 34 49.54 0.002732
# 48 34 49.62 0.002489
# 49 35 49.68 0.002268
# 50 36 49.85 0.002066
# 51 35 50.16 0.001883
# 52 35 50.40 0.001716
# 53 36 50.65 0.001563
# 54 37 50.85 0.001424
# 55 37 51.02 0.001298
# 56 38 51.17 0.001182
# 57 38 51.30 0.001077
# 58 38 51.40 0.000982
# 59 38 51.49 0.000894
# 60 38 51.57 0.000815
# 61 38 51.63 0.000743
# 62 36 51.84 0.000677
# 63 37 52.01 0.000616
# 64 41 52.18 0.000562
# 65 39 52.36 0.000512
# 66 39 52.49 0.000466
# 67 40 52.54 0.000425
# 68 40 52.83 0.000387
# 69 41 53.06 0.000353
# 70 42 53.30 0.000322
# 71 42 53.50 0.000293
# 72 42 53.67 0.000267
# 73 43 53.82 0.000243
# 74 43 53.88 0.000222
# 75 44 54.02 0.000202
# 76 42 54.18 0.000184
# 77 44 54.25 0.000168
# 78 42 54.37 0.000153
# 79 44 54.42 0.000139
# 80 42 54.49 0.000127
# 81 43 54.56 0.000116
# 82 43 54.60 0.000105
# 83 44 54.64 0.000096
# 84 44 54.69 0.000087
# 85 46 54.70 0.000080
# 86 46 54.77 0.000073
# 87 46 54.77 0.000066
# 88 46 54.82 0.000060
# 89 46 54.82 0.000055
# 90 46 54.87 0.000050
# 91 46 54.87 0.000046
# 92 46 54.91 0.000042
# 93 46 54.91 0.000038
# 94 46 54.91 0.000034
# 95 46 54.92 0.000031
# 96 44 54.96 0.000029
# 97 44 54.98 0.000026
# 98 45 55.00 0.000024
# 99 45 55.00 0.000022

# %%
cv_fit <- cv.glmnet(x = test_predictors, y = response, alpha = 1, family = "binomial")
par(bg = "white")
plot(cv_fit)
optimal_lambda <- cv_fit$lambda.min  # The lambda that minimizes the cross-validated error
print(optimal_lambda)
# Fit the final model with the optimal lambda
final_model <- glmnet(x = predictors, y = response, alpha = 1, lambda = optimal_lambda)
coef(final_model)
# Out:
# Error in eval(expr, envir, enclos): object 'test_predictors' not found
# Traceback:
#
# 1. cv.glmnet(x = test_predictors, y = response, alpha = 1, family = "binomial")
# 2. nrow(x)

# %%
cv_fit <- cv.glmnet(x = predictors, y = response, alpha = 1, family = "gaussian")
par(bg = "white")
plot(cv_fit)
optimal_lambda <- cv_fit$lambda.min  # The lambda that minimizes the cross-validated error
print(optimal_lambda)
# Fit the final model with the optimal lambda
final_model <- glmnet(x = predictors, y = response, alpha = 1, lambda = optimal_lambda)
coef(final_model)
# Out:
# [1] 0.04885857
# 47 x 1 sparse Matrix of class "dgCMatrix"
#                                                               s0
# (Intercept)                                        -1.354194e-01
# IT01V_packetsRecieved_ellen                         .
# IT01V_packetsRecieved_aadya                         5.032947e-04
# IT01V_packetsLost_ellen                             .
# IT01V_packetsLost_aadya                             6.916337e-03
# IT01A_bytesReceived_in_bits_s_ellen                 .
# IT01A_bytesReceived_in_bits_s_aadya                 .
# OT01V_bytesSent_in_bits_s_aadya                     .
# OT01V_bytesSent_in_bits_s_ellen                     .
# OT01V_packetsSent_s_aadya                           .
# OT01V_packetsSent_s_ellen                           .
# IT01V_frameWidth_ellen                              .
# IT01V_frameWidth_aadya                              .
# IT01V_frameHeight_ellen                             .
# IT01V_frameHeight_aadya                             .
# IT01V_totalFreezesDuration_ellen                    .
# IT01V_totalFreezesDuration_aadya                    .
# IT01V_framesPerSecond_ellen                         .
# IT01V_framesPerSecond_aadya                         .
# IT01V_bytesReceived_in_bits_s_ellen                 .
# IT01V_bytesReceived_in_bits_s_aadya                 .
# IT01V_totalProcessingDelay_ellen                   -6.282335e-05
# IT01V_totalProcessingDelay_aadya                   -2.195915e-03
# IT01V_jitter_ellen                                  .
# IT01V_jitter_aadya                                  .
# IT01V_jitterBufferDelay_emissions_ellen             .
# IT01V_jitterBufferDelay_emissions_aadya            -1.295902e-04
# OT01V_frameWidth_ellen                              .
# OT01V_frameWidth_aadya                              6.520514e-05
# OT01V_framesPerSecond_ellen                         4.678153e-03
# OT01V_framesPerSecond_aadya                         1.600098e-02
# OT01V_totalPacketSendDelay_ellen                    .
# OT01V_totalPacketSendDelay_aadya                    .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .
# RIV_roundTripTime_ellen                             .
# RIV_roundTripTime_aadya                             3.311222e-03
# RIV_fractionLost_ellen                              .
# RIV_fractionLost_aadya                              .
# RIA_fractionLost_ellen                              .
# RIA_fractionLost_aadya                              1.176114e+00
# RIA_roundTripTime_ellen                             .
# RIA_roundTripTime_aadya                             .
# ROA_roundTripTime_ellen                             .
# ROA_roundTripTime_aadya                            -1.522016e-01
# AP_totalPlayoutDelay_ellen                          .
# AP_totalPlayoutDelay_aadya                          .
# plot without title

# %%
my.pred.stats(predict.glmnet.f(cv_fit, web_stats, type="response"), web_stats$serviceable_agg)
# Out:
# Error in terms.formula(formula, data = data): argument is not a valid model
# Traceback:
#
# 1. my.pred.stats(predict.glmnet.f(cv_fit, web_stats, type = "response"),
#  .     web_stats$serviceable_agg)
# 2. factor(prob > 1/2, c(F, T), classes)   # at line 9 of file <text>
# 3. predict.glmnet.f(cv_fit, web_stats, type = "response")   # at line 9 of file <text>
# 4. model.frame(formula = fit$formula, data = data)
# 5. model.frame.default(formula = fit$formula, data = data)
# 6. terms(formula, data = data)
# 7. terms.formula(formula, data = data)

# %%
# Sample the training indices
train_indices <- sample(1:nrow(web_stats_copy), size = 0.7 * nrow(web_stats_copy))

# Split the data into training and testing sets
train_set <- web_stats_copy[train_indices, ]
test_set <- web_stats_copy[-train_indices, ]

# Ensure the target variable is a factor in both train and test sets
train_set$serviceable_agg <- factor(train_set$serviceable_agg, levels = c(0, 1))
test_set$serviceable_agg <- factor(test_set$serviceable_agg, levels = c(0, 1))
# Scale only the numeric columns
numeric_columns <- sapply(train_set, is.numeric)

# Scale the numeric columns in train and test sets
train_set_scaled <- train_set
train_set_scaled[, numeric_columns] <- scale(train_set[, numeric_columns])

test_set_scaled <- test_set
test_set_scaled[, numeric_columns] <- scale(test_set[, numeric_columns])
# Fit the lasso model
lasso.fit <- glmnet.f(serviceable_agg ~ ., train_set_scaled, family="binomial", lambda = 0, maxit = 1000000)

# Predict probabilities on the test set
probabilities <- predict.glmnet.f(lasso.fit, test_set_scaled, type="response")

probabilities <- as.numeric(probabilities)
# Convert probabilities to binary predictions (0 or 1)
predicted_binary <- ifelse(probabilities > 0.5, 1, 0)

par(bg = "white")
# Pass binary factors to the custom stats function
my.pred.stats(predicted_binary, actual_binary)
# Out:
# ---------------------------------------------------------------------------
# Performance statistics:
#
# Confusion matrix:
#
#     target
# pred  0  1
#    0 15  6
#    1  7  0
#
# Classification accuracy = 0.5357143
# Sensitivity             = 0
# Specificity             = 0.6818182
# Area-under-curve        = 0.3409091
# Logarithmic loss        = 299.3361
#
# ---------------------------------------------------------------------------
# plot without title

# %%
lasso.fit = glmnet.f(serviceable_agg ~ ., train_set_scaled, family="binomial")
coefficients(lasso.fit)
# Out:
#   [[ suppressing 100 column names 's0', 's1', 's2' ... ]]
# 49 x 100 sparse Matrix of class "dgCMatrix"
#
# (Intercept)                                        -0.6690496 -0.67247498
# IT01V_packetsRecieved_ellen                         .          .
# IT01V_packetsRecieved_aadya                         .          .
# IT01V_packetsLost_ellen                             .          .
# IT01V_packetsLost_aadya                             .          .
# IT01V_frameWidth_ellen                              .          .
# IT01V_frameWidth_aadya                              .          .
# IT01V_frameHeight_ellen                             .          .
# IT01V_frameHeight_aadya                             .          .
# IT01V_totalFreezesDuration_ellen                    .          .
# IT01V_totalFreezesDuration_aadya                    .          .
# IT01V_framesPerSecond_ellen                         .          .
# IT01V_framesPerSecond_aadya                         .          .
# IT01V_bytesReceived_in_bits_s_ellen                 .          .
# IT01V_bytesReceived_in_bits_s_aadya                 .          .
# IT01V_totalProcessingDelay_ellen                    .          .
# IT01V_totalProcessingDelay_aadya                    .          .
# IT01V_jitter_ellen                                  .          .
# IT01V_jitter_aadya                                  .          .
# IT01V_jitterBufferDelay_emissions_ellen             .          .
# IT01V_jitterBufferDelay_emissions_aadya             .          .
# IT01A_bytesReceived_in_bits_s_ellen                 .          .
# IT01A_bytesReceived_in_bits_s_aadya                 .          .
# IT01A_jitterBufferDelay_emissions_ellen             .          .
# IT01A_jitterBufferDelay_emissions_aadya             .          .
# OT01V_packetsSent_s_ellen                           .          .
# OT01V_packetsSent_s_aadya                           .          .
# OT01V_bytesSent_in_bits_s_ellen                     .          .
# OT01V_bytesSent_in_bits_s_aadya                     .          .
# OT01V_frameWidth_ellen                              .          .
# OT01V_frameWidth_aadya                              .          .
# OT01V_framesPerSecond_ellen                         .          .
# OT01V_framesPerSecond_aadya                         .          0.06840282
# OT01V_totalPacketSendDelay_ellen                    .          .
# OT01V_totalPacketSendDelay_aadya                    .          .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .          .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .          .
# RIV_roundTripTime_ellen                             .          .
# RIV_roundTripTime_aadya                             .          .
# RIV_fractionLost_ellen                              .          .
# RIV_fractionLost_aadya                              .          .
# RIA_fractionLost_ellen                              .          .
# RIA_fractionLost_aadya                              .          .
# RIA_roundTripTime_ellen                             .          .
# RIA_roundTripTime_aadya                             .          .
# ROA_roundTripTime_ellen                             .          .
# ROA_roundTripTime_aadya                             .          .
# AP_totalPlayoutDelay_ellen                          .          .
# AP_totalPlayoutDelay_aadya                          .          .
#
# (Intercept)                                        -6.766053e-01 -6.823833e-01
# IT01V_packetsRecieved_ellen                         .             .
# IT01V_packetsRecieved_aadya                         .             .
# IT01V_packetsLost_ellen                             .             .
# IT01V_packetsLost_aadya                             .             .
# IT01V_frameWidth_ellen                              2.544171e-02  6.129048e-02
# IT01V_frameWidth_aadya                              .             .
# IT01V_frameHeight_ellen                             1.288644e-16  .
# IT01V_frameHeight_aadya                             .             .
# IT01V_totalFreezesDuration_ellen                    .             .
# IT01V_totalFreezesDuration_aadya                    .             .
# IT01V_framesPerSecond_ellen                         .             .
# IT01V_framesPerSecond_aadya                         .             .
# IT01V_bytesReceived_in_bits_s_ellen                 .             .
# IT01V_bytesReceived_in_bits_s_aadya                 .             .
# IT01V_totalProcessingDelay_ellen                    .             .
# IT01V_totalProcessingDelay_aadya                    .            -3.699170e-02
# IT01V_jitter_ellen                                  .             .
# IT01V_jitter_aadya                                  .             .
# IT01V_jitterBufferDelay_emissions_ellen             .             .
# IT01V_jitterBufferDelay_emissions_aadya             .             .
# IT01A_bytesReceived_in_bits_s_ellen                 .             .
# IT01A_bytesReceived_in_bits_s_aadya                 .             .
# IT01A_jitterBufferDelay_emissions_ellen             .             .
# IT01A_jitterBufferDelay_emissions_aadya             .             .
# OT01V_packetsSent_s_ellen                           .             .
# OT01V_packetsSent_s_aadya                           .             .
# OT01V_bytesSent_in_bits_s_ellen                     .             .
# OT01V_bytesSent_in_bits_s_aadya                     .             .
# OT01V_frameWidth_ellen                              .             .
# OT01V_frameWidth_aadya                              2.577289e-16  2.470709e-07
# OT01V_framesPerSecond_ellen                         .             .
# OT01V_framesPerSecond_aadya                         1.167548e-01  1.508469e-01
# OT01V_totalPacketSendDelay_ellen                    .             .
# OT01V_totalPacketSendDelay_aadya                    .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .             .
# RIV_roundTripTime_ellen                             .             .
# RIV_roundTripTime_aadya                             .             .
# RIV_fractionLost_ellen                              .             .
# RIV_fractionLost_aadya                              .             .
# RIA_fractionLost_ellen                              .             .
# RIA_fractionLost_aadya                              .             .
# RIA_roundTripTime_ellen                             .             .
# RIA_roundTripTime_aadya                             .             .
# ROA_roundTripTime_ellen                             .             .
# ROA_roundTripTime_aadya                             .             .
# AP_totalPlayoutDelay_ellen                          .             .
# AP_totalPlayoutDelay_aadya                          .             .
#
# (Intercept)                                        -6.901511e-01 -6.999820e-01
# IT01V_packetsRecieved_ellen                         .             .
# IT01V_packetsRecieved_aadya                         .             .
# IT01V_packetsLost_ellen                             .             .
# IT01V_packetsLost_aadya                             .             .
# IT01V_frameWidth_ellen                              9.510694e-02  1.230411e-01
# IT01V_frameWidth_aadya                              .             .
# IT01V_frameHeight_ellen                             .             .
# IT01V_frameHeight_aadya                             .             .
# IT01V_totalFreezesDuration_ellen                    .             .
# IT01V_totalFreezesDuration_aadya                    .             .
# IT01V_framesPerSecond_ellen                         .             .
# IT01V_framesPerSecond_aadya                         .             .
# IT01V_bytesReceived_in_bits_s_ellen                 .             .
# IT01V_bytesReceived_in_bits_s_aadya                 .             .
# IT01V_totalProcessingDelay_ellen                    .             .
# IT01V_totalProcessingDelay_aadya                   -8.420221e-02 -1.327652e-01
# IT01V_jitter_ellen                                  .             .
# IT01V_jitter_aadya                                  .             .
# IT01V_jitterBufferDelay_emissions_ellen             .             .
# IT01V_jitterBufferDelay_emissions_aadya             .             .
# IT01A_bytesReceived_in_bits_s_ellen                 .             .
# IT01A_bytesReceived_in_bits_s_aadya                 .             .
# IT01A_jitterBufferDelay_emissions_ellen             .             .
# IT01A_jitterBufferDelay_emissions_aadya             .             .
# OT01V_packetsSent_s_ellen                           .             .
# OT01V_packetsSent_s_aadya                           .             .
# OT01V_bytesSent_in_bits_s_ellen                     .             .
# OT01V_bytesSent_in_bits_s_aadya                     .             .
# OT01V_frameWidth_ellen                              .             .
# OT01V_frameWidth_aadya                              2.321744e-07  1.299131e-07
# OT01V_framesPerSecond_ellen                         .             3.795762e-02
# OT01V_framesPerSecond_aadya                         1.821204e-01  2.080282e-01
# OT01V_totalPacketSendDelay_ellen                    .             .
# OT01V_totalPacketSendDelay_aadya                    .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .             .
# RIV_roundTripTime_ellen                             .             .
# RIV_roundTripTime_aadya                             .             .
# RIV_fractionLost_ellen                              .             .
# RIV_fractionLost_aadya                              .             .
# RIA_fractionLost_ellen                              .             .
# RIA_fractionLost_aadya                              .             .
# RIA_roundTripTime_ellen                             .             .
# RIA_roundTripTime_aadya                             .             .
# ROA_roundTripTime_ellen                             .             .
# ROA_roundTripTime_aadya                             .             .
# AP_totalPlayoutDelay_ellen                          .             .
# AP_totalPlayoutDelay_aadya                          .             .
#
# (Intercept)                                        -7.117685e-01 -7.251766e-01
# IT01V_packetsRecieved_ellen                         .             .
# IT01V_packetsRecieved_aadya                         .             .
# IT01V_packetsLost_ellen                             .             .
# IT01V_packetsLost_aadya                             .             .
# IT01V_frameWidth_ellen                              1.490828e-01  1.766613e-01
# IT01V_frameWidth_aadya                              .             .
# IT01V_frameHeight_ellen                             .             7.625155e-17
# IT01V_frameHeight_aadya                             .             .
# IT01V_totalFreezesDuration_ellen                    .             .
# IT01V_totalFreezesDuration_aadya                    .             .
# IT01V_framesPerSecond_ellen                         .             .
# IT01V_framesPerSecond_aadya                         .             .
# IT01V_bytesReceived_in_bits_s_ellen                 .             .
# IT01V_bytesReceived_in_bits_s_aadya                 .             .
# IT01V_totalProcessingDelay_ellen                    .             .
# IT01V_totalProcessingDelay_aadya                   -1.794353e-01 -2.240565e-01
# IT01V_jitter_ellen                                  .             .
# IT01V_jitter_aadya                                  .             .
# IT01V_jitterBufferDelay_emissions_ellen             .             .
# IT01V_jitterBufferDelay_emissions_aadya             .             .
# IT01A_bytesReceived_in_bits_s_ellen                 .             .
# IT01A_bytesReceived_in_bits_s_aadya                 .             .
# IT01A_jitterBufferDelay_emissions_ellen             .             .
# IT01A_jitterBufferDelay_emissions_aadya             .             .
# OT01V_packetsSent_s_ellen                           .             .
# OT01V_packetsSent_s_aadya                           .             .
# OT01V_bytesSent_in_bits_s_ellen                     .             .
# OT01V_bytesSent_in_bits_s_aadya                     .             .
# OT01V_frameWidth_ellen                              .             .
# OT01V_frameWidth_aadya                              1.004981e-07  1.122356e-09
# OT01V_framesPerSecond_ellen                         7.683785e-02  1.125528e-01
# OT01V_framesPerSecond_aadya                         2.332468e-01  2.561705e-01
# OT01V_totalPacketSendDelay_ellen                    .             .
# OT01V_totalPacketSendDelay_aadya                    .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .             .
# RIV_roundTripTime_ellen                             .             .
# RIV_roundTripTime_aadya                             .             5.090626e-03
# RIV_fractionLost_ellen                              .             .
# RIV_fractionLost_aadya                              .             .
# RIA_fractionLost_ellen                              .             .
# RIA_fractionLost_aadya                              .             .
# RIA_roundTripTime_ellen                             .             .
# RIA_roundTripTime_aadya                             .             .
# ROA_roundTripTime_ellen                             .             .
# ROA_roundTripTime_aadya                             .             .
# AP_totalPlayoutDelay_ellen                          .             .
# AP_totalPlayoutDelay_aadya                          .             .
#
# (Intercept)                                        -0.7396403637 -0.75055264
# IT01V_packetsRecieved_ellen                         .             .
# IT01V_packetsRecieved_aadya                         .             .
# IT01V_packetsLost_ellen                             .             .
# IT01V_packetsLost_aadya                             0.0274456335  0.05502528
# IT01V_frameWidth_ellen                              0.2173448459  0.24972628
# IT01V_frameWidth_aadya                              .             .
# IT01V_frameHeight_ellen                             .             .
# IT01V_frameHeight_aadya                             .             .
# IT01V_totalFreezesDuration_ellen                    .             .
# IT01V_totalFreezesDuration_aadya                    .             .
# IT01V_framesPerSecond_ellen                         .             .
# IT01V_framesPerSecond_aadya                         .             .
# IT01V_bytesReceived_in_bits_s_ellen                 .             .
# IT01V_bytesReceived_in_bits_s_aadya                 .             .
# IT01V_totalProcessingDelay_ellen                    .             .
# IT01V_totalProcessingDelay_aadya                   -0.2688963552 -0.32076383
# IT01V_jitter_ellen                                  .             .
# IT01V_jitter_aadya                                  .             .
# IT01V_jitterBufferDelay_emissions_ellen             .             .
# IT01V_jitterBufferDelay_emissions_aadya             .             .
# IT01A_bytesReceived_in_bits_s_ellen                 .             .
# IT01A_bytesReceived_in_bits_s_aadya                 .             .
# IT01A_jitterBufferDelay_emissions_ellen             .             .
# IT01A_jitterBufferDelay_emissions_aadya             .             .
# OT01V_packetsSent_s_ellen                           .             .
# OT01V_packetsSent_s_aadya                           .             .
# OT01V_bytesSent_in_bits_s_ellen                     .             .
# OT01V_bytesSent_in_bits_s_aadya                     .             .
# OT01V_frameWidth_ellen                              .             .
# OT01V_frameWidth_aadya                              0.0008666073  .
# OT01V_framesPerSecond_ellen                         0.1479195224  0.18047045
# OT01V_framesPerSecond_aadya                         0.2636006854  0.30430949
# OT01V_totalPacketSendDelay_ellen                    .             .
# OT01V_totalPacketSendDelay_aadya                    .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .             .
# RIV_roundTripTime_ellen                             .             .
# RIV_roundTripTime_aadya                             0.0459269680  0.08040381
# RIV_fractionLost_ellen                              .             .
# RIV_fractionLost_aadya                              .             0.01259609
# RIA_fractionLost_ellen                              .             .
# RIA_fractionLost_aadya                              .             0.08038787
# RIA_roundTripTime_ellen                             .             .
# RIA_roundTripTime_aadya                             .             .
# ROA_roundTripTime_ellen                             .             .
# ROA_roundTripTime_aadya                             .             .
# AP_totalPlayoutDelay_ellen                          .             .
# AP_totalPlayoutDelay_aadya                          .             .
#
# (Intercept)                                        -0.76735822 -7.876327e-01
# IT01V_packetsRecieved_ellen                         .           .
# IT01V_packetsRecieved_aadya                         .           .
# IT01V_packetsLost_ellen                             .           .
# IT01V_packetsLost_aadya                             0.08211022  1.068858e-01
# IT01V_frameWidth_ellen                              0.28096677  3.125907e-01
# IT01V_frameWidth_aadya                              .           .
# IT01V_frameHeight_ellen                             .           9.176511e-17
# IT01V_frameHeight_aadya                             .           .
# IT01V_totalFreezesDuration_ellen                    .           .
# IT01V_totalFreezesDuration_aadya                    .           .
# IT01V_framesPerSecond_ellen                         .           .
# IT01V_framesPerSecond_aadya                         .           .
# IT01V_bytesReceived_in_bits_s_ellen                 .           .
# IT01V_bytesReceived_in_bits_s_aadya                 .           .
# IT01V_totalProcessingDelay_ellen                    .           .
# IT01V_totalProcessingDelay_aadya                   -0.36987470 -4.176494e-01
# IT01V_jitter_ellen                                  .           .
# IT01V_jitter_aadya                                  .           .
# IT01V_jitterBufferDelay_emissions_ellen             .           .
# IT01V_jitterBufferDelay_emissions_aadya             .           .
# IT01A_bytesReceived_in_bits_s_ellen                 .           .
# IT01A_bytesReceived_in_bits_s_aadya                 .           .
# IT01A_jitterBufferDelay_emissions_ellen             .           .
# IT01A_jitterBufferDelay_emissions_aadya             .           .
# OT01V_packetsSent_s_ellen                           .           .
# OT01V_packetsSent_s_aadya                           .           .
# OT01V_bytesSent_in_bits_s_ellen                     .           .
# OT01V_bytesSent_in_bits_s_aadya                     .           .
# OT01V_frameWidth_ellen                              .           .
# OT01V_frameWidth_aadya                              .           .
# OT01V_framesPerSecond_ellen                         0.21040415  2.384819e-01
# OT01V_framesPerSecond_aadya                         0.34929154  3.946474e-01
# OT01V_totalPacketSendDelay_ellen                    .           .
# OT01V_totalPacketSendDelay_aadya                    .           .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .           .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .           .
# RIV_roundTripTime_ellen                             .           .
# RIV_roundTripTime_aadya                             0.11176399  1.412278e-01
# RIV_fractionLost_ellen                              .           .
# RIV_fractionLost_aadya                              0.04733125  7.771561e-02
# RIA_fractionLost_ellen                              .           .
# RIA_fractionLost_aadya                              0.13330087  1.848678e-01
# RIA_roundTripTime_ellen                             .           .
# RIA_roundTripTime_aadya                             .           .
# ROA_roundTripTime_ellen                             .           .
# ROA_roundTripTime_aadya                             .           .
# AP_totalPlayoutDelay_ellen                          .           .
# AP_totalPlayoutDelay_aadya                          .           .
#
# (Intercept)                                        -8.108968e-01 -0.83830784
# IT01V_packetsRecieved_ellen                         .             .
# IT01V_packetsRecieved_aadya                         .             .
# IT01V_packetsLost_ellen                             .             .
# IT01V_packetsLost_aadya                             1.297852e-01  0.15454626
# IT01V_frameWidth_ellen                              3.447664e-01  0.38306627
# IT01V_frameWidth_aadya                              .             .
# IT01V_frameHeight_ellen                             4.827647e-17  .
# IT01V_frameHeight_aadya                             .             .
# IT01V_totalFreezesDuration_ellen                    .             .
# IT01V_totalFreezesDuration_aadya                    .             .
# IT01V_framesPerSecond_ellen                         .             .
# IT01V_framesPerSecond_aadya                         .             .
# IT01V_bytesReceived_in_bits_s_ellen                 .             .
# IT01V_bytesReceived_in_bits_s_aadya                 .             .
# IT01V_totalProcessingDelay_ellen                    .             .
# IT01V_totalProcessingDelay_aadya                   -4.642107e-01 -0.50830236
# IT01V_jitter_ellen                                  .             .
# IT01V_jitter_aadya                                  .             .
# IT01V_jitterBufferDelay_emissions_ellen             .             .
# IT01V_jitterBufferDelay_emissions_aadya             .             .
# IT01A_bytesReceived_in_bits_s_ellen                 .             .
# IT01A_bytesReceived_in_bits_s_aadya                 .             .
# IT01A_jitterBufferDelay_emissions_ellen             .             .
# IT01A_jitterBufferDelay_emissions_aadya             .             .
# OT01V_packetsSent_s_ellen                           .             .
# OT01V_packetsSent_s_aadya                           .             .
# OT01V_bytesSent_in_bits_s_ellen                     .             .
# OT01V_bytesSent_in_bits_s_aadya                     .             .
# OT01V_frameWidth_ellen                              .             .
# OT01V_frameWidth_aadya                              .             .
# OT01V_framesPerSecond_ellen                         2.648604e-01  0.28402737
# OT01V_framesPerSecond_aadya                         4.403905e-01  0.48242126
# OT01V_totalPacketSendDelay_ellen                    .             .
# OT01V_totalPacketSendDelay_aadya                    .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .             .
# RIV_roundTripTime_ellen                             .             .
# RIV_roundTripTime_aadya                             1.693560e-01  0.19855386
# RIV_fractionLost_ellen                              .             .
# RIV_fractionLost_aadya                              1.054884e-01  0.13292372
# RIA_fractionLost_ellen                              .             .
# RIA_fractionLost_aadya                              2.348380e-01  0.28127070
# RIA_roundTripTime_ellen                             .             .
# RIA_roundTripTime_aadya                             .             .
# ROA_roundTripTime_ellen                             .             .
# ROA_roundTripTime_aadya                             .            -0.01896242
# AP_totalPlayoutDelay_ellen                          .             .
# AP_totalPlayoutDelay_aadya                          .             .
#
# (Intercept)                                        -0.87065584 -0.905379050
# IT01V_packetsRecieved_ellen                         .           .
# IT01V_packetsRecieved_aadya                         .           .
# IT01V_packetsLost_ellen                             .           .
# IT01V_packetsLost_aadya                             0.18322076  0.211124810
# IT01V_frameWidth_ellen                              0.43086050  0.479263621
# IT01V_frameWidth_aadya                              .           .
# IT01V_frameHeight_ellen                             .           .
# IT01V_frameHeight_aadya                             .           .
# IT01V_totalFreezesDuration_ellen                    .           .
# IT01V_totalFreezesDuration_aadya                    .           .
# IT01V_framesPerSecond_ellen                         .           .
# IT01V_framesPerSecond_aadya                         .           .
# IT01V_bytesReceived_in_bits_s_ellen                 .           .
# IT01V_bytesReceived_in_bits_s_aadya                 .           .
# IT01V_totalProcessingDelay_ellen                    .           .
# IT01V_totalProcessingDelay_aadya                   -0.54957995 -0.587566969
# IT01V_jitter_ellen                                  .           .
# IT01V_jitter_aadya                                  .           .
# IT01V_jitterBufferDelay_emissions_ellen             .           .
# IT01V_jitterBufferDelay_emissions_aadya             .          -0.004206948
# IT01A_bytesReceived_in_bits_s_ellen                 .           .
# IT01A_bytesReceived_in_bits_s_aadya                 .           0.003444151
# IT01A_jitterBufferDelay_emissions_ellen             .           .
# IT01A_jitterBufferDelay_emissions_aadya             .           .
# OT01V_packetsSent_s_ellen                           .           .
# OT01V_packetsSent_s_aadya                           .           .
# OT01V_bytesSent_in_bits_s_ellen                     .           .
# OT01V_bytesSent_in_bits_s_aadya                     .           .
# OT01V_frameWidth_ellen                              .           .
# OT01V_frameWidth_aadya                              .           .
# OT01V_framesPerSecond_ellen                         0.29340423  0.299550107
# OT01V_framesPerSecond_aadya                         0.51818431  0.554313226
# OT01V_totalPacketSendDelay_ellen                    .           .
# OT01V_totalPacketSendDelay_aadya                    .           .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .           .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .           .
# RIV_roundTripTime_ellen                             .           .
# RIV_roundTripTime_aadya                             0.23031130  0.262037436
# RIV_fractionLost_ellen                              .           .
# RIV_fractionLost_aadya                              0.16120909  0.188957681
# RIA_fractionLost_ellen                              .           .
# RIA_fractionLost_aadya                              0.32331469  0.364302591
# RIA_roundTripTime_ellen                             .           .
# RIA_roundTripTime_aadya                             .           .
# ROA_roundTripTime_ellen                             .           .
# ROA_roundTripTime_aadya                            -0.06678984 -0.112964447
# AP_totalPlayoutDelay_ellen                          .           .
# AP_totalPlayoutDelay_aadya                          .           .
#
# (Intercept)                                        -9.410994e-01 -9.787829e-01
# IT01V_packetsRecieved_ellen                         .             .
# IT01V_packetsRecieved_aadya                         .             .
# IT01V_packetsLost_ellen                            -2.413184e-02 -5.102434e-02
# IT01V_packetsLost_aadya                             2.425317e-01  2.736224e-01
# IT01V_frameWidth_ellen                              5.470876e-01  6.163846e-01
# IT01V_frameWidth_aadya                              .             .
# IT01V_frameHeight_ellen                             .             6.300791e-17
# IT01V_frameHeight_aadya                             .             .
# IT01V_totalFreezesDuration_ellen                    .             .
# IT01V_totalFreezesDuration_aadya                    .             .
# IT01V_framesPerSecond_ellen                         .             .
# IT01V_framesPerSecond_aadya                         .             .
# IT01V_bytesReceived_in_bits_s_ellen                 .             .
# IT01V_bytesReceived_in_bits_s_aadya                 .             .
# IT01V_totalProcessingDelay_ellen                    .             .
# IT01V_totalProcessingDelay_aadya                   -6.221813e-01 -6.527045e-01
# IT01V_jitter_ellen                                  .             .
# IT01V_jitter_aadya                                  .             .
# IT01V_jitterBufferDelay_emissions_ellen             .             .
# IT01V_jitterBufferDelay_emissions_aadya             .             .
# IT01A_bytesReceived_in_bits_s_ellen                 .             .
# IT01A_bytesReceived_in_bits_s_aadya                 2.911037e-02  5.476460e-02
# IT01A_jitterBufferDelay_emissions_ellen             .             .
# IT01A_jitterBufferDelay_emissions_aadya             .             .
# OT01V_packetsSent_s_ellen                           .             .
# OT01V_packetsSent_s_aadya                           .             .
# OT01V_bytesSent_in_bits_s_ellen                     .             .
# OT01V_bytesSent_in_bits_s_aadya                     .             .
# OT01V_frameWidth_ellen                              .             .
# OT01V_frameWidth_aadya                              9.406486e-07  9.111853e-07
# OT01V_framesPerSecond_ellen                         3.000108e-01  2.986603e-01
# OT01V_framesPerSecond_aadya                         5.725785e-01  5.903393e-01
# OT01V_totalPacketSendDelay_ellen                    .             .
# OT01V_totalPacketSendDelay_aadya                    .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .             .
# RIV_roundTripTime_ellen                             .             .
# RIV_roundTripTime_aadya                             2.991097e-01  3.362396e-01
# RIV_fractionLost_ellen                              .             .
# RIV_fractionLost_aadya                              2.177148e-01  2.466994e-01
# RIA_fractionLost_ellen                              .             .
# RIA_fractionLost_aadya                              3.881681e-01  4.100660e-01
# RIA_roundTripTime_ellen                             .             .
# RIA_roundTripTime_aadya                             .             .
# ROA_roundTripTime_ellen                             .             .
# ROA_roundTripTime_aadya                            -1.689953e-01 -2.238228e-01
# AP_totalPlayoutDelay_ellen                          .             .
# AP_totalPlayoutDelay_aadya                          .             .
#
# (Intercept)                                        -1.018432e+00 -1.060400e+00
# IT01V_packetsRecieved_ellen                         .             .
# IT01V_packetsRecieved_aadya                         .             .
# IT01V_packetsLost_ellen                            -7.656566e-02 -1.010836e-01
# IT01V_packetsLost_aadya                             3.035154e-01  3.296131e-01
# IT01V_frameWidth_ellen                              6.864275e-01  7.568049e-01
# IT01V_frameWidth_aadya                              .             .
# IT01V_frameHeight_ellen                             9.962382e-17  6.987526e-17
# IT01V_frameHeight_aadya                             .             .
# IT01V_totalFreezesDuration_ellen                    .             .
# IT01V_totalFreezesDuration_aadya                    .             3.906125e-02
# IT01V_framesPerSecond_ellen                         .             .
# IT01V_framesPerSecond_aadya                         .             .
# IT01V_bytesReceived_in_bits_s_ellen                 .             .
# IT01V_bytesReceived_in_bits_s_aadya                 .             .
# IT01V_totalProcessingDelay_ellen                    .             .
# IT01V_totalProcessingDelay_aadya                   -6.828169e-01 -7.119622e-01
# IT01V_jitter_ellen                                  .             .
# IT01V_jitter_aadya                                  .             .
# IT01V_jitterBufferDelay_emissions_ellen             .             .
# IT01V_jitterBufferDelay_emissions_aadya             .             .
# IT01A_bytesReceived_in_bits_s_ellen                 .             .
# IT01A_bytesReceived_in_bits_s_aadya                 7.911937e-02  9.829683e-02
# IT01A_jitterBufferDelay_emissions_ellen             .             .
# IT01A_jitterBufferDelay_emissions_aadya             .             .
# OT01V_packetsSent_s_ellen                           .             .
# OT01V_packetsSent_s_aadya                           .             .
# OT01V_bytesSent_in_bits_s_ellen                     .             .
# OT01V_bytesSent_in_bits_s_aadya                     .             .
# OT01V_frameWidth_ellen                              .             .
# OT01V_frameWidth_aadya                              8.488394e-07  1.244830e-05
# OT01V_framesPerSecond_ellen                         2.969064e-01  3.218577e-01
# OT01V_framesPerSecond_aadya                         6.083814e-01  6.236195e-01
# OT01V_totalPacketSendDelay_ellen                    .             .
# OT01V_totalPacketSendDelay_aadya                    .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .             .
# RIV_roundTripTime_ellen                             .             .
# RIV_roundTripTime_aadya                             3.732590e-01  4.072054e-01
# RIV_fractionLost_ellen                              .             .
# RIV_fractionLost_aadya                              2.752998e-01  3.050803e-01
# RIA_fractionLost_ellen                              .             .
# RIA_fractionLost_aadya                              4.316743e-01  4.395287e-01
# RIA_roundTripTime_ellen                             .            -6.564112e-03
# RIA_roundTripTime_aadya                             .             .
# ROA_roundTripTime_ellen                             .             .
# ROA_roundTripTime_aadya                            -2.776359e-01 -3.316535e-01
# AP_totalPlayoutDelay_ellen                          .             .
# AP_totalPlayoutDelay_aadya                          .             .
#
# (Intercept)                                        -1.105319133 -1.153006825
# IT01V_packetsRecieved_ellen                         .            .
# IT01V_packetsRecieved_aadya                         .            .
# IT01V_packetsLost_ellen                            -0.130003297 -0.157501012
# IT01V_packetsLost_aadya                             0.357379062  0.386139973
# IT01V_frameWidth_ellen                              0.848045596  0.955890993
# IT01V_frameWidth_aadya                              .            .
# IT01V_frameHeight_ellen                             .            .
# IT01V_frameHeight_aadya                             .            .
# IT01V_totalFreezesDuration_ellen                    0.003909426  0.047285838
# IT01V_totalFreezesDuration_aadya                    0.069361285  0.092699987
# IT01V_framesPerSecond_ellen                         .            .
# IT01V_framesPerSecond_aadya                         .            .
# IT01V_bytesReceived_in_bits_s_ellen                 .            .
# IT01V_bytesReceived_in_bits_s_aadya                 .            .
# IT01V_totalProcessingDelay_ellen                    .            .
# IT01V_totalProcessingDelay_aadya                   -0.748950798 -0.797041992
# IT01V_jitter_ellen                                  .            .
# IT01V_jitter_aadya                                  .            .
# IT01V_jitterBufferDelay_emissions_ellen             .            .
# IT01V_jitterBufferDelay_emissions_aadya             .            .
# IT01A_bytesReceived_in_bits_s_ellen                 .            .
# IT01A_bytesReceived_in_bits_s_aadya                 0.118843039  0.138167872
# IT01A_jitterBufferDelay_emissions_ellen             .            .
# IT01A_jitterBufferDelay_emissions_aadya             .            .
# OT01V_packetsSent_s_ellen                           .            .
# OT01V_packetsSent_s_aadya                           .            .
# OT01V_bytesSent_in_bits_s_ellen                     .            .
# OT01V_bytesSent_in_bits_s_aadya                     .            .
# OT01V_frameWidth_ellen                              .            .
# OT01V_frameWidth_aadya                              0.005958054  0.017045509
# OT01V_framesPerSecond_ellen                         0.331681519  0.329201474
# OT01V_framesPerSecond_aadya                         0.632281482  0.641835698
# OT01V_totalPacketSendDelay_ellen                    .            .
# OT01V_totalPacketSendDelay_aadya                    .            .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .            .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .            .
# RIV_roundTripTime_ellen                             0.036529329  0.093718724
# RIV_roundTripTime_aadya                             0.453078038  0.508778521
# RIV_fractionLost_ellen                              .            .
# RIV_fractionLost_aadya                              0.336531845  0.353143440
# RIA_fractionLost_ellen                              .            .
# RIA_fractionLost_aadya                              0.449194130  0.453839027
# RIA_roundTripTime_ellen                            -0.009005744 -0.008002591
# RIA_roundTripTime_aadya                             .            .
# ROA_roundTripTime_ellen                             .            .
# ROA_roundTripTime_aadya                            -0.396054026 -0.469591088
# AP_totalPlayoutDelay_ellen                          .            .
# AP_totalPlayoutDelay_aadya                          .            .
#
# (Intercept)                                        -1.204210444 -1.260439205
# IT01V_packetsRecieved_ellen                         .            .
# IT01V_packetsRecieved_aadya                         .            .
# IT01V_packetsLost_ellen                            -0.184238399 -0.211379862
# IT01V_packetsLost_aadya                             0.414562307  0.444394116
# IT01V_frameWidth_ellen                              1.067388341  1.184553715
# IT01V_frameWidth_aadya                              .            .
# IT01V_frameHeight_ellen                             .            .
# IT01V_frameHeight_aadya                             .            .
# IT01V_totalFreezesDuration_ellen                    0.085908630  0.116227538
# IT01V_totalFreezesDuration_aadya                    0.115033310  0.135172013
# IT01V_framesPerSecond_ellen                         .            .
# IT01V_framesPerSecond_aadya                         .            .
# IT01V_bytesReceived_in_bits_s_ellen                 .            .
# IT01V_bytesReceived_in_bits_s_aadya                 .            .
# IT01V_totalProcessingDelay_ellen                    .            0.012236165
# IT01V_totalProcessingDelay_aadya                   -0.844182855 -0.894838072
# IT01V_jitter_ellen                                  .            .
# IT01V_jitter_aadya                                  .            .
# IT01V_jitterBufferDelay_emissions_ellen             .            .
# IT01V_jitterBufferDelay_emissions_aadya             .            .
# IT01A_bytesReceived_in_bits_s_ellen                 .            .
# IT01A_bytesReceived_in_bits_s_aadya                 0.156684634  0.175859435
# IT01A_jitterBufferDelay_emissions_ellen             .            .
# IT01A_jitterBufferDelay_emissions_aadya             .            .
# OT01V_packetsSent_s_ellen                           .            .
# OT01V_packetsSent_s_aadya                           .            .
# OT01V_bytesSent_in_bits_s_ellen                     .            .
# OT01V_bytesSent_in_bits_s_aadya                     .            .
# OT01V_frameWidth_ellen                              .            .
# OT01V_frameWidth_aadya                              0.026986359  0.035206697
# OT01V_framesPerSecond_ellen                         0.326446311  0.321624621
# OT01V_framesPerSecond_aadya                         0.651485196  0.664185950
# OT01V_totalPacketSendDelay_ellen                    .            .
# OT01V_totalPacketSendDelay_aadya                    .            .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .            .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .            .
# RIV_roundTripTime_ellen                             0.150123326  0.203911203
# RIV_roundTripTime_aadya                             0.565058796  0.624588215
# RIV_fractionLost_ellen                              .            .
# RIV_fractionLost_aadya                              0.372019180  0.395691657
# RIA_fractionLost_ellen                              .            .
# RIA_fractionLost_aadya                              0.460673387  0.468642288
# RIA_roundTripTime_ellen                            -0.006167102 -0.001981178
# RIA_roundTripTime_aadya                             .            .
# ROA_roundTripTime_ellen                             .            .
# ROA_roundTripTime_aadya                            -0.543253863 -0.620685741
# AP_totalPlayoutDelay_ellen                          .            .
# AP_totalPlayoutDelay_aadya                          .            .
#
# (Intercept)                                        -1.327596e+00 -1.392599e+00
# IT01V_packetsRecieved_ellen                         .             .
# IT01V_packetsRecieved_aadya                         .             .
# IT01V_packetsLost_ellen                            -2.463873e-01 -2.880482e-01
# IT01V_packetsLost_aadya                             4.840631e-01  5.296147e-01
# IT01V_frameWidth_ellen                              1.323599e+00  1.486468e+00
# IT01V_frameWidth_aadya                              .            -1.982534e-02
# IT01V_frameHeight_ellen                             3.584799e-16  3.099690e-03
# IT01V_frameHeight_aadya                             .            -8.576409e-04
# IT01V_totalFreezesDuration_ellen                    1.174938e-01  1.121717e-01
# IT01V_totalFreezesDuration_aadya                    1.424706e-01  1.387232e-01
# IT01V_framesPerSecond_ellen                         .             .
# IT01V_framesPerSecond_aadya                         .             .
# IT01V_bytesReceived_in_bits_s_ellen                 .             .
# IT01V_bytesReceived_in_bits_s_aadya                 .             .
# IT01V_totalProcessingDelay_ellen                    9.137616e-02  1.795374e-01
# ...
# ROA_roundTripTime_aadya                            -4.503603e+01 -4.599834e+01
# AP_totalPlayoutDelay_ellen                          .             .
# AP_totalPlayoutDelay_aadya                         -1.918849e+00 -1.963777e+00
#
# (Intercept)                                        -2.410738e+01 -2.450537e+01
# IT01V_packetsRecieved_ellen                         .             .
# IT01V_packetsRecieved_aadya                         .             .
# IT01V_packetsLost_ellen                            -4.168359e+00 -4.244873e+00
# IT01V_packetsLost_aadya                             1.357016e+01  1.382168e+01
# IT01V_frameWidth_ellen                              1.522574e+01  1.541434e+01
# IT01V_frameWidth_aadya                              .             .
# IT01V_frameHeight_ellen                             3.234256e-15  6.772991e-15
# IT01V_frameHeight_aadya                             .             .
# IT01V_totalFreezesDuration_ellen                    .             .
# IT01V_totalFreezesDuration_aadya                    .             .
# IT01V_framesPerSecond_ellen                         6.434577e-01  6.772640e-01
# IT01V_framesPerSecond_aadya                         .             .
# IT01V_bytesReceived_in_bits_s_ellen                 .             .
# IT01V_bytesReceived_in_bits_s_aadya                -1.057832e+01 -1.080160e+01
# IT01V_totalProcessingDelay_ellen                    3.029034e+01  3.081299e+01
# IT01V_totalProcessingDelay_aadya                   -2.758139e+00 -2.798641e+00
# IT01V_jitter_ellen                                  .             .
# IT01V_jitter_aadya                                  2.833229e+00  2.873791e+00
# IT01V_jitterBufferDelay_emissions_ellen            -2.888755e+01 -2.948912e+01
# IT01V_jitterBufferDelay_emissions_aadya            -1.214457e+01 -1.230703e+01
# IT01A_bytesReceived_in_bits_s_ellen                 1.105462e+00  1.135812e+00
# IT01A_bytesReceived_in_bits_s_aadya                 5.015707e+00  5.102930e+00
# IT01A_jitterBufferDelay_emissions_ellen            -1.273402e+01 -1.294331e+01
# IT01A_jitterBufferDelay_emissions_aadya            -7.492883e-01 -7.650078e-01
# OT01V_packetsSent_s_ellen                           .             .
# OT01V_packetsSent_s_aadya                           .             .
# OT01V_bytesSent_in_bits_s_ellen                     2.458344e+00  2.561245e+00
# OT01V_bytesSent_in_bits_s_aadya                     1.873457e+01  1.909563e+01
# OT01V_frameWidth_ellen                              .             .
# OT01V_frameWidth_aadya                              4.623913e-02  5.819403e-02
# OT01V_framesPerSecond_ellen                        -2.322591e+00 -2.379509e+00
# OT01V_framesPerSecond_aadya                        -1.697732e-01 -2.469169e-01
# OT01V_totalPacketSendDelay_ellen                    8.499747e+00  8.649119e+00
# OT01V_totalPacketSendDelay_aadya                    9.384951e+00  9.635993e+00
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .             .
# RIV_roundTripTime_ellen                             1.686432e+01  1.717382e+01
# RIV_roundTripTime_aadya                             .             .
# RIV_fractionLost_ellen                              1.076990e+01  1.094050e+01
# RIV_fractionLost_aadya                              9.896907e+00  1.003842e+01
# RIA_fractionLost_ellen                             -7.994931e-03 -1.343737e-02
# RIA_fractionLost_aadya                              6.489019e+00  6.582023e+00
# RIA_roundTripTime_ellen                             .             .
# RIA_roundTripTime_aadya                             1.754622e+01  1.782716e+01
# ROA_roundTripTime_ellen                            -5.338862e+00 -5.428970e+00
# ROA_roundTripTime_aadya                            -4.690010e+01 -4.778235e+01
# AP_totalPlayoutDelay_ellen                          .             .
# AP_totalPlayoutDelay_aadya                         -2.009877e+00 -2.057031e+00
#
# (Intercept)                                        -24.91475566 -2.530401e+01
# IT01V_packetsRecieved_ellen                          .           .
# IT01V_packetsRecieved_aadya                          .           .
# IT01V_packetsLost_ellen                             -4.32342495 -4.400396e+00
# IT01V_packetsLost_aadya                             14.08758291  1.434130e+01
# IT01V_frameWidth_ellen                              15.61102882  1.580344e+01
# IT01V_frameWidth_aadya                               .           .
# IT01V_frameHeight_ellen                              .           .
# IT01V_frameHeight_aadya                              .           .
# IT01V_totalFreezesDuration_ellen                     .           .
# IT01V_totalFreezesDuration_aadya                     .           .
# IT01V_framesPerSecond_ellen                          0.72120143  7.702438e-01
# IT01V_framesPerSecond_aadya                          .           .
# IT01V_bytesReceived_in_bits_s_ellen                  .           .
# IT01V_bytesReceived_in_bits_s_aadya                -11.04465578 -1.127910e+01
# IT01V_totalProcessingDelay_ellen                    31.35174143  3.185826e+01
# IT01V_totalProcessingDelay_aadya                    -2.83769205 -2.874770e+00
# IT01V_jitter_ellen                                   .           .
# IT01V_jitter_aadya                                   2.90873557  2.945941e+00
# IT01V_jitterBufferDelay_emissions_ellen            -30.09137361 -3.066055e+01
# IT01V_jitterBufferDelay_emissions_aadya            -12.49018285 -1.266206e+01
# IT01A_bytesReceived_in_bits_s_ellen                  1.16349989  1.193992e+00
# IT01A_bytesReceived_in_bits_s_aadya                  5.19421134  5.280405e+00
# IT01A_jitterBufferDelay_emissions_ellen            -13.15793774 -1.336166e+01
# IT01A_jitterBufferDelay_emissions_aadya             -0.77160037 -7.846324e-01
# OT01V_packetsSent_s_ellen                            .           .
# OT01V_packetsSent_s_aadya                            .           .
# OT01V_bytesSent_in_bits_s_ellen                      2.67776292  2.795183e+00
# OT01V_bytesSent_in_bits_s_aadya                     19.46957883  1.982893e+01
# OT01V_frameWidth_ellen                               .           .
# OT01V_frameWidth_aadya                               0.05687732  5.852754e-02
# OT01V_framesPerSecond_ellen                         -2.43912358 -2.496935e+00
# OT01V_framesPerSecond_aadya                         -0.33336966 -4.280886e-01
# OT01V_totalPacketSendDelay_ellen                     8.81199192  8.967684e+00
# OT01V_totalPacketSendDelay_aadya                     9.87248994  1.010692e+01
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen   .           .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya   .           .
# RIV_roundTripTime_ellen                             17.48860574  1.779465e+01
# RIV_roundTripTime_aadya                              .           .
# RIV_fractionLost_ellen                              11.11286372  1.128560e+01
# RIV_fractionLost_aadya                              10.19297547  1.034052e+01
# RIA_fractionLost_ellen                              -0.01589402 -2.209219e-02
# RIA_fractionLost_aadya                               6.67826266  6.761129e+00
# RIA_roundTripTime_ellen                              .           .
# RIA_roundTripTime_aadya                             18.11398995  1.839143e+01
# ROA_roundTripTime_ellen                             -5.51857340 -5.606571e+00
# ROA_roundTripTime_aadya                            -48.70546834 -4.957907e+01
# AP_totalPlayoutDelay_ellen                           .           2.514961e-04
# AP_totalPlayoutDelay_aadya                          -2.10369287 -2.151505e+00
#
# (Intercept)                                        -25.686553349 -2.607507e+01
# IT01V_packetsRecieved_ellen                          .            .
# IT01V_packetsRecieved_aadya                          .            .
# IT01V_packetsLost_ellen                             -4.476275578 -4.553486e+00
# IT01V_packetsLost_aadya                             14.593887819  1.485406e+01
# IT01V_frameWidth_ellen                              15.998765415  1.620385e+01
# IT01V_frameWidth_aadya                               .            .
# IT01V_frameHeight_ellen                              .            5.163038e-15
# IT01V_frameHeight_aadya                              .            .
# IT01V_totalFreezesDuration_ellen                     .            .
# IT01V_totalFreezesDuration_aadya                     .            .
# IT01V_framesPerSecond_ellen                          0.826540245  8.891874e-01
# IT01V_framesPerSecond_aadya                          .            .
# IT01V_bytesReceived_in_bits_s_ellen                  .            .
# IT01V_bytesReceived_in_bits_s_aadya                -11.502542570 -1.172306e+01
# IT01V_totalProcessingDelay_ellen                    32.353829404  3.285934e+01
# IT01V_totalProcessingDelay_aadya                    -2.915044038 -2.953790e+00
# IT01V_jitter_ellen                                   .            .
# IT01V_jitter_aadya                                   2.980548503  3.016887e+00
# IT01V_jitterBufferDelay_emissions_ellen            -31.212253268 -3.176519e+01
# IT01V_jitterBufferDelay_emissions_aadya            -12.836584125 -1.302369e+01
# IT01A_bytesReceived_in_bits_s_ellen                  1.226447279  1.258537e+00
# IT01A_bytesReceived_in_bits_s_aadya                  5.366608804  5.454197e+00
# IT01A_jitterBufferDelay_emissions_ellen            -13.558523963 -1.376001e+01
# IT01A_jitterBufferDelay_emissions_aadya             -0.809643021 -8.347920e-01
# OT01V_packetsSent_s_ellen                            .            .
# OT01V_packetsSent_s_aadya                            .            .
# OT01V_bytesSent_in_bits_s_ellen                      2.905414378  3.012815e+00
# OT01V_bytesSent_in_bits_s_aadya                     20.176060470  2.051990e+01
# OT01V_frameWidth_ellen                               .            .
# OT01V_frameWidth_aadya                               0.055156718  4.732302e-02
# OT01V_framesPerSecond_ellen                         -2.560531261 -2.626621e+00
# OT01V_framesPerSecond_aadya                         -0.525607592 -6.249040e-01
# OT01V_totalPacketSendDelay_ellen                     9.132433073  9.304163e+00
# OT01V_totalPacketSendDelay_aadya                    10.338793047  1.056582e+01
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen   .            .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya   .            .
# RIV_roundTripTime_ellen                             18.102220153  1.841790e+01
# RIV_roundTripTime_aadya                              .            .
# RIV_fractionLost_ellen                              11.460942477  1.163685e+01
# RIV_fractionLost_aadya                              10.485875287  1.063578e+01
# RIA_fractionLost_ellen                              -0.030092369 -3.484290e-02
# RIA_fractionLost_aadya                               6.840766552  6.922542e+00
# RIA_roundTripTime_ellen                              .            .
# RIA_roundTripTime_aadya                             18.665219602  1.894300e+01
# ROA_roundTripTime_ellen                             -5.694706196 -5.783075e+00
# ROA_roundTripTime_aadya                            -50.442008572 -5.132475e+01
# AP_totalPlayoutDelay_ellen                           0.007014237  1.642412e-02
# AP_totalPlayoutDelay_aadya                          -2.203428738 -2.257470e+00
#
# (Intercept)                                        -2.646130e+01 -2.684508e+01
# IT01V_packetsRecieved_ellen                         .             .
# IT01V_packetsRecieved_aadya                         .             .
# IT01V_packetsLost_ellen                            -4.630864e+00 -4.708234e+00
# IT01V_packetsLost_aadya                             1.511443e+01  1.537432e+01
# IT01V_frameWidth_ellen                              1.641586e+01  1.663518e+01
# IT01V_frameWidth_aadya                              .             .
# IT01V_frameHeight_ellen                             1.101785e-14  1.021064e-14
# IT01V_frameHeight_aadya                             .             .
# IT01V_totalFreezesDuration_ellen                    .             .
# IT01V_totalFreezesDuration_aadya                    .             .
# IT01V_framesPerSecond_ellen                         9.541466e-01  1.022449e+00
# IT01V_framesPerSecond_aadya                         .             .
# IT01V_bytesReceived_in_bits_s_ellen                 .             .
# IT01V_bytesReceived_in_bits_s_aadya                -1.193972e+01 -1.215276e+01
# IT01V_totalProcessingDelay_ellen                    3.336039e+01  3.385632e+01
# IT01V_totalProcessingDelay_aadya                   -2.991352e+00 -3.029475e+00
# IT01V_jitter_ellen                                  .             .
# IT01V_jitter_aadya                                  3.053902e+00  3.090920e+00
# IT01V_jitterBufferDelay_emissions_ellen            -3.230527e+01 -3.283427e+01
# IT01V_jitterBufferDelay_emissions_aadya            -1.321472e+01 -1.340717e+01
# IT01A_bytesReceived_in_bits_s_ellen                 1.290764e+00  1.323527e+00
# IT01A_bytesReceived_in_bits_s_aadya                 5.541209e+00  5.627856e+00
# IT01A_jitterBufferDelay_emissions_ellen            -1.396078e+01 -1.415922e+01
# IT01A_jitterBufferDelay_emissions_aadya            -8.607319e-01 -8.879380e-01
# OT01V_packetsSent_s_ellen                           .             .
# OT01V_packetsSent_s_aadya                           .             .
# OT01V_bytesSent_in_bits_s_ellen                     3.117662e+00  3.219962e+00
# OT01V_bytesSent_in_bits_s_aadya                     2.085462e+01  2.117992e+01
# OT01V_frameWidth_ellen                              .             .
# OT01V_frameWidth_aadya                              3.840431e-02  2.843854e-02
# OT01V_framesPerSecond_ellen                        -2.692495e+00 -2.758795e+00
# OT01V_framesPerSecond_aadya                        -7.251424e-01 -8.273123e-01
# OT01V_totalPacketSendDelay_ellen                    9.476927e+00  9.650125e+00
# OT01V_totalPacketSendDelay_aadya                    1.078426e+01  1.099691e+01
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .             .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .             .
# RIV_roundTripTime_ellen                             1.873217e+01  1.904494e+01
# RIV_roundTripTime_aadya                             .             .
# RIV_fractionLost_ellen                              1.181407e+01  1.199241e+01
# RIV_fractionLost_aadya                              1.078729e+01  1.093938e+01
# RIA_fractionLost_ellen                             -4.031198e-02 -4.758685e-02
# RIA_fractionLost_aadya                              7.001558e+00  7.077787e+00
# RIA_roundTripTime_ellen                             .             .
# RIA_roundTripTime_aadya                             1.922006e+01  1.949611e+01
# ROA_roundTripTime_ellen                            -5.870243e+00 -5.956644e+00
# ROA_roundTripTime_aadya                            -5.220354e+01 -5.307777e+01
# AP_totalPlayoutDelay_ellen                          2.649879e-02  3.695687e-02
# AP_totalPlayoutDelay_aadya                         -2.311821e+00 -2.366357e+00

# %%
par(bg = "white")
plot(lasso.fit,"lambda", labels=T)
# Out:
# Warning message in plot.window(...):
# ""labels" is not a graphical parameter"
# Warning message in plot.xy(xy, type, ...):
# ""labels" is not a graphical parameter"
# Warning message in box(...):
# ""labels" is not a graphical parameter"
# Warning message in title(...):
# ""labels" is not a graphical parameter"
# plot without title

# %%
lasso.fit = cv.glmnet.f(serviceable_agg ~ ., train_set_scaled, family="binomial")
par(bg = "white")
plot(lasso.fit)
min(lasso.fit$cvm)
coefficients(lasso.fit)
# Out:
# [1] 1.266222
# 49 x 1 sparse Matrix of class "dgCMatrix"
#                                                            s1
# (Intercept)                                        -0.6690496
# IT01V_packetsRecieved_ellen                         .
# IT01V_packetsRecieved_aadya                         .
# IT01V_packetsLost_ellen                             .
# IT01V_packetsLost_aadya                             .
# IT01V_frameWidth_ellen                              .
# IT01V_frameWidth_aadya                              .
# IT01V_frameHeight_ellen                             .
# IT01V_frameHeight_aadya                             .
# IT01V_totalFreezesDuration_ellen                    .
# IT01V_totalFreezesDuration_aadya                    .
# IT01V_framesPerSecond_ellen                         .
# IT01V_framesPerSecond_aadya                         .
# IT01V_bytesReceived_in_bits_s_ellen                 .
# IT01V_bytesReceived_in_bits_s_aadya                 .
# IT01V_totalProcessingDelay_ellen                    .
# IT01V_totalProcessingDelay_aadya                    .
# IT01V_jitter_ellen                                  .
# IT01V_jitter_aadya                                  .
# IT01V_jitterBufferDelay_emissions_ellen             .
# IT01V_jitterBufferDelay_emissions_aadya             .
# IT01A_bytesReceived_in_bits_s_ellen                 .
# IT01A_bytesReceived_in_bits_s_aadya                 .
# IT01A_jitterBufferDelay_emissions_ellen             .
# IT01A_jitterBufferDelay_emissions_aadya             .
# OT01V_packetsSent_s_ellen                           .
# OT01V_packetsSent_s_aadya                           .
# OT01V_bytesSent_in_bits_s_ellen                     .
# OT01V_bytesSent_in_bits_s_aadya                     .
# OT01V_frameWidth_ellen                              .
# OT01V_frameWidth_aadya                              .
# OT01V_framesPerSecond_ellen                         .
# OT01V_framesPerSecond_aadya                         .
# OT01V_totalPacketSendDelay_ellen                    .
# OT01V_totalPacketSendDelay_aadya                    .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen  .
# OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya  .
# RIV_roundTripTime_ellen                             .
# RIV_roundTripTime_aadya                             .
# RIV_fractionLost_ellen                              .
# RIV_fractionLost_aadya                              .
# RIA_fractionLost_ellen                              .
# RIA_fractionLost_aadya                              .
# RIA_roundTripTime_ellen                             .
# RIA_roundTripTime_aadya                             .
# ROA_roundTripTime_ellen                             .
# ROA_roundTripTime_aadya                             .
# AP_totalPlayoutDelay_ellen                          .
# AP_totalPlayoutDelay_aadya                          .
# plot without title

# %%
par(bg = "white")
my.pred.stats(predict.glmnet.f(lasso.fit, test_set_scaled, type="response"), test_set_scaled$serviceable_agg)
# Out:
# ---------------------------------------------------------------------------
# Performance statistics:
#
# Confusion matrix:
#
#     target
# pred  0  1
#    0 18 10
#    1  0  0
#
# Classification accuracy = 0.6428571
# Sensitivity             = 0
# Specificity             = 1
# Area-under-curve        = 0.5
# Logarithmic loss        = 18.27024
#
# ---------------------------------------------------------------------------
# plot without title

# %%
subjective <- read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression/regression_tables/fieldwork/subjective_table.csv")
sum(is.na(subjective))
web_stats <- read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression_2_(web_to_serviceable)/independent_vars_tables/fieldwork_independent_vars_table.csv")
sum(is.na(web_stats))
#rename the id col in subjective to perform a merge
names(subjective)[names(subjective) == "identifier"] <- "ID"
#add the ordinal var to web_stats
web_stats <- merge(web_stats, subjective[, c("ID", "serviceable_agg")], by = "ID", all.x = TRUE)
sum(is.na(web_stats))
# Out:
# [1] 0
# [1] 0
# [1] 90

# %%
# Separate the predictor variables (X) and the response variable (y)
X <- model.matrix(serviceable_agg ~ IT01V_packetsRecieved_ellen + IT01V_packetsRecieved_aadya + IT01V_packetsLost_ellen + IT01V_packetsLost_aadya + 
IT01V_frameWidth_ellen + IT01V_frameWidth_aadya + IT01V_totalFreezesDuration_ellen + IT01V_totalFreezesDuration_aadya + 
IT01V_framesPerSecond_ellen + IT01V_framesPerSecond_aadya + IT01V_bytesReceived_in_bits_s_ellen + IT01V_bytesReceived_in_bits_s_aadya + 
IT01V_totalProcessingDelay_ellen + IT01V_totalProcessingDelay_aadya + IT01V_jitter_ellen + IT01V_jitter_aadya + 
IT01V_jitterBufferDelay_emissions_ellen + IT01V_jitterBufferDelay_emissions_aadya + 
IT01A_bytesReceived_in_bits_s_ellen + IT01A_bytesReceived_in_bits_s_aadya + IT01A_jitterBufferDelay_emissions_ellen + IT01A_jitterBufferDelay_emissions_aadya + 
OT01V_packetsSent_s_ellen + OT01V_packetsSent_s_aadya + OT01V_bytesSent_in_bits_s_ellen + OT01V_bytesSent_in_bits_s_aadya + 
OT01V_frameWidth_ellen + OT01V_frameWidth_aadya + OT01V_framesPerSecond_ellen + OT01V_framesPerSecond_aadya + 
OT01V_totalPacketSendDelay_ellen + OT01V_totalPacketSendDelay_aadya + OT01V_totalPacketSendDelay_packetsSent_in_ms_ellen + 
OT01V_totalPacketSendDelay_packetsSent_in_ms_aadya + RIV_roundTripTime_ellen + RIV_roundTripTime_aadya + 
RIV_fractionLost_ellen + RIV_fractionLost_aadya + RIA_fractionLost_ellen + RIA_fractionLost_aadya + 
RIA_roundTripTime_ellen + RIA_roundTripTime_aadya + ROA_roundTripTime_ellen + ROA_roundTripTime_aadya + 
AP_totalPlayoutDelay_ellen + AP_totalPlayoutDelay_aadya, 
data = web_stats)[, -1] 

y <- as.numeric(web_stats$serviceable_agg)  # Ensure the response is numeric
# Out:
# [1] 90

# %%
install.packages("glmnet")
library(glmnet)

# Set alpha = 1 for Lasso
lasso_model <- cv.glmnet(X, y, family = "binomial", alpha = 1)

# Print the best lambda value
lasso_model$lambda.min

# Fit the model with the best lambda
best_lasso_model <- glmnet(X, y, family = "binomial", alpha = 1, lambda = lasso_model$lambda.min)
# Out:
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpyGic5f/downloaded_packages
# Loading required package: Matrix
#
# Loaded glmnet 4.1-8
# Error in glmnet(x, y, weights = weights, offset = offset, lambda = lambda, : number of observations in y (90) not equal to the number of rows of x (0)
# Traceback:
#
# 1. cv.glmnet(X, y, family = "binomial", alpha = 1)
# 2. cv.glmnet.raw(x, y, weights, offset, lambda, type.measure, nfolds,
#  .     foldid, alignment, grouped, keep, parallel, trace.it, glmnet.call,
#  .     cv.call, ...)
# 3. glmnet(x, y, weights = weights, offset = offset, lambda = lambda,
#  .     trace.it = trace.it, ...)
# 4. stop(paste("number of observations in y (", nrowy, ") not equal to the number of rows of x (",
#  .     nobs, ")", sep = ""))

# %%
# Out:
# [1] 49
