# %%
install.packages("pROC")
install.packages("vctrs")
install.packages("caret")
install.packages("nnet")
install.packages("ggplot2")
install.packages("cowplot")
# Out:
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpN8AJBo/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpN8AJBo/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpN8AJBo/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpN8AJBo/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpN8AJBo/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/91/4c3th19d31j6hvx23r6bb5b00000gn/T//RtmpN8AJBo/downloaded_packages

# %%
stage1 <- read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression/regression_tables/stage_1/stage1_regression_table.csv")
stage2 <- read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression/regression_tables/stage_2/stage2_regression_table.csv")
stage3 <-read.csv("/Users/User/Documents/GitHub/DesktopDownthrottlingExperiment/post_experiment/Regression/regression_tables/stage_3/stage3_regression_table.csv")

# %%
options(repr.plot.width = 10, repr.plot.height = 6)

par(bg = "white")
hist(stage1$agg_MOS, 
     col = "black",
     border = "white")
     
par(bg = "white")
hist(stage2$agg_MOS, 
     col = "black",
     border = "white")

par(bg = "white")
hist(stage3$agg_MOS, 
     col = "black",
     border = "white")

par(bg = "white")
hist(stage2$ellen_MOS, 
     col = "black",
     border = "white")

par(bg = "white")
hist(stage2$aadya_MOS, 
     col = "black",
     border = "white")
par(bg = "white")
hist(stage3$ellen_MOS, 
     col = "black",
     border = "white")

par(bg = "white")
hist(stage3$aadya_MOS, 
     col = "black",
     border = "white")
# Out:
# Plot with title "Histogram of stage1$agg_MOS"
# Plot with title "Histogram of stage2$agg_MOS"
# Plot with title "Histogram of stage3$agg_MOS"
# Plot with title "Histogram of stage2$ellen_MOS"
# Plot with title "Histogram of stage2$aadya_MOS"
# Plot with title "Histogram of stage3$ellen_MOS"
# Plot with title "Histogram of stage3$aadya_MOS"
